# %%
# our usual pylab import
# %matplotlib inline

# %% [markdown]
# # Goal

# %% [markdown]
# For background, see [Mapping Census Data](http://www.udel.edu/johnmack/frec682/census/), including the
# [scan of the 10-question form](http://www.udel.edu/johnmack/frec682/census/census_form.png).  Keep in mind what people were asked and the range of data available in the census.
#
# Using the census API to get an understanding of some of the geographic entities in the **2010 census**.  We'll specifically be using the variable `P0010001`, the total population.
#
# What you will do in this notebook:
#
#  * Sum the population of the **states** (or state-like entity like DC) to get the total population of the **nation**
#  * Add up the **counties** for each **state** and validate the sums
#  * Add up the **census tracts** for each **county** and validate the sums
#
# We will make use of `pandas` in this notebook.

# %% [markdown]
# I often have the following [diagram](http://www.census.gov/geo/reference/pdfs/geodiagram.pdf) in mind to help understand the relationship among entities.  Also use the [list of example URLs](http://api.census.gov/data/2010/sf1/geo.html)  -- it'll come in handy.

# %% [markdown]
# <a href="http://www.flickr.com/photos/raymondyee/12297467734/" title="Census Geographic Hierarchies by Raymond Yee, on Flickr"><img src="http://farm4.staticflickr.com/3702/12297467734_af8882d310_c.jpg" width="618" height="800" alt="Census Geographic Hierarchies"></a>

# %% [markdown]
# # Working out the geographical hierarchy for Cafe Milano

# %% [markdown]
# It's helpful to have a concrete instance of a place to work with, especially when dealing with rather intangible entities like census tracts, block groups, and blocks.  You can use the [American FactFinder](http://factfinder2.census.gov/faces/nav/jsf/pages/index.xhtml) site to look up for any given US address the corresponding census geographies.
#
# Let's use Cafe Milano in Berkeley as an example. You can verify the following results by typing in the address into http://factfinder2.census.gov/faces/nav/jsf/pages/searchresults.xhtml?refresh=t.
#
# https://www.evernote.com/shard/s1/sh/dc0bfb96-4965-4fbf-bc28-c9d4d0080782/2bd8c92a045d62521723347d62fa2b9d
#
# 2522 Bancroft Way, BERKELEY, CA, 94704
#
# * State: California
# * County: Alameda County
# * County Subdivision: Berkeley CCD, Alameda County, California
# * Census Tract: Census Tract 4228, Alameda County, California
# * Block Group: Block Group 1, Census Tract 4228, Alameda County, California
# * Block: Block 1001, Block Group 1, Census Tract 4228, Alameda County, California

# %%
# YouTube video I made on how to use the American Factfinder site to look up addresses
from IPython.display import YouTubeVideo
YouTubeVideo('HeXcliUx96Y')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/HeXcliUx96Y"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#  standard numpy, pandas, matplotlib imports

import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series, Index
import pandas as pd

# %%
# check that CENSUS_KEY is defined
import census
import us

import requests

import settings
assert settings.CENSUS_KEY is not None

# %% [markdown]
# The census documentation has example URLs but needs your API key to work.  In this notebook, we'll use the IPython notebook HTML display mechanism to help out.

# %%
c = census.Census(key=settings.CENSUS_KEY)

# %% [markdown]
# Note:  we can use `c.sf1` to access 2010 census (SF1: Census Summary File 1 (2010, 2000, 1990) available in API -- 2010 is the default)
#
# see documentation: [sunlightlabs/census](https://github.com/sunlightlabs/census)

# %% [markdown]
# # Summing up populations by state

# %% [markdown]
# Let's make a `DataFrame` named `states_df` with columns `NAME`, `P0010001` (for population), and `state` (to hold the FIPS code).  **Make sure to exclude Puerto Rico.**

# %%
# call the API and instantiate `df`
df = DataFrame(c.sf1.get('NAME,P0010001', geo={'for':'state:*'}))
# convert the population to integer
df['P0010001'] = df['P0010001'].astype(np.int)
df.head()
# Out:
#          NAME  P0010001 state
# 0     Alabama   4779736    01
# 1      Alaska    710231    02
# 2     Arizona   6392017    04
# 3    Arkansas   2915918    05
# 4  California  37253956    06

# %%
states_df = df[df['NAME'] != 'Puerto Rico']

# %%
'a' in ['a', 'b']
# Out:
# True

# %% [markdown]
# You can filter Puerto Rico (PR) in a number of ways -- use the way you're most comfortable with.
#
# Optional fun: filter PR in the following way
#
# * calculate a `np.array` holding the the fips of the states
# * then use [numpy.in1d](http://docs.scipy.org/doc/numpy/reference/generated/numpy.in1d.html), which is a analogous to the [in](http://stackoverflow.com/a/3437130/7782) operator to test membership in a list

# %%
states_fips = np.array([state.fips for state in us.states.STATES])
states_df = df[np.in1d(df.state,states_fips)]

# %% [markdown]
# If `states_df` is calculated properly, the following asserts will pass silently.

# %%
# check that we have three columns
assert set(states_df.columns) == set((u'NAME', u'P0010001', u'state'))

# check that the total 2010 census population is correct
assert np.sum(states_df.P0010001) == 308745538 

# check that the number of states+DC is 51
assert len(states_df) == 51

# %% [markdown]
# # Counties

# %% [markdown]
# Looking at http://api.census.gov/data/2010/sf1/geo.html, we see
#
#     state-county: http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*
#
# if we want to grab all counties in one go, or you can grab counties state-by-state:
#
#     http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*&in=state:06
#
# for all counties in the state with FIPS code `06` (which is what state?)

# %%
# Here's a way to use translate 
# http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*
# into a call using the census.Census object

r = c.sf1.get('NAME,P0010001', geo={'for':'county:*'})

# ask yourself what len(r) means and what it should be
len(r)
# Out:
# 3221

# %%
# let's try out one of the `census` object convenience methods
# instead of using `c.sf1.get`

r = c.sf1.state_county('NAME,P0010001',census.ALL,census.ALL)
r
# Out:
# [{'NAME': 'Autauga County',
#   'P0010001': '54571',
#   'county': '001',
#   'state': '01'},
#  {'NAME': 'Baldwin County',
#   'P0010001': '182265',
#   'county': '003',
#   'state': '01'},
#  {'NAME': 'Barbour County',
#   'P0010001': '27457',
#   'county': '005',
#   'state': '01'},
#  {'NAME': 'Bibb County', 'P0010001': '22915', 'county': '007', 'state': '01'},
#  {'NAME': 'Blount County',
#   'P0010001': '57322',
#   'county': '009',
#   'state': '01'},
#  {'NAME': 'Bullock County',
#   'P0010001': '10914',
#   'county': '011',
#   'state': '01'},
#  {'NAME': 'Butler County',
#   'P0010001': '20947',
#   'county': '013',
#   'state': '01'},
#  {'NAME': 'Calhoun County',
#   'P0010001': '118572',
#   'county': '015',
#   'state': '01'},
#  {'NAME': 'Chambers County',
#   'P0010001': '34215',
#   'county': '017',
#   'state': '01'},
#  {'NAME': 'Cherokee County',
#   'P0010001': '25989',
#   'county': '019',
#   'state': '01'},
#  {'NAME': 'Chilton County',
#   'P0010001': '43643',
#   'county': '021',
#   'state': '01'},
#  {'NAME': 'Choctaw County',
#   'P0010001': '13859',
#   'county': '023',
#   'state': '01'},
#  {'NAME': 'Clarke County',
#   'P0010001': '25833',
#   'county': '025',
#   'state': '01'},
#  {'NAME': 'Clay County', 'P0010001': '13932', 'county': '027', 'state': '01'},
#  {'NAME': 'Cleburne County',
#   'P0010001': '14972',
#   'county': '029',
#   'state': '01'},
#  {'NAME': 'Coffee County',
#   'P0010001': '49948',
#   'county': '031',
#   'state': '01'},
#  {'NAME': 'Colbert County',
#   'P0010001': '54428',
#   'county': '033',
#   'state': '01'},
#  {'NAME': 'Conecuh County',
#   'P0010001': '13228',
#   'county': '035',
#   'state': '01'},
#  {'NAME': 'Coosa County', 'P0010001': '11539', 'county': '037', 'state': '01'},
#  {'NAME': 'Covington County',
#   'P0010001': '37765',
#   'county': '039',
#   'state': '01'},
#  {'NAME': 'Crenshaw County',
#   'P0010001': '13906',
#   'county': '041',
#   'state': '01'},
#  {'NAME': 'Cullman County',
#   'P0010001': '80406',
#   'county': '043',
#   'state': '01'},
#  {'NAME': 'Dale County', 'P0010001': '50251', 'county': '045', 'state': '01'},
#  {'NAME': 'Dallas County',
#   'P0010001': '43820',
#   'county': '047',
#   'state': '01'},
#  {'NAME': 'DeKalb County',
#   'P0010001': '71109',
#   'county': '049',
#   'state': '01'},
#  {'NAME': 'Elmore County',
#   'P0010001': '79303',
#   'county': '051',
#   'state': '01'},
#  {'NAME': 'Escambia County',
#   'P0010001': '38319',
#   'county': '053',
#   'state': '01'},
#  {'NAME': 'Etowah County',
#   'P0010001': '104430',
#   'county': '055',
#   'state': '01'},
#  {'NAME': 'Fayette County',
#   'P0010001': '17241',
#   'county': '057',
#   'state': '01'},
#  {'NAME': 'Franklin County',
#   'P0010001': '31704',
#   'county': '059',
#   'state': '01'},
#  {'NAME': 'Geneva County',
#   'P0010001': '26790',
#   'county': '061',
#   'state': '01'},
#  {'NAME': 'Greene County', 'P0010001': '9045', 'county': '063', 'state': '01'},
#  {'NAME': 'Hale County', 'P0010001': '15760', 'county': '065', 'state': '01'},
#  {'NAME': 'Henry County', 'P0010001': '17302', 'county': '067', 'state': '01'},
#  {'NAME': 'Houston County',
#   'P0010001': '101547',
#   'county': '069',
#   'state': '01'},
#  {'NAME': 'Jackson County',
#   'P0010001': '53227',
#   'county': '071',
#   'state': '01'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '658466',
#   'county': '073',
#   'state': '01'},
#  {'NAME': 'Lamar County', 'P0010001': '14564', 'county': '075', 'state': '01'},
#  {'NAME': 'Lauderdale County',
#   'P0010001': '92709',
#   'county': '077',
#   'state': '01'},
#  {'NAME': 'Lawrence County',
#   'P0010001': '34339',
#   'county': '079',
#   'state': '01'},
#  {'NAME': 'Lee County', 'P0010001': '140247', 'county': '081', 'state': '01'},
#  {'NAME': 'Limestone County',
#   'P0010001': '82782',
#   'county': '083',
#   'state': '01'},
#  {'NAME': 'Lowndes County',
#   'P0010001': '11299',
#   'county': '085',
#   'state': '01'},
#  {'NAME': 'Macon County', 'P0010001': '21452', 'county': '087', 'state': '01'},
#  {'NAME': 'Madison County',
#   'P0010001': '334811',
#   'county': '089',
#   'state': '01'},
#  {'NAME': 'Marengo County',
#   'P0010001': '21027',
#   'county': '091',
#   'state': '01'},
#  {'NAME': 'Marion County',
#   'P0010001': '30776',
#   'county': '093',
#   'state': '01'},
#  {'NAME': 'Marshall County',
#   'P0010001': '93019',
#   'county': '095',
#   'state': '01'},
#  {'NAME': 'Mobile County',
#   'P0010001': '412992',
#   'county': '097',
#   'state': '01'},
#  {'NAME': 'Monroe County',
#   'P0010001': '23068',
#   'county': '099',
#   'state': '01'},
#  {'NAME': 'Montgomery County',
#   'P0010001': '229363',
#   'county': '101',
#   'state': '01'},
#  {'NAME': 'Morgan County',
#   'P0010001': '119490',
#   'county': '103',
#   'state': '01'},
#  {'NAME': 'Perry County', 'P0010001': '10591', 'county': '105', 'state': '01'},
#  {'NAME': 'Pickens County',
#   'P0010001': '19746',
#   'county': '107',
#   'state': '01'},
#  {'NAME': 'Pike County', 'P0010001': '32899', 'county': '109', 'state': '01'},
#  {'NAME': 'Randolph County',
#   'P0010001': '22913',
#   'county': '111',
#   'state': '01'},
#  {'NAME': 'Russell County',
#   'P0010001': '52947',
#   'county': '113',
#   'state': '01'},
#  {'NAME': 'St. Clair County',
#   'P0010001': '83593',
#   'county': '115',
#   'state': '01'},
#  {'NAME': 'Shelby County',
#   'P0010001': '195085',
#   'county': '117',
#   'state': '01'},
#  {'NAME': 'Sumter County',
#   'P0010001': '13763',
#   'county': '119',
#   'state': '01'},
#  {'NAME': 'Talladega County',
#   'P0010001': '82291',
#   'county': '121',
#   'state': '01'},
#  {'NAME': 'Tallapoosa County',
#   'P0010001': '41616',
#   'county': '123',
#   'state': '01'},
#  {'NAME': 'Tuscaloosa County',
#   'P0010001': '194656',
#   'county': '125',
#   'state': '01'},
#  {'NAME': 'Walker County',
#   'P0010001': '67023',
#   'county': '127',
#   'state': '01'},
#  {'NAME': 'Washington County',
#   'P0010001': '17581',
#   'county': '129',
#   'state': '01'},
#  {'NAME': 'Wilcox County',
#   'P0010001': '11670',
#   'county': '131',
#   'state': '01'},
#  {'NAME': 'Winston County',
#   'P0010001': '24484',
#   'county': '133',
#   'state': '01'},
#  {'NAME': 'Aleutians East Borough',
#   'P0010001': '3141',
#   'county': '013',
#   'state': '02'},
#  {'NAME': 'Aleutians West Census Area',
#   'P0010001': '5561',
#   'county': '016',
#   'state': '02'},
#  {'NAME': 'Anchorage Municipality',
#   'P0010001': '291826',
#   'county': '020',
#   'state': '02'},
#  {'NAME': 'Bethel Census Area',
#   'P0010001': '17013',
#   'county': '050',
#   'state': '02'},
#  {'NAME': 'Bristol Bay Borough',
#   'P0010001': '997',
#   'county': '060',
#   'state': '02'},
#  {'NAME': 'Denali Borough',
#   'P0010001': '1826',
#   'county': '068',
#   'state': '02'},
#  {'NAME': 'Dillingham Census Area',
#   'P0010001': '4847',
#   'county': '070',
#   'state': '02'},
#  {'NAME': 'Fairbanks North Star Borough',
#   'P0010001': '97581',
#   'county': '090',
#   'state': '02'},
#  {'NAME': 'Haines Borough',
#   'P0010001': '2508',
#   'county': '100',
#   'state': '02'},
#  {'NAME': 'Hoonah-Angoon Census Area',
#   'P0010001': '2150',
#   'county': '105',
#   'state': '02'},
#  {'NAME': 'Juneau City and Borough',
#   'P0010001': '31275',
#   'county': '110',
#   'state': '02'},
#  {'NAME': 'Kenai Peninsula Borough',
#   'P0010001': '55400',
#   'county': '122',
#   'state': '02'},
#  {'NAME': 'Ketchikan Gateway Borough',
#   'P0010001': '13477',
#   'county': '130',
#   'state': '02'},
#  {'NAME': 'Kodiak Island Borough',
#   'P0010001': '13592',
#   'county': '150',
#   'state': '02'},
#  {'NAME': 'Lake and Peninsula Borough',
#   'P0010001': '1631',
#   'county': '164',
#   'state': '02'},
#  {'NAME': 'Matanuska-Susitna Borough',
#   'P0010001': '88995',
#   'county': '170',
#   'state': '02'},
#  {'NAME': 'Nome Census Area',
#   'P0010001': '9492',
#   'county': '180',
#   'state': '02'},
#  {'NAME': 'North Slope Borough',
#   'P0010001': '9430',
#   'county': '185',
#   'state': '02'},
#  {'NAME': 'Northwest Arctic Borough',
#   'P0010001': '7523',
#   'county': '188',
#   'state': '02'},
#  {'NAME': 'Petersburg Census Area',
#   'P0010001': '3815',
#   'county': '195',
#   'state': '02'},
#  {'NAME': 'Prince of Wales-Hyder Census Area',
#   'P0010001': '5559',
#   'county': '198',
#   'state': '02'},
#  {'NAME': 'Sitka City and Borough',
#   'P0010001': '8881',
#   'county': '220',
#   'state': '02'},
#  {'NAME': 'Skagway Municipality',
#   'P0010001': '968',
#   'county': '230',
#   'state': '02'},
#  {'NAME': 'Southeast Fairbanks Census Area',
#   'P0010001': '7029',
#   'county': '240',
#   'state': '02'},
#  {'NAME': 'Valdez-Cordova Census Area',
#   'P0010001': '9636',
#   'county': '261',
#   'state': '02'},
#  {'NAME': 'Wade Hampton Census Area',
#   'P0010001': '7459',
#   'county': '270',
#   'state': '02'},
#  {'NAME': 'Wrangell City and Borough',
#   'P0010001': '2369',
#   'county': '275',
#   'state': '02'},
#  {'NAME': 'Yakutat City and Borough',
#   'P0010001': '662',
#   'county': '282',
#   'state': '02'},
#  {'NAME': 'Yukon-Koyukuk Census Area',
#   'P0010001': '5588',
#   'county': '290',
#   'state': '02'},
#  {'NAME': 'Apache County',
#   'P0010001': '71518',
#   'county': '001',
#   'state': '04'},
#  {'NAME': 'Cochise County',
#   'P0010001': '131346',
#   'county': '003',
#   'state': '04'},
#  {'NAME': 'Coconino County',
#   'P0010001': '134421',
#   'county': '005',
#   'state': '04'},
#  {'NAME': 'Gila County', 'P0010001': '53597', 'county': '007', 'state': '04'},
#  {'NAME': 'Graham County',
#   'P0010001': '37220',
#   'county': '009',
#   'state': '04'},
#  {'NAME': 'Greenlee County',
#   'P0010001': '8437',
#   'county': '011',
#   'state': '04'},
#  {'NAME': 'La Paz County',
#   'P0010001': '20489',
#   'county': '012',
#   'state': '04'},
#  {'NAME': 'Maricopa County',
#   'P0010001': '3817117',
#   'county': '013',
#   'state': '04'},
#  {'NAME': 'Mohave County',
#   'P0010001': '200186',
#   'county': '015',
#   'state': '04'},
#  {'NAME': 'Navajo County',
#   'P0010001': '107449',
#   'county': '017',
#   'state': '04'},
#  {'NAME': 'Pima County', 'P0010001': '980263', 'county': '019', 'state': '04'},
#  {'NAME': 'Pinal County',
#   'P0010001': '375770',
#   'county': '021',
#   'state': '04'},
#  {'NAME': 'Santa Cruz County',
#   'P0010001': '47420',
#   'county': '023',
#   'state': '04'},
#  {'NAME': 'Yavapai County',
#   'P0010001': '211033',
#   'county': '025',
#   'state': '04'},
#  {'NAME': 'Yuma County', 'P0010001': '195751', 'county': '027', 'state': '04'},
#  {'NAME': 'Arkansas County',
#   'P0010001': '19019',
#   'county': '001',
#   'state': '05'},
#  {'NAME': 'Ashley County',
#   'P0010001': '21853',
#   'county': '003',
#   'state': '05'},
#  {'NAME': 'Baxter County',
#   'P0010001': '41513',
#   'county': '005',
#   'state': '05'},
#  {'NAME': 'Benton County',
#   'P0010001': '221339',
#   'county': '007',
#   'state': '05'},
#  {'NAME': 'Boone County', 'P0010001': '36903', 'county': '009', 'state': '05'},
#  {'NAME': 'Bradley County',
#   'P0010001': '11508',
#   'county': '011',
#   'state': '05'},
#  {'NAME': 'Calhoun County',
#   'P0010001': '5368',
#   'county': '013',
#   'state': '05'},
#  {'NAME': 'Carroll County',
#   'P0010001': '27446',
#   'county': '015',
#   'state': '05'},
#  {'NAME': 'Chicot County',
#   'P0010001': '11800',
#   'county': '017',
#   'state': '05'},
#  {'NAME': 'Clark County', 'P0010001': '22995', 'county': '019', 'state': '05'},
#  {'NAME': 'Clay County', 'P0010001': '16083', 'county': '021', 'state': '05'},
#  {'NAME': 'Cleburne County',
#   'P0010001': '25970',
#   'county': '023',
#   'state': '05'},
#  {'NAME': 'Cleveland County',
#   'P0010001': '8689',
#   'county': '025',
#   'state': '05'},
#  {'NAME': 'Columbia County',
#   'P0010001': '24552',
#   'county': '027',
#   'state': '05'},
#  {'NAME': 'Conway County',
#   'P0010001': '21273',
#   'county': '029',
#   'state': '05'},
#  {'NAME': 'Craighead County',
#   'P0010001': '96443',
#   'county': '031',
#   'state': '05'},
#  {'NAME': 'Crawford County',
#   'P0010001': '61948',
#   'county': '033',
#   'state': '05'},
#  {'NAME': 'Crittenden County',
#   'P0010001': '50902',
#   'county': '035',
#   'state': '05'},
#  {'NAME': 'Cross County', 'P0010001': '17870', 'county': '037', 'state': '05'},
#  {'NAME': 'Dallas County', 'P0010001': '8116', 'county': '039', 'state': '05'},
#  {'NAME': 'Desha County', 'P0010001': '13008', 'county': '041', 'state': '05'},
#  {'NAME': 'Drew County', 'P0010001': '18509', 'county': '043', 'state': '05'},
#  {'NAME': 'Faulkner County',
#   'P0010001': '113237',
#   'county': '045',
#   'state': '05'},
#  {'NAME': 'Franklin County',
#   'P0010001': '18125',
#   'county': '047',
#   'state': '05'},
#  {'NAME': 'Fulton County',
#   'P0010001': '12245',
#   'county': '049',
#   'state': '05'},
#  {'NAME': 'Garland County',
#   'P0010001': '96024',
#   'county': '051',
#   'state': '05'},
#  {'NAME': 'Grant County', 'P0010001': '17853', 'county': '053', 'state': '05'},
#  {'NAME': 'Greene County',
#   'P0010001': '42090',
#   'county': '055',
#   'state': '05'},
#  {'NAME': 'Hempstead County',
#   'P0010001': '22609',
#   'county': '057',
#   'state': '05'},
#  {'NAME': 'Hot Spring County',
#   'P0010001': '32923',
#   'county': '059',
#   'state': '05'},
#  {'NAME': 'Howard County',
#   'P0010001': '13789',
#   'county': '061',
#   'state': '05'},
#  {'NAME': 'Independence County',
#   'P0010001': '36647',
#   'county': '063',
#   'state': '05'},
#  {'NAME': 'Izard County', 'P0010001': '13696', 'county': '065', 'state': '05'},
#  {'NAME': 'Jackson County',
#   'P0010001': '17997',
#   'county': '067',
#   'state': '05'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '77435',
#   'county': '069',
#   'state': '05'},
#  {'NAME': 'Johnson County',
#   'P0010001': '25540',
#   'county': '071',
#   'state': '05'},
#  {'NAME': 'Lafayette County',
#   'P0010001': '7645',
#   'county': '073',
#   'state': '05'},
#  {'NAME': 'Lawrence County',
#   'P0010001': '17415',
#   'county': '075',
#   'state': '05'},
#  {'NAME': 'Lee County', 'P0010001': '10424', 'county': '077', 'state': '05'},
#  {'NAME': 'Lincoln County',
#   'P0010001': '14134',
#   'county': '079',
#   'state': '05'},
#  {'NAME': 'Little River County',
#   'P0010001': '13171',
#   'county': '081',
#   'state': '05'},
#  {'NAME': 'Logan County', 'P0010001': '22353', 'county': '083', 'state': '05'},
#  {'NAME': 'Lonoke County',
#   'P0010001': '68356',
#   'county': '085',
#   'state': '05'},
#  {'NAME': 'Madison County',
#   'P0010001': '15717',
#   'county': '087',
#   'state': '05'},
#  {'NAME': 'Marion County',
#   'P0010001': '16653',
#   'county': '089',
#   'state': '05'},
#  {'NAME': 'Miller County',
#   'P0010001': '43462',
#   'county': '091',
#   'state': '05'},
#  {'NAME': 'Mississippi County',
#   'P0010001': '46480',
#   'county': '093',
#   'state': '05'},
#  {'NAME': 'Monroe County', 'P0010001': '8149', 'county': '095', 'state': '05'},
#  {'NAME': 'Montgomery County',
#   'P0010001': '9487',
#   'county': '097',
#   'state': '05'},
#  {'NAME': 'Nevada County', 'P0010001': '8997', 'county': '099', 'state': '05'},
#  {'NAME': 'Newton County', 'P0010001': '8330', 'county': '101', 'state': '05'},
#  {'NAME': 'Ouachita County',
#   'P0010001': '26120',
#   'county': '103',
#   'state': '05'},
#  {'NAME': 'Perry County', 'P0010001': '10445', 'county': '105', 'state': '05'},
#  {'NAME': 'Phillips County',
#   'P0010001': '21757',
#   'county': '107',
#   'state': '05'},
#  {'NAME': 'Pike County', 'P0010001': '11291', 'county': '109', 'state': '05'},
#  {'NAME': 'Poinsett County',
#   'P0010001': '24583',
#   'county': '111',
#   'state': '05'},
#  {'NAME': 'Polk County', 'P0010001': '20662', 'county': '113', 'state': '05'},
#  {'NAME': 'Pope County', 'P0010001': '61754', 'county': '115', 'state': '05'},
#  {'NAME': 'Prairie County',
#   'P0010001': '8715',
#   'county': '117',
#   'state': '05'},
#  {'NAME': 'Pulaski County',
#   'P0010001': '382748',
#   'county': '119',
#   'state': '05'},
#  {'NAME': 'Randolph County',
#   'P0010001': '17969',
#   'county': '121',
#   'state': '05'},
#  {'NAME': 'St. Francis County',
#   'P0010001': '28258',
#   'county': '123',
#   'state': '05'},
#  {'NAME': 'Saline County',
#   'P0010001': '107118',
#   'county': '125',
#   'state': '05'},
#  {'NAME': 'Scott County', 'P0010001': '11233', 'county': '127', 'state': '05'},
#  {'NAME': 'Searcy County', 'P0010001': '8195', 'county': '129', 'state': '05'},
#  {'NAME': 'Sebastian County',
#   'P0010001': '125744',
#   'county': '131',
#   'state': '05'},
#  {'NAME': 'Sevier County',
#   'P0010001': '17058',
#   'county': '133',
#   'state': '05'},
#  {'NAME': 'Sharp County', 'P0010001': '17264', 'county': '135', 'state': '05'},
#  {'NAME': 'Stone County', 'P0010001': '12394', 'county': '137', 'state': '05'},
#  {'NAME': 'Union County', 'P0010001': '41639', 'county': '139', 'state': '05'},
#  {'NAME': 'Van Buren County',
#   'P0010001': '17295',
#   'county': '141',
#   'state': '05'},
#  {'NAME': 'Washington County',
#   'P0010001': '203065',
#   'county': '143',
#   'state': '05'},
#  {'NAME': 'White County', 'P0010001': '77076', 'county': '145', 'state': '05'},
#  {'NAME': 'Woodruff County',
#   'P0010001': '7260',
#   'county': '147',
#   'state': '05'},
#  {'NAME': 'Yell County', 'P0010001': '22185', 'county': '149', 'state': '05'},
#  {'NAME': 'Alameda County',
#   'P0010001': '1510271',
#   'county': '001',
#   'state': '06'},
#  {'NAME': 'Alpine County', 'P0010001': '1175', 'county': '003', 'state': '06'},
#  {'NAME': 'Amador County',
#   'P0010001': '38091',
#   'county': '005',
#   'state': '06'},
#  {'NAME': 'Butte County',
#   'P0010001': '220000',
#   'county': '007',
#   'state': '06'},
#  {'NAME': 'Calaveras County',
#   'P0010001': '45578',
#   'county': '009',
#   'state': '06'},
#  {'NAME': 'Colusa County',
#   'P0010001': '21419',
#   'county': '011',
#   'state': '06'},
#  {'NAME': 'Contra Costa County',
#   'P0010001': '1049025',
#   'county': '013',
#   'state': '06'},
#  {'NAME': 'Del Norte County',
#   'P0010001': '28610',
#   'county': '015',
#   'state': '06'},
#  {'NAME': 'El Dorado County',
#   'P0010001': '181058',
#   'county': '017',
#   'state': '06'},
#  {'NAME': 'Fresno County',
#   'P0010001': '930450',
#   'county': '019',
#   'state': '06'},
#  {'NAME': 'Glenn County', 'P0010001': '28122', 'county': '021', 'state': '06'},
#  {'NAME': 'Humboldt County',
#   'P0010001': '134623',
#   'county': '023',
#   'state': '06'},
#  {'NAME': 'Imperial County',
#   'P0010001': '174528',
#   'county': '025',
#   'state': '06'},
#  {'NAME': 'Inyo County', 'P0010001': '18546', 'county': '027', 'state': '06'},
#  {'NAME': 'Kern County', 'P0010001': '839631', 'county': '029', 'state': '06'},
#  {'NAME': 'Kings County',
#   'P0010001': '152982',
#   'county': '031',
#   'state': '06'},
#  {'NAME': 'Lake County', 'P0010001': '64665', 'county': '033', 'state': '06'},
#  {'NAME': 'Lassen County',
#   'P0010001': '34895',
#   'county': '035',
#   'state': '06'},
#  {'NAME': 'Los Angeles County',
#   'P0010001': '9818605',
#   'county': '037',
#   'state': '06'},
#  {'NAME': 'Madera County',
#   'P0010001': '150865',
#   'county': '039',
#   'state': '06'},
#  {'NAME': 'Marin County',
#   'P0010001': '252409',
#   'county': '041',
#   'state': '06'},
#  {'NAME': 'Mariposa County',
#   'P0010001': '18251',
#   'county': '043',
#   'state': '06'},
#  {'NAME': 'Mendocino County',
#   'P0010001': '87841',
#   'county': '045',
#   'state': '06'},
#  {'NAME': 'Merced County',
#   'P0010001': '255793',
#   'county': '047',
#   'state': '06'},
#  {'NAME': 'Modoc County', 'P0010001': '9686', 'county': '049', 'state': '06'},
#  {'NAME': 'Mono County', 'P0010001': '14202', 'county': '051', 'state': '06'},
#  {'NAME': 'Monterey County',
#   'P0010001': '415057',
#   'county': '053',
#   'state': '06'},
#  {'NAME': 'Napa County', 'P0010001': '136484', 'county': '055', 'state': '06'},
#  {'NAME': 'Nevada County',
#   'P0010001': '98764',
#   'county': '057',
#   'state': '06'},
#  {'NAME': 'Orange County',
#   'P0010001': '3010232',
#   'county': '059',
#   'state': '06'},
#  {'NAME': 'Placer County',
#   'P0010001': '348432',
#   'county': '061',
#   'state': '06'},
#  {'NAME': 'Plumas County',
#   'P0010001': '20007',
#   'county': '063',
#   'state': '06'},
#  {'NAME': 'Riverside County',
#   'P0010001': '2189641',
#   'county': '065',
#   'state': '06'},
#  {'NAME': 'Sacramento County',
#   'P0010001': '1418788',
#   'county': '067',
#   'state': '06'},
#  {'NAME': 'San Benito County',
#   'P0010001': '55269',
#   'county': '069',
#   'state': '06'},
#  {'NAME': 'San Bernardino County',
#   'P0010001': '2035210',
#   'county': '071',
#   'state': '06'},
#  {'NAME': 'San Diego County',
#   'P0010001': '3095313',
#   'county': '073',
#   'state': '06'},
#  {'NAME': 'San Francisco County',
#   'P0010001': '805235',
#   'county': '075',
#   'state': '06'},
#  {'NAME': 'San Joaquin County',
#   'P0010001': '685306',
#   'county': '077',
#   'state': '06'},
#  {'NAME': 'San Luis Obispo County',
#   'P0010001': '269637',
#   'county': '079',
#   'state': '06'},
#  {'NAME': 'San Mateo County',
#   'P0010001': '718451',
#   'county': '081',
#   'state': '06'},
#  {'NAME': 'Santa Barbara County',
#   'P0010001': '423895',
#   'county': '083',
#   'state': '06'},
#  {'NAME': 'Santa Clara County',
#   'P0010001': '1781642',
#   'county': '085',
#   'state': '06'},
#  {'NAME': 'Santa Cruz County',
#   'P0010001': '262382',
#   'county': '087',
#   'state': '06'},
#  {'NAME': 'Shasta County',
#   'P0010001': '177223',
#   'county': '089',
#   'state': '06'},
#  {'NAME': 'Sierra County', 'P0010001': '3240', 'county': '091', 'state': '06'},
#  {'NAME': 'Siskiyou County',
#   'P0010001': '44900',
#   'county': '093',
#   'state': '06'},
#  {'NAME': 'Solano County',
#   'P0010001': '413344',
#   'county': '095',
#   'state': '06'},
#  {'NAME': 'Sonoma County',
#   'P0010001': '483878',
#   'county': '097',
#   'state': '06'},
#  {'NAME': 'Stanislaus County',
#   'P0010001': '514453',
#   'county': '099',
#   'state': '06'},
#  {'NAME': 'Sutter County',
#   'P0010001': '94737',
#   'county': '101',
#   'state': '06'},
#  {'NAME': 'Tehama County',
#   'P0010001': '63463',
#   'county': '103',
#   'state': '06'},
#  {'NAME': 'Trinity County',
#   'P0010001': '13786',
#   'county': '105',
#   'state': '06'},
#  {'NAME': 'Tulare County',
#   'P0010001': '442179',
#   'county': '107',
#   'state': '06'},
#  {'NAME': 'Tuolumne County',
#   'P0010001': '55365',
#   'county': '109',
#   'state': '06'},
#  {'NAME': 'Ventura County',
#   'P0010001': '823318',
#   'county': '111',
#   'state': '06'},
#  {'NAME': 'Yolo County', 'P0010001': '200849', 'county': '113', 'state': '06'},
#  {'NAME': 'Yuba County', 'P0010001': '72155', 'county': '115', 'state': '06'},
#  {'NAME': 'Adams County',
#   'P0010001': '441603',
#   'county': '001',
#   'state': '08'},
#  {'NAME': 'Alamosa County',
#   'P0010001': '15445',
#   'county': '003',
#   'state': '08'},
#  {'NAME': 'Arapahoe County',
#   'P0010001': '572003',
#   'county': '005',
#   'state': '08'},
#  {'NAME': 'Archuleta County',
#   'P0010001': '12084',
#   'county': '007',
#   'state': '08'},
#  {'NAME': 'Baca County', 'P0010001': '3788', 'county': '009', 'state': '08'},
#  {'NAME': 'Bent County', 'P0010001': '6499', 'county': '011', 'state': '08'},
#  {'NAME': 'Boulder County',
#   'P0010001': '294567',
#   'county': '013',
#   'state': '08'},
#  {'NAME': 'Broomfield County',
#   'P0010001': '55889',
#   'county': '014',
#   'state': '08'},
#  {'NAME': 'Chaffee County',
#   'P0010001': '17809',
#   'county': '015',
#   'state': '08'},
#  {'NAME': 'Cheyenne County',
#   'P0010001': '1836',
#   'county': '017',
#   'state': '08'},
#  {'NAME': 'Clear Creek County',
#   'P0010001': '9088',
#   'county': '019',
#   'state': '08'},
#  {'NAME': 'Conejos County',
#   'P0010001': '8256',
#   'county': '021',
#   'state': '08'},
#  {'NAME': 'Costilla County',
#   'P0010001': '3524',
#   'county': '023',
#   'state': '08'},
#  {'NAME': 'Crowley County',
#   'P0010001': '5823',
#   'county': '025',
#   'state': '08'},
#  {'NAME': 'Custer County', 'P0010001': '4255', 'county': '027', 'state': '08'},
#  {'NAME': 'Delta County', 'P0010001': '30952', 'county': '029', 'state': '08'},
#  {'NAME': 'Denver County',
#   'P0010001': '600158',
#   'county': '031',
#   'state': '08'},
#  {'NAME': 'Dolores County',
#   'P0010001': '2064',
#   'county': '033',
#   'state': '08'},
#  {'NAME': 'Douglas County',
#   'P0010001': '285465',
#   'county': '035',
#   'state': '08'},
#  {'NAME': 'Eagle County', 'P0010001': '52197', 'county': '037', 'state': '08'},
#  {'NAME': 'Elbert County',
#   'P0010001': '23086',
#   'county': '039',
#   'state': '08'},
#  {'NAME': 'El Paso County',
#   'P0010001': '622263',
#   'county': '041',
#   'state': '08'},
#  {'NAME': 'Fremont County',
#   'P0010001': '46824',
#   'county': '043',
#   'state': '08'},
#  {'NAME': 'Garfield County',
#   'P0010001': '56389',
#   'county': '045',
#   'state': '08'},
#  {'NAME': 'Gilpin County', 'P0010001': '5441', 'county': '047', 'state': '08'},
#  {'NAME': 'Grand County', 'P0010001': '14843', 'county': '049', 'state': '08'},
#  {'NAME': 'Gunnison County',
#   'P0010001': '15324',
#   'county': '051',
#   'state': '08'},
#  {'NAME': 'Hinsdale County',
#   'P0010001': '843',
#   'county': '053',
#   'state': '08'},
#  {'NAME': 'Huerfano County',
#   'P0010001': '6711',
#   'county': '055',
#   'state': '08'},
#  {'NAME': 'Jackson County',
#   'P0010001': '1394',
#   'county': '057',
#   'state': '08'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '534543',
#   'county': '059',
#   'state': '08'},
#  {'NAME': 'Kiowa County', 'P0010001': '1398', 'county': '061', 'state': '08'},
#  {'NAME': 'Kit Carson County',
#   'P0010001': '8270',
#   'county': '063',
#   'state': '08'},
#  {'NAME': 'Lake County', 'P0010001': '7310', 'county': '065', 'state': '08'},
#  {'NAME': 'La Plata County',
#   'P0010001': '51334',
#   'county': '067',
#   'state': '08'},
#  {'NAME': 'Larimer County',
#   'P0010001': '299630',
#   'county': '069',
#   'state': '08'},
#  {'NAME': 'Las Animas County',
#   'P0010001': '15507',
#   'county': '071',
#   'state': '08'},
#  {'NAME': 'Lincoln County',
#   'P0010001': '5467',
#   'county': '073',
#   'state': '08'},
#  {'NAME': 'Logan County', 'P0010001': '22709', 'county': '075', 'state': '08'},
#  {'NAME': 'Mesa County', 'P0010001': '146723', 'county': '077', 'state': '08'},
#  {'NAME': 'Mineral County', 'P0010001': '712', 'county': '079', 'state': '08'},
#  {'NAME': 'Moffat County',
#   'P0010001': '13795',
#   'county': '081',
#   'state': '08'},
#  {'NAME': 'Montezuma County',
#   'P0010001': '25535',
#   'county': '083',
#   'state': '08'},
#  {'NAME': 'Montrose County',
#   'P0010001': '41276',
#   'county': '085',
#   'state': '08'},
#  {'NAME': 'Morgan County',
#   'P0010001': '28159',
#   'county': '087',
#   'state': '08'},
#  {'NAME': 'Otero County', 'P0010001': '18831', 'county': '089', 'state': '08'},
#  {'NAME': 'Ouray County', 'P0010001': '4436', 'county': '091', 'state': '08'},
#  {'NAME': 'Park County', 'P0010001': '16206', 'county': '093', 'state': '08'},
#  {'NAME': 'Phillips County',
#   'P0010001': '4442',
#   'county': '095',
#   'state': '08'},
#  {'NAME': 'Pitkin County',
#   'P0010001': '17148',
#   'county': '097',
#   'state': '08'},
#  {'NAME': 'Prowers County',
#   'P0010001': '12551',
#   'county': '099',
#   'state': '08'},
#  {'NAME': 'Pueblo County',
#   'P0010001': '159063',
#   'county': '101',
#   'state': '08'},
#  {'NAME': 'Rio Blanco County',
#   'P0010001': '6666',
#   'county': '103',
#   'state': '08'},
#  {'NAME': 'Rio Grande County',
#   'P0010001': '11982',
#   'county': '105',
#   'state': '08'},
#  {'NAME': 'Routt County', 'P0010001': '23509', 'county': '107', 'state': '08'},
#  {'NAME': 'Saguache County',
#   'P0010001': '6108',
#   'county': '109',
#   'state': '08'},
#  {'NAME': 'San Juan County',
#   'P0010001': '699',
#   'county': '111',
#   'state': '08'},
#  {'NAME': 'San Miguel County',
#   'P0010001': '7359',
#   'county': '113',
#   'state': '08'},
#  {'NAME': 'Sedgwick County',
#   'P0010001': '2379',
#   'county': '115',
#   'state': '08'},
#  {'NAME': 'Summit County',
#   'P0010001': '27994',
#   'county': '117',
#   'state': '08'},
#  {'NAME': 'Teller County',
#   'P0010001': '23350',
#   'county': '119',
#   'state': '08'},
#  {'NAME': 'Washington County',
#   'P0010001': '4814',
#   'county': '121',
#   'state': '08'},
#  {'NAME': 'Weld County', 'P0010001': '252825', 'county': '123', 'state': '08'},
#  {'NAME': 'Yuma County', 'P0010001': '10043', 'county': '125', 'state': '08'},
#  {'NAME': 'Fairfield County',
#   'P0010001': '916829',
#   'county': '001',
#   'state': '09'},
#  {'NAME': 'Hartford County',
#   'P0010001': '894014',
#   'county': '003',
#   'state': '09'},
#  {'NAME': 'Litchfield County',
#   'P0010001': '189927',
#   'county': '005',
#   'state': '09'},
#  {'NAME': 'Middlesex County',
#   'P0010001': '165676',
#   'county': '007',
#   'state': '09'},
#  {'NAME': 'New Haven County',
#   'P0010001': '862477',
#   'county': '009',
#   'state': '09'},
#  {'NAME': 'New London County',
#   'P0010001': '274055',
#   'county': '011',
#   'state': '09'},
#  {'NAME': 'Tolland County',
#   'P0010001': '152691',
#   'county': '013',
#   'state': '09'},
#  {'NAME': 'Windham County',
#   'P0010001': '118428',
#   'county': '015',
#   'state': '09'},
#  {'NAME': 'Kent County', 'P0010001': '162310', 'county': '001', 'state': '10'},
#  {'NAME': 'New Castle County',
#   'P0010001': '538479',
#   'county': '003',
#   'state': '10'},
#  {'NAME': 'Sussex County',
#   'P0010001': '197145',
#   'county': '005',
#   'state': '10'},
#  {'NAME': 'District of Columbia',
#   'P0010001': '601723',
#   'county': '001',
#   'state': '11'},
#  {'NAME': 'Alachua County',
#   'P0010001': '247336',
#   'county': '001',
#   'state': '12'},
#  {'NAME': 'Baker County', 'P0010001': '27115', 'county': '003', 'state': '12'},
#  {'NAME': 'Bay County', 'P0010001': '168852', 'county': '005', 'state': '12'},
#  {'NAME': 'Bradford County',
#   'P0010001': '28520',
#   'county': '007',
#   'state': '12'},
#  {'NAME': 'Brevard County',
#   'P0010001': '543376',
#   'county': '009',
#   'state': '12'},
#  {'NAME': 'Broward County',
#   'P0010001': '1748066',
#   'county': '011',
#   'state': '12'},
#  {'NAME': 'Calhoun County',
#   'P0010001': '14625',
#   'county': '013',
#   'state': '12'},
#  {'NAME': 'Charlotte County',
#   'P0010001': '159978',
#   'county': '015',
#   'state': '12'},
#  {'NAME': 'Citrus County',
#   'P0010001': '141236',
#   'county': '017',
#   'state': '12'},
#  {'NAME': 'Clay County', 'P0010001': '190865', 'county': '019', 'state': '12'},
#  {'NAME': 'Collier County',
#   'P0010001': '321520',
#   'county': '021',
#   'state': '12'},
#  {'NAME': 'Columbia County',
#   'P0010001': '67531',
#   'county': '023',
#   'state': '12'},
#  {'NAME': 'DeSoto County',
#   'P0010001': '34862',
#   'county': '027',
#   'state': '12'},
#  {'NAME': 'Dixie County', 'P0010001': '16422', 'county': '029', 'state': '12'},
#  {'NAME': 'Duval County',
#   'P0010001': '864263',
#   'county': '031',
#   'state': '12'},
#  {'NAME': 'Escambia County',
#   'P0010001': '297619',
#   'county': '033',
#   'state': '12'},
#  {'NAME': 'Flagler County',
#   'P0010001': '95696',
#   'county': '035',
#   'state': '12'},
#  {'NAME': 'Franklin County',
#   'P0010001': '11549',
#   'county': '037',
#   'state': '12'},
#  {'NAME': 'Gadsden County',
#   'P0010001': '46389',
#   'county': '039',
#   'state': '12'},
#  {'NAME': 'Gilchrist County',
#   'P0010001': '16939',
#   'county': '041',
#   'state': '12'},
#  {'NAME': 'Glades County',
#   'P0010001': '12884',
#   'county': '043',
#   'state': '12'},
#  {'NAME': 'Gulf County', 'P0010001': '15863', 'county': '045', 'state': '12'},
#  {'NAME': 'Hamilton County',
#   'P0010001': '14799',
#   'county': '047',
#   'state': '12'},
#  {'NAME': 'Hardee County',
#   'P0010001': '27731',
#   'county': '049',
#   'state': '12'},
#  {'NAME': 'Hendry County',
#   'P0010001': '39140',
#   'county': '051',
#   'state': '12'},
#  {'NAME': 'Hernando County',
#   'P0010001': '172778',
#   'county': '053',
#   'state': '12'},
#  {'NAME': 'Highlands County',
#   'P0010001': '98786',
#   'county': '055',
#   'state': '12'},
#  {'NAME': 'Hillsborough County',
#   'P0010001': '1229226',
#   'county': '057',
#   'state': '12'},
#  {'NAME': 'Holmes County',
#   'P0010001': '19927',
#   'county': '059',
#   'state': '12'},
#  {'NAME': 'Indian River County',
#   'P0010001': '138028',
#   'county': '061',
#   'state': '12'},
#  {'NAME': 'Jackson County',
#   'P0010001': '49746',
#   'county': '063',
#   'state': '12'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '14761',
#   'county': '065',
#   'state': '12'},
#  {'NAME': 'Lafayette County',
#   'P0010001': '8870',
#   'county': '067',
#   'state': '12'},
#  {'NAME': 'Lake County', 'P0010001': '297052', 'county': '069', 'state': '12'},
#  {'NAME': 'Lee County', 'P0010001': '618754', 'county': '071', 'state': '12'},
#  {'NAME': 'Leon County', 'P0010001': '275487', 'county': '073', 'state': '12'},
#  {'NAME': 'Levy County', 'P0010001': '40801', 'county': '075', 'state': '12'},
#  {'NAME': 'Liberty County',
#   'P0010001': '8365',
#   'county': '077',
#   'state': '12'},
#  {'NAME': 'Madison County',
#   'P0010001': '19224',
#   'county': '079',
#   'state': '12'},
#  {'NAME': 'Manatee County',
#   'P0010001': '322833',
#   'county': '081',
#   'state': '12'},
#  {'NAME': 'Marion County',
#   'P0010001': '331298',
#   'county': '083',
#   'state': '12'},
#  {'NAME': 'Martin County',
#   'P0010001': '146318',
#   'county': '085',
#   'state': '12'},
#  {'NAME': 'Miami-Dade County',
#   'P0010001': '2496435',
#   'county': '086',
#   'state': '12'},
#  {'NAME': 'Monroe County',
#   'P0010001': '73090',
#   'county': '087',
#   'state': '12'},
#  {'NAME': 'Nassau County',
#   'P0010001': '73314',
#   'county': '089',
#   'state': '12'},
#  {'NAME': 'Okaloosa County',
#   'P0010001': '180822',
#   'county': '091',
#   'state': '12'},
#  {'NAME': 'Okeechobee County',
#   'P0010001': '39996',
#   'county': '093',
#   'state': '12'},
#  {'NAME': 'Orange County',
#   'P0010001': '1145956',
#   'county': '095',
#   'state': '12'},
#  {'NAME': 'Osceola County',
#   'P0010001': '268685',
#   'county': '097',
#   'state': '12'},
#  {'NAME': 'Palm Beach County',
#   'P0010001': '1320134',
#   'county': '099',
#   'state': '12'},
#  {'NAME': 'Pasco County',
#   'P0010001': '464697',
#   'county': '101',
#   'state': '12'},
#  {'NAME': 'Pinellas County',
#   'P0010001': '916542',
#   'county': '103',
#   'state': '12'},
#  {'NAME': 'Polk County', 'P0010001': '602095', 'county': '105', 'state': '12'},
#  {'NAME': 'Putnam County',
#   'P0010001': '74364',
#   'county': '107',
#   'state': '12'},
#  {'NAME': 'St. Johns County',
#   'P0010001': '190039',
#   'county': '109',
#   'state': '12'},
#  {'NAME': 'St. Lucie County',
#   'P0010001': '277789',
#   'county': '111',
#   'state': '12'},
#  {'NAME': 'Santa Rosa County',
#   'P0010001': '151372',
#   'county': '113',
#   'state': '12'},
#  {'NAME': 'Sarasota County',
#   'P0010001': '379448',
#   'county': '115',
#   'state': '12'},
#  {'NAME': 'Seminole County',
#   'P0010001': '422718',
#   'county': '117',
#   'state': '12'},
#  {'NAME': 'Sumter County',
#   'P0010001': '93420',
#   'county': '119',
#   'state': '12'},
#  {'NAME': 'Suwannee County',
#   'P0010001': '41551',
#   'county': '121',
#   'state': '12'},
#  {'NAME': 'Taylor County',
#   'P0010001': '22570',
#   'county': '123',
#   'state': '12'},
#  {'NAME': 'Union County', 'P0010001': '15535', 'county': '125', 'state': '12'},
#  {'NAME': 'Volusia County',
#   'P0010001': '494593',
#   'county': '127',
#   'state': '12'},
#  {'NAME': 'Wakulla County',
#   'P0010001': '30776',
#   'county': '129',
#   'state': '12'},
#  {'NAME': 'Walton County',
#   'P0010001': '55043',
#   'county': '131',
#   'state': '12'},
#  {'NAME': 'Washington County',
#   'P0010001': '24896',
#   'county': '133',
#   'state': '12'},
#  {'NAME': 'Appling County',
#   'P0010001': '18236',
#   'county': '001',
#   'state': '13'},
#  {'NAME': 'Atkinson County',
#   'P0010001': '8375',
#   'county': '003',
#   'state': '13'},
#  {'NAME': 'Bacon County', 'P0010001': '11096', 'county': '005', 'state': '13'},
#  {'NAME': 'Baker County', 'P0010001': '3451', 'county': '007', 'state': '13'},
#  {'NAME': 'Baldwin County',
#   'P0010001': '45720',
#   'county': '009',
#   'state': '13'},
#  {'NAME': 'Banks County', 'P0010001': '18395', 'county': '011', 'state': '13'},
#  {'NAME': 'Barrow County',
#   'P0010001': '69367',
#   'county': '013',
#   'state': '13'},
#  {'NAME': 'Bartow County',
#   'P0010001': '100157',
#   'county': '015',
#   'state': '13'},
#  {'NAME': 'Ben Hill County',
#   'P0010001': '17634',
#   'county': '017',
#   'state': '13'},
#  {'NAME': 'Berrien County',
#   'P0010001': '19286',
#   'county': '019',
#   'state': '13'},
#  {'NAME': 'Bibb County', 'P0010001': '155547', 'county': '021', 'state': '13'},
#  {'NAME': 'Bleckley County',
#   'P0010001': '13063',
#   'county': '023',
#   'state': '13'},
#  {'NAME': 'Brantley County',
#   'P0010001': '18411',
#   'county': '025',
#   'state': '13'},
#  {'NAME': 'Brooks County',
#   'P0010001': '16243',
#   'county': '027',
#   'state': '13'},
#  {'NAME': 'Bryan County', 'P0010001': '30233', 'county': '029', 'state': '13'},
#  {'NAME': 'Bulloch County',
#   'P0010001': '70217',
#   'county': '031',
#   'state': '13'},
#  {'NAME': 'Burke County', 'P0010001': '23316', 'county': '033', 'state': '13'},
#  {'NAME': 'Butts County', 'P0010001': '23655', 'county': '035', 'state': '13'},
#  {'NAME': 'Calhoun County',
#   'P0010001': '6694',
#   'county': '037',
#   'state': '13'},
#  {'NAME': 'Camden County',
#   'P0010001': '50513',
#   'county': '039',
#   'state': '13'},
#  {'NAME': 'Candler County',
#   'P0010001': '10998',
#   'county': '043',
#   'state': '13'},
#  {'NAME': 'Carroll County',
#   'P0010001': '110527',
#   'county': '045',
#   'state': '13'},
#  {'NAME': 'Catoosa County',
#   'P0010001': '63942',
#   'county': '047',
#   'state': '13'},
#  {'NAME': 'Charlton County',
#   'P0010001': '12171',
#   'county': '049',
#   'state': '13'},
#  {'NAME': 'Chatham County',
#   'P0010001': '265128',
#   'county': '051',
#   'state': '13'},
#  {'NAME': 'Chattahoochee County',
#   'P0010001': '11267',
#   'county': '053',
#   'state': '13'},
#  {'NAME': 'Chattooga County',
#   'P0010001': '26015',
#   'county': '055',
#   'state': '13'},
#  {'NAME': 'Cherokee County',
#   'P0010001': '214346',
#   'county': '057',
#   'state': '13'},
#  {'NAME': 'Clarke County',
#   'P0010001': '116714',
#   'county': '059',
#   'state': '13'},
#  {'NAME': 'Clay County', 'P0010001': '3183', 'county': '061', 'state': '13'},
#  {'NAME': 'Clayton County',
#   'P0010001': '259424',
#   'county': '063',
#   'state': '13'},
#  {'NAME': 'Clinch County', 'P0010001': '6798', 'county': '065', 'state': '13'},
#  {'NAME': 'Cobb County', 'P0010001': '688078', 'county': '067', 'state': '13'},
#  {'NAME': 'Coffee County',
#   'P0010001': '42356',
#   'county': '069',
#   'state': '13'},
#  {'NAME': 'Colquitt County',
#   'P0010001': '45498',
#   'county': '071',
#   'state': '13'},
#  {'NAME': 'Columbia County',
#   'P0010001': '124053',
#   'county': '073',
#   'state': '13'},
#  {'NAME': 'Cook County', 'P0010001': '17212', 'county': '075', 'state': '13'},
#  {'NAME': 'Coweta County',
#   'P0010001': '127317',
#   'county': '077',
#   'state': '13'},
#  {'NAME': 'Crawford County',
#   'P0010001': '12630',
#   'county': '079',
#   'state': '13'},
#  {'NAME': 'Crisp County', 'P0010001': '23439', 'county': '081', 'state': '13'},
#  {'NAME': 'Dade County', 'P0010001': '16633', 'county': '083', 'state': '13'},
#  {'NAME': 'Dawson County',
#   'P0010001': '22330',
#   'county': '085',
#   'state': '13'},
#  {'NAME': 'Decatur County',
#   'P0010001': '27842',
#   'county': '087',
#   'state': '13'},
#  {'NAME': 'DeKalb County',
#   'P0010001': '691893',
#   'county': '089',
#   'state': '13'},
#  {'NAME': 'Dodge County', 'P0010001': '21796', 'county': '091', 'state': '13'},
#  {'NAME': 'Dooly County', 'P0010001': '14918', 'county': '093', 'state': '13'},
#  {'NAME': 'Dougherty County',
#   'P0010001': '94565',
#   'county': '095',
#   'state': '13'},
#  {'NAME': 'Douglas County',
#   'P0010001': '132403',
#   'county': '097',
#   'state': '13'},
#  {'NAME': 'Early County', 'P0010001': '11008', 'county': '099', 'state': '13'},
#  {'NAME': 'Echols County', 'P0010001': '4034', 'county': '101', 'state': '13'},
#  {'NAME': 'Effingham County',
#   'P0010001': '52250',
#   'county': '103',
#   'state': '13'},
#  {'NAME': 'Elbert County',
#   'P0010001': '20166',
#   'county': '105',
#   'state': '13'},
#  {'NAME': 'Emanuel County',
#   'P0010001': '22598',
#   'county': '107',
#   'state': '13'},
#  {'NAME': 'Evans County', 'P0010001': '11000', 'county': '109', 'state': '13'},
#  {'NAME': 'Fannin County',
#   'P0010001': '23682',
#   'county': '111',
#   'state': '13'},
#  {'NAME': 'Fayette County',
#   'P0010001': '106567',
#   'county': '113',
#   'state': '13'},
#  {'NAME': 'Floyd County', 'P0010001': '96317', 'county': '115', 'state': '13'},
#  {'NAME': 'Forsyth County',
#   'P0010001': '175511',
#   'county': '117',
#   'state': '13'},
#  {'NAME': 'Franklin County',
#   'P0010001': '22084',
#   'county': '119',
#   'state': '13'},
#  {'NAME': 'Fulton County',
#   'P0010001': '920581',
#   'county': '121',
#   'state': '13'},
#  {'NAME': 'Gilmer County',
#   'P0010001': '28292',
#   'county': '123',
#   'state': '13'},
#  {'NAME': 'Glascock County',
#   'P0010001': '3082',
#   'county': '125',
#   'state': '13'},
#  {'NAME': 'Glynn County', 'P0010001': '79626', 'county': '127', 'state': '13'},
#  {'NAME': 'Gordon County',
#   'P0010001': '55186',
#   'county': '129',
#   'state': '13'},
#  {'NAME': 'Grady County', 'P0010001': '25011', 'county': '131', 'state': '13'},
#  {'NAME': 'Greene County',
#   'P0010001': '15994',
#   'county': '133',
#   'state': '13'},
#  {'NAME': 'Gwinnett County',
#   'P0010001': '805321',
#   'county': '135',
#   'state': '13'},
#  {'NAME': 'Habersham County',
#   'P0010001': '43041',
#   'county': '137',
#   'state': '13'},
#  {'NAME': 'Hall County', 'P0010001': '179684', 'county': '139', 'state': '13'},
#  {'NAME': 'Hancock County',
#   'P0010001': '9429',
#   'county': '141',
#   'state': '13'},
#  {'NAME': 'Haralson County',
#   'P0010001': '28780',
#   'county': '143',
#   'state': '13'},
#  {'NAME': 'Harris County',
#   'P0010001': '32024',
#   'county': '145',
#   'state': '13'},
#  {'NAME': 'Hart County', 'P0010001': '25213', 'county': '147', 'state': '13'},
#  {'NAME': 'Heard County', 'P0010001': '11834', 'county': '149', 'state': '13'},
#  {'NAME': 'Henry County',
#   'P0010001': '203922',
#   'county': '151',
#   'state': '13'},
#  {'NAME': 'Houston County',
#   'P0010001': '139900',
#   'county': '153',
#   'state': '13'},
#  {'NAME': 'Irwin County', 'P0010001': '9538', 'county': '155', 'state': '13'},
#  {'NAME': 'Jackson County',
#   'P0010001': '60485',
#   'county': '157',
#   'state': '13'},
#  {'NAME': 'Jasper County',
#   'P0010001': '13900',
#   'county': '159',
#   'state': '13'},
#  {'NAME': 'Jeff Davis County',
#   'P0010001': '15068',
#   'county': '161',
#   'state': '13'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '16930',
#   'county': '163',
#   'state': '13'},
#  {'NAME': 'Jenkins County',
#   'P0010001': '8340',
#   'county': '165',
#   'state': '13'},
#  {'NAME': 'Johnson County',
#   'P0010001': '9980',
#   'county': '167',
#   'state': '13'},
#  {'NAME': 'Jones County', 'P0010001': '28669', 'county': '169', 'state': '13'},
#  {'NAME': 'Lamar County', 'P0010001': '18317', 'county': '171', 'state': '13'},
#  {'NAME': 'Lanier County',
#   'P0010001': '10078',
#   'county': '173',
#   'state': '13'},
#  {'NAME': 'Laurens County',
#   'P0010001': '48434',
#   'county': '175',
#   'state': '13'},
#  {'NAME': 'Lee County', 'P0010001': '28298', 'county': '177', 'state': '13'},
#  {'NAME': 'Liberty County',
#   'P0010001': '63453',
#   'county': '179',
#   'state': '13'},
#  {'NAME': 'Lincoln County',
#   'P0010001': '7996',
#   'county': '181',
#   'state': '13'},
#  {'NAME': 'Long County', 'P0010001': '14464', 'county': '183', 'state': '13'},
#  {'NAME': 'Lowndes County',
#   'P0010001': '109233',
#   'county': '185',
#   'state': '13'},
#  {'NAME': 'Lumpkin County',
#   'P0010001': '29966',
#   'county': '187',
#   'state': '13'},
#  {'NAME': 'McDuffie County',
#   'P0010001': '21875',
#   'county': '189',
#   'state': '13'},
#  {'NAME': 'McIntosh County',
#   'P0010001': '14333',
#   'county': '191',
#   'state': '13'},
#  {'NAME': 'Macon County', 'P0010001': '14740', 'county': '193', 'state': '13'},
#  {'NAME': 'Madison County',
#   'P0010001': '28120',
#   'county': '195',
#   'state': '13'},
#  {'NAME': 'Marion County', 'P0010001': '8742', 'county': '197', 'state': '13'},
#  {'NAME': 'Meriwether County',
#   'P0010001': '21992',
#   'county': '199',
#   'state': '13'},
#  {'NAME': 'Miller County', 'P0010001': '6125', 'county': '201', 'state': '13'},
#  {'NAME': 'Mitchell County',
#   'P0010001': '23498',
#   'county': '205',
#   'state': '13'},
#  {'NAME': 'Monroe County',
#   'P0010001': '26424',
#   'county': '207',
#   'state': '13'},
#  {'NAME': 'Montgomery County',
#   'P0010001': '9123',
#   'county': '209',
#   'state': '13'},
#  {'NAME': 'Morgan County',
#   'P0010001': '17868',
#   'county': '211',
#   'state': '13'},
#  {'NAME': 'Murray County',
#   'P0010001': '39628',
#   'county': '213',
#   'state': '13'},
#  {'NAME': 'Muscogee County',
#   'P0010001': '189885',
#   'county': '215',
#   'state': '13'},
#  {'NAME': 'Newton County',
#   'P0010001': '99958',
#   'county': '217',
#   'state': '13'},
#  {'NAME': 'Oconee County',
#   'P0010001': '32808',
#   'county': '219',
#   'state': '13'},
#  {'NAME': 'Oglethorpe County',
#   'P0010001': '14899',
#   'county': '221',
#   'state': '13'},
#  {'NAME': 'Paulding County',
#   'P0010001': '142324',
#   'county': '223',
#   'state': '13'},
#  {'NAME': 'Peach County', 'P0010001': '27695', 'county': '225', 'state': '13'},
#  {'NAME': 'Pickens County',
#   'P0010001': '29431',
#   'county': '227',
#   'state': '13'},
#  {'NAME': 'Pierce County',
#   'P0010001': '18758',
#   'county': '229',
#   'state': '13'},
#  {'NAME': 'Pike County', 'P0010001': '17869', 'county': '231', 'state': '13'},
#  {'NAME': 'Polk County', 'P0010001': '41475', 'county': '233', 'state': '13'},
#  {'NAME': 'Pulaski County',
#   'P0010001': '12010',
#   'county': '235',
#   'state': '13'},
#  {'NAME': 'Putnam County',
#   'P0010001': '21218',
#   'county': '237',
#   'state': '13'},
#  {'NAME': 'Quitman County',
#   'P0010001': '2513',
#   'county': '239',
#   'state': '13'},
#  {'NAME': 'Rabun County', 'P0010001': '16276', 'county': '241', 'state': '13'},
#  {'NAME': 'Randolph County',
#   'P0010001': '7719',
#   'county': '243',
#   'state': '13'},
#  {'NAME': 'Richmond County',
#   'P0010001': '200549',
#   'county': '245',
#   'state': '13'},
#  {'NAME': 'Rockdale County',
#   'P0010001': '85215',
#   'county': '247',
#   'state': '13'},
#  {'NAME': 'Schley County', 'P0010001': '5010', 'county': '249', 'state': '13'},
#  {'NAME': 'Screven County',
#   'P0010001': '14593',
#   'county': '251',
#   'state': '13'},
#  {'NAME': 'Seminole County',
#   'P0010001': '8729',
#   'county': '253',
#   'state': '13'},
#  {'NAME': 'Spalding County',
#   'P0010001': '64073',
#   'county': '255',
#   'state': '13'},
#  {'NAME': 'Stephens County',
#   'P0010001': '26175',
#   'county': '257',
#   'state': '13'},
#  {'NAME': 'Stewart County',
#   'P0010001': '6058',
#   'county': '259',
#   'state': '13'},
#  {'NAME': 'Sumter County',
#   'P0010001': '32819',
#   'county': '261',
#   'state': '13'},
#  {'NAME': 'Talbot County', 'P0010001': '6865', 'county': '263', 'state': '13'},
#  {'NAME': 'Taliaferro County',
#   'P0010001': '1717',
#   'county': '265',
#   'state': '13'},
#  {'NAME': 'Tattnall County',
#   'P0010001': '25520',
#   'county': '267',
#   'state': '13'},
#  {'NAME': 'Taylor County', 'P0010001': '8906', 'county': '269', 'state': '13'},
#  {'NAME': 'Telfair County',
#   'P0010001': '16500',
#   'county': '271',
#   'state': '13'},
#  {'NAME': 'Terrell County',
#   'P0010001': '9315',
#   'county': '273',
#   'state': '13'},
#  {'NAME': 'Thomas County',
#   'P0010001': '44720',
#   'county': '275',
#   'state': '13'},
#  {'NAME': 'Tift County', 'P0010001': '40118', 'county': '277', 'state': '13'},
#  {'NAME': 'Toombs County',
#   'P0010001': '27223',
#   'county': '279',
#   'state': '13'},
#  {'NAME': 'Towns County', 'P0010001': '10471', 'county': '281', 'state': '13'},
#  {'NAME': 'Treutlen County',
#   'P0010001': '6885',
#   'county': '283',
#   'state': '13'},
#  {'NAME': 'Troup County', 'P0010001': '67044', 'county': '285', 'state': '13'},
#  {'NAME': 'Turner County', 'P0010001': '8930', 'county': '287', 'state': '13'},
#  {'NAME': 'Twiggs County', 'P0010001': '9023', 'county': '289', 'state': '13'},
#  {'NAME': 'Union County', 'P0010001': '21356', 'county': '291', 'state': '13'},
#  {'NAME': 'Upson County', 'P0010001': '27153', 'county': '293', 'state': '13'},
#  {'NAME': 'Walker County',
#   'P0010001': '68756',
#   'county': '295',
#   'state': '13'},
#  {'NAME': 'Walton County',
#   'P0010001': '83768',
#   'county': '297',
#   'state': '13'},
#  {'NAME': 'Ware County', 'P0010001': '36312', 'county': '299', 'state': '13'},
#  {'NAME': 'Warren County', 'P0010001': '5834', 'county': '301', 'state': '13'},
#  {'NAME': 'Washington County',
#   'P0010001': '21187',
#   'county': '303',
#   'state': '13'},
#  {'NAME': 'Wayne County', 'P0010001': '30099', 'county': '305', 'state': '13'},
#  {'NAME': 'Webster County',
#   'P0010001': '2799',
#   'county': '307',
#   'state': '13'},
#  {'NAME': 'Wheeler County',
#   'P0010001': '7421',
#   'county': '309',
#   'state': '13'},
#  {'NAME': 'White County', 'P0010001': '27144', 'county': '311', 'state': '13'},
#  {'NAME': 'Whitfield County',
#   'P0010001': '102599',
#   'county': '313',
#   'state': '13'},
#  {'NAME': 'Wilcox County', 'P0010001': '9255', 'county': '315', 'state': '13'},
#  {'NAME': 'Wilkes County',
#   'P0010001': '10593',
#   'county': '317',
#   'state': '13'},
#  {'NAME': 'Wilkinson County',
#   'P0010001': '9563',
#   'county': '319',
#   'state': '13'},
#  {'NAME': 'Worth County', 'P0010001': '21679', 'county': '321', 'state': '13'},
#  {'NAME': 'Hawaii County',
#   'P0010001': '185079',
#   'county': '001',
#   'state': '15'},
#  {'NAME': 'Honolulu County',
#   'P0010001': '953207',
#   'county': '003',
#   'state': '15'},
#  {'NAME': 'Kalawao County', 'P0010001': '90', 'county': '005', 'state': '15'},
#  {'NAME': 'Kauai County', 'P0010001': '67091', 'county': '007', 'state': '15'},
#  {'NAME': 'Maui County', 'P0010001': '154834', 'county': '009', 'state': '15'},
#  {'NAME': 'Ada County', 'P0010001': '392365', 'county': '001', 'state': '16'},
# ...
#   'county': '045',
#   'state': '19'},
#  {'NAME': 'Crawford County',
#   'P0010001': '17096',
#   'county': '047',
#   'state': '19'},
#  {'NAME': 'Dallas County',
#   'P0010001': '66135',
#   'county': '049',
#   'state': '19'},
#  {'NAME': 'Davis County', 'P0010001': '8753', 'county': '051', 'state': '19'},
#  {'NAME': 'Decatur County',
#   'P0010001': '8457',
#   'county': '053',
#   'state': '19'},
#  {'NAME': 'Delaware County',
#   'P0010001': '17764',
#   'county': '055',
#   'state': '19'},
#  {'NAME': 'Des Moines County',
#   'P0010001': '40325',
#   'county': '057',
#   'state': '19'},
#  {'NAME': 'Dickinson County',
#   'P0010001': '16667',
#   'county': '059',
#   'state': '19'},
#  {'NAME': 'Dubuque County',
#   'P0010001': '93653',
#   'county': '061',
#   'state': '19'},
#  {'NAME': 'Emmet County', 'P0010001': '10302', 'county': '063', 'state': '19'},
#  {'NAME': 'Fayette County',
#   'P0010001': '20880',
#   'county': '065',
#   'state': '19'},
#  {'NAME': 'Floyd County', 'P0010001': '16303', 'county': '067', 'state': '19'},
#  {'NAME': 'Franklin County',
#   'P0010001': '10680',
#   'county': '069',
#   'state': '19'},
#  {'NAME': 'Fremont County',
#   'P0010001': '7441',
#   'county': '071',
#   'state': '19'},
#  {'NAME': 'Greene County', 'P0010001': '9336', 'county': '073', 'state': '19'},
#  {'NAME': 'Grundy County',
#   'P0010001': '12453',
#   'county': '075',
#   'state': '19'},
#  {'NAME': 'Guthrie County',
#   'P0010001': '10954',
#   'county': '077',
#   'state': '19'},
#  {'NAME': 'Hamilton County',
#   'P0010001': '15673',
#   'county': '079',
#   'state': '19'},
#  {'NAME': 'Hancock County',
#   'P0010001': '11341',
#   'county': '081',
#   'state': '19'},
#  {'NAME': 'Hardin County',
#   'P0010001': '17534',
#   'county': '083',
#   'state': '19'},
#  {'NAME': 'Harrison County',
#   'P0010001': '14928',
#   'county': '085',
#   'state': '19'},
#  {'NAME': 'Henry County', 'P0010001': '20145', 'county': '087', 'state': '19'},
#  {'NAME': 'Howard County', 'P0010001': '9566', 'county': '089', 'state': '19'},
#  {'NAME': 'Humboldt County',
#   'P0010001': '9815',
#   'county': '091',
#   'state': '19'},
#  {'NAME': 'Ida County', 'P0010001': '7089', 'county': '093', 'state': '19'},
#  {'NAME': 'Iowa County', 'P0010001': '16355', 'county': '095', 'state': '19'},
#  {'NAME': 'Jackson County',
#   'P0010001': '19848',
#   'county': '097',
#   'state': '19'},
#  {'NAME': 'Jasper County',
#   'P0010001': '36842',
#   'county': '099',
#   'state': '19'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '16843',
#   'county': '101',
#   'state': '19'},
#  {'NAME': 'Johnson County',
#   'P0010001': '130882',
#   'county': '103',
#   'state': '19'},
#  {'NAME': 'Jones County', 'P0010001': '20638', 'county': '105', 'state': '19'},
#  {'NAME': 'Keokuk County',
#   'P0010001': '10511',
#   'county': '107',
#   'state': '19'},
#  {'NAME': 'Kossuth County',
#   'P0010001': '15543',
#   'county': '109',
#   'state': '19'},
#  {'NAME': 'Lee County', 'P0010001': '35862', 'county': '111', 'state': '19'},
#  {'NAME': 'Linn County', 'P0010001': '211226', 'county': '113', 'state': '19'},
#  {'NAME': 'Louisa County',
#   'P0010001': '11387',
#   'county': '115',
#   'state': '19'},
#  {'NAME': 'Lucas County', 'P0010001': '8898', 'county': '117', 'state': '19'},
#  {'NAME': 'Lyon County', 'P0010001': '11581', 'county': '119', 'state': '19'},
#  {'NAME': 'Madison County',
#   'P0010001': '15679',
#   'county': '121',
#   'state': '19'},
#  {'NAME': 'Mahaska County',
#   'P0010001': '22381',
#   'county': '123',
#   'state': '19'},
#  {'NAME': 'Marion County',
#   'P0010001': '33309',
#   'county': '125',
#   'state': '19'},
#  {'NAME': 'Marshall County',
#   'P0010001': '40648',
#   'county': '127',
#   'state': '19'},
#  {'NAME': 'Mills County', 'P0010001': '15059', 'county': '129', 'state': '19'},
#  {'NAME': 'Mitchell County',
#   'P0010001': '10776',
#   'county': '131',
#   'state': '19'},
#  {'NAME': 'Monona County', 'P0010001': '9243', 'county': '133', 'state': '19'},
#  {'NAME': 'Monroe County', 'P0010001': '7970', 'county': '135', 'state': '19'},
#  {'NAME': 'Montgomery County',
#   'P0010001': '10740',
#   'county': '137',
#   'state': '19'},
#  {'NAME': 'Muscatine County',
#   'P0010001': '42745',
#   'county': '139',
#   'state': '19'},
#  {'NAME': "O'Brien County",
#   'P0010001': '14398',
#   'county': '141',
#   'state': '19'},
#  {'NAME': 'Osceola County',
#   'P0010001': '6462',
#   'county': '143',
#   'state': '19'},
#  {'NAME': 'Page County', 'P0010001': '15932', 'county': '145', 'state': '19'},
#  {'NAME': 'Palo Alto County',
#   'P0010001': '9421',
#   'county': '147',
#   'state': '19'},
#  {'NAME': 'Plymouth County',
#   'P0010001': '24986',
#   'county': '149',
#   'state': '19'},
#  {'NAME': 'Pocahontas County',
#   'P0010001': '7310',
#   'county': '151',
#   'state': '19'},
#  {'NAME': 'Polk County', 'P0010001': '430640', 'county': '153', 'state': '19'},
#  {'NAME': 'Pottawattamie County',
#   'P0010001': '93158',
#   'county': '155',
#   'state': '19'},
#  {'NAME': 'Poweshiek County',
#   'P0010001': '18914',
#   'county': '157',
#   'state': '19'},
#  {'NAME': 'Ringgold County',
#   'P0010001': '5131',
#   'county': '159',
#   'state': '19'},
#  {'NAME': 'Sac County', 'P0010001': '10350', 'county': '161', 'state': '19'},
#  {'NAME': 'Scott County',
#   'P0010001': '165224',
#   'county': '163',
#   'state': '19'},
#  {'NAME': 'Shelby County',
#   'P0010001': '12167',
#   'county': '165',
#   'state': '19'},
#  {'NAME': 'Sioux County', 'P0010001': '33704', 'county': '167', 'state': '19'},
#  {'NAME': 'Story County', 'P0010001': '89542', 'county': '169', 'state': '19'},
#  {'NAME': 'Tama County', 'P0010001': '17767', 'county': '171', 'state': '19'},
#  {'NAME': 'Taylor County', 'P0010001': '6317', 'county': '173', 'state': '19'},
#  {'NAME': 'Union County', 'P0010001': '12534', 'county': '175', 'state': '19'},
#  {'NAME': 'Van Buren County',
#   'P0010001': '7570',
#   'county': '177',
#   'state': '19'},
#  {'NAME': 'Wapello County',
#   'P0010001': '35625',
#   'county': '179',
#   'state': '19'},
#  {'NAME': 'Warren County',
#   'P0010001': '46225',
#   'county': '181',
#   'state': '19'},
#  {'NAME': 'Washington County',
#   'P0010001': '21704',
#   'county': '183',
#   'state': '19'},
#  {'NAME': 'Wayne County', 'P0010001': '6403', 'county': '185', 'state': '19'},
#  {'NAME': 'Webster County',
#   'P0010001': '38013',
#   'county': '187',
#   'state': '19'},
#  {'NAME': 'Winnebago County',
#   'P0010001': '10866',
#   'county': '189',
#   'state': '19'},
#  {'NAME': 'Winneshiek County',
#   'P0010001': '21056',
#   'county': '191',
#   'state': '19'},
#  {'NAME': 'Woodbury County',
#   'P0010001': '102172',
#   'county': '193',
#   'state': '19'},
#  {'NAME': 'Worth County', 'P0010001': '7598', 'county': '195', 'state': '19'},
#  {'NAME': 'Wright County',
#   'P0010001': '13229',
#   'county': '197',
#   'state': '19'},
#  {'NAME': 'Allen County', 'P0010001': '13371', 'county': '001', 'state': '20'},
#  {'NAME': 'Anderson County',
#   'P0010001': '8102',
#   'county': '003',
#   'state': '20'},
#  {'NAME': 'Atchison County',
#   'P0010001': '16924',
#   'county': '005',
#   'state': '20'},
#  {'NAME': 'Barber County', 'P0010001': '4861', 'county': '007', 'state': '20'},
#  {'NAME': 'Barton County',
#   'P0010001': '27674',
#   'county': '009',
#   'state': '20'},
#  {'NAME': 'Bourbon County',
#   'P0010001': '15173',
#   'county': '011',
#   'state': '20'},
#  {'NAME': 'Brown County', 'P0010001': '9984', 'county': '013', 'state': '20'},
#  {'NAME': 'Butler County',
#   'P0010001': '65880',
#   'county': '015',
#   'state': '20'},
#  {'NAME': 'Chase County', 'P0010001': '2790', 'county': '017', 'state': '20'},
#  {'NAME': 'Chautauqua County',
#   'P0010001': '3669',
#   'county': '019',
#   'state': '20'},
#  {'NAME': 'Cherokee County',
#   'P0010001': '21603',
#   'county': '021',
#   'state': '20'},
#  {'NAME': 'Cheyenne County',
#   'P0010001': '2726',
#   'county': '023',
#   'state': '20'},
#  {'NAME': 'Clark County', 'P0010001': '2215', 'county': '025', 'state': '20'},
#  {'NAME': 'Clay County', 'P0010001': '8535', 'county': '027', 'state': '20'},
#  {'NAME': 'Cloud County', 'P0010001': '9533', 'county': '029', 'state': '20'},
#  {'NAME': 'Coffey County', 'P0010001': '8601', 'county': '031', 'state': '20'},
#  {'NAME': 'Comanche County',
#   'P0010001': '1891',
#   'county': '033',
#   'state': '20'},
#  {'NAME': 'Cowley County',
#   'P0010001': '36311',
#   'county': '035',
#   'state': '20'},
#  {'NAME': 'Crawford County',
#   'P0010001': '39134',
#   'county': '037',
#   'state': '20'},
#  {'NAME': 'Decatur County',
#   'P0010001': '2961',
#   'county': '039',
#   'state': '20'},
#  {'NAME': 'Dickinson County',
#   'P0010001': '19754',
#   'county': '041',
#   'state': '20'},
#  {'NAME': 'Doniphan County',
#   'P0010001': '7945',
#   'county': '043',
#   'state': '20'},
#  {'NAME': 'Douglas County',
#   'P0010001': '110826',
#   'county': '045',
#   'state': '20'},
#  {'NAME': 'Edwards County',
#   'P0010001': '3037',
#   'county': '047',
#   'state': '20'},
#  {'NAME': 'Elk County', 'P0010001': '2882', 'county': '049', 'state': '20'},
#  {'NAME': 'Ellis County', 'P0010001': '28452', 'county': '051', 'state': '20'},
#  {'NAME': 'Ellsworth County',
#   'P0010001': '6497',
#   'county': '053',
#   'state': '20'},
#  {'NAME': 'Finney County',
#   'P0010001': '36776',
#   'county': '055',
#   'state': '20'},
#  {'NAME': 'Ford County', 'P0010001': '33848', 'county': '057', 'state': '20'},
#  {'NAME': 'Franklin County',
#   'P0010001': '25992',
#   'county': '059',
#   'state': '20'},
#  {'NAME': 'Geary County', 'P0010001': '34362', 'county': '061', 'state': '20'},
#  {'NAME': 'Gove County', 'P0010001': '2695', 'county': '063', 'state': '20'},
#  {'NAME': 'Graham County', 'P0010001': '2597', 'county': '065', 'state': '20'},
#  {'NAME': 'Grant County', 'P0010001': '7829', 'county': '067', 'state': '20'},
#  {'NAME': 'Gray County', 'P0010001': '6006', 'county': '069', 'state': '20'},
#  {'NAME': 'Greeley County',
#   'P0010001': '1247',
#   'county': '071',
#   'state': '20'},
#  {'NAME': 'Greenwood County',
#   'P0010001': '6689',
#   'county': '073',
#   'state': '20'},
#  {'NAME': 'Hamilton County',
#   'P0010001': '2690',
#   'county': '075',
#   'state': '20'},
#  {'NAME': 'Harper County', 'P0010001': '6034', 'county': '077', 'state': '20'},
#  {'NAME': 'Harvey County',
#   'P0010001': '34684',
#   'county': '079',
#   'state': '20'},
#  {'NAME': 'Haskell County',
#   'P0010001': '4256',
#   'county': '081',
#   'state': '20'},
#  {'NAME': 'Hodgeman County',
#   'P0010001': '1916',
#   'county': '083',
#   'state': '20'},
#  {'NAME': 'Jackson County',
#   'P0010001': '13462',
#   'county': '085',
#   'state': '20'},
#  {'NAME': 'Jefferson County',
#   'P0010001': '19126',
#   'county': '087',
#   'state': '20'},
#  {'NAME': 'Jewell County', 'P0010001': '3077', 'county': '089', 'state': '20'},
#  {'NAME': 'Johnson County',
#   'P0010001': '544179',
#   'county': '091',
#   'state': '20'},
#  {'NAME': 'Kearny County', 'P0010001': '3977', 'county': '093', 'state': '20'},
#  {'NAME': 'Kingman County',
#   'P0010001': '7858',
#   'county': '095',
#   'state': '20'},
#  {'NAME': 'Kiowa County', 'P0010001': '2553', 'county': '097', 'state': '20'},
#  {'NAME': 'Labette County',
#   'P0010001': '21607',
#   'county': '099',
#   'state': '20'},
#  {'NAME': 'Lane County', 'P0010001': '1750', 'county': '101', 'state': '20'},
#  {'NAME': 'Leavenworth County',
#   'P0010001': '76227',
#   'county': '103',
#   'state': '20'},
#  {'NAME': 'Lincoln County',
#   'P0010001': '3241',
#   'county': '105',
#   'state': '20'},
#  {'NAME': 'Linn County', 'P0010001': '9656', 'county': '107', 'state': '20'},
#  {'NAME': 'Logan County', 'P0010001': '2756', 'county': '109', 'state': '20'},
#  {'NAME': 'Lyon County', 'P0010001': '33690', 'county': '111', 'state': '20'},
#  {'NAME': 'McPherson County',
#   'P0010001': '29180',
#   'county': '113',
#   'state': '20'},
#  {'NAME': 'Marion County',
#   'P0010001': '12660',
#   'county': '115',
#   'state': '20'},
#  {'NAME': 'Marshall County',
#   'P0010001': '10117',
#   'county': '117',
#   'state': '20'},
#  {'NAME': 'Meade County', 'P0010001': '4575', 'county': '119', 'state': '20'},
#  {'NAME': 'Miami County', 'P0010001': '32787', 'county': '121', 'state': '20'},
#  {'NAME': 'Mitchell County',
#   'P0010001': '6373',
#   'county': '123',
#   'state': '20'},
#  {'NAME': 'Montgomery County',
#   'P0010001': '35471',
#   'county': '125',
#   'state': '20'},
#  {'NAME': 'Morris County', 'P0010001': '5923', 'county': '127', 'state': '20'},
#  {'NAME': 'Morton County', 'P0010001': '3233', 'county': '129', 'state': '20'},
#  {'NAME': 'Nemaha County',
#   'P0010001': '10178',
#   'county': '131',
#   'state': '20'},
#  {'NAME': 'Neosho County',
#   'P0010001': '16512',
#   'county': '133',
#   'state': '20'},
#  {'NAME': 'Ness County', 'P0010001': '3107', 'county': '135', 'state': '20'},
#  {'NAME': 'Norton County', 'P0010001': '5671', 'county': '137', 'state': '20'},
#  {'NAME': 'Osage County', 'P0010001': '16295', 'county': '139', 'state': '20'},
#  {'NAME': 'Osborne County',
#   'P0010001': '3858',
#   'county': '141',
#   'state': '20'},
#  {'NAME': 'Ottawa County', 'P0010001': '6091', 'county': '143', 'state': '20'},
#  {'NAME': 'Pawnee County', 'P0010001': '6973', 'county': '145', 'state': '20'},
#  {'NAME': 'Phillips County',
#   'P0010001': '5642',
#   'county': '147',
#   'state': '20'},
#  {'NAME': 'Pottawatomie County',
#   'P0010001': '21604',
#   'county': '149',
#   'state': '20'},
#  {'NAME': 'Pratt County', 'P0010001': '9656', 'county': '151', 'state': '20'},
#  {'NAME': 'Rawlins County',
#   'P0010001': '2519',
#   'county': '153',
#   'state': '20'},
#  {'NAME': 'Reno County', 'P0010001': '64511', 'county': '155', 'state': '20'},
#  {'NAME': 'Republic County',
#   'P0010001': '4980',
#   'county': '157',
#   'state': '20'},
#  {'NAME': 'Rice County', 'P0010001': '10083', 'county': '159', 'state': '20'},
#  {'NAME': 'Riley County', 'P0010001': '71115', 'county': '161', 'state': '20'},
#  {'NAME': 'Rooks County', 'P0010001': '5181', 'county': '163', 'state': '20'},
#  {'NAME': 'Rush County', 'P0010001': '3307', 'county': '165', 'state': '20'},
#  {'NAME': 'Russell County',
#   'P0010001': '6970',
#   'county': '167',
#   'state': '20'},
#  {'NAME': 'Saline County',
#   'P0010001': '55606',
#   'county': '169',
#   'state': '20'},
#  {'NAME': 'Scott County', 'P0010001': '4936', 'county': '171', 'state': '20'},
#  {'NAME': 'Sedgwick County',
#   'P0010001': '498365',
#   'county': '173',
#   'state': '20'},
#  {'NAME': 'Seward County',
#   'P0010001': '22952',
#   'county': '175',
#   'state': '20'},
#  {'NAME': 'Shawnee County',
#   'P0010001': '177934',
#   'county': '177',
#   'state': '20'},
#  {'NAME': 'Sheridan County',
#   'P0010001': '2556',
#   'county': '179',
#   'state': '20'},
#  {'NAME': 'Sherman County',
#   'P0010001': '6010',
#   'county': '181',
#   'state': '20'},
#  {'NAME': 'Smith County', 'P0010001': '3853', 'county': '183', 'state': '20'},
#  {'NAME': 'Stafford County',
#   'P0010001': '4437',
#   'county': '185',
#   'state': '20'},
#  {'NAME': 'Stanton County',
#   'P0010001': '2235',
#   'county': '187',
#   'state': '20'},
#  {'NAME': 'Stevens County',
#   'P0010001': '5724',
#   'county': '189',
#   'state': '20'},
#  {'NAME': 'Sumner County',
#   'P0010001': '24132',
#   'county': '191',
#   'state': '20'},
#  {'NAME': 'Thomas County', 'P0010001': '7900', 'county': '193', 'state': '20'},
#  {'NAME': 'Trego County', 'P0010001': '3001', 'county': '195', 'state': '20'},
#  {'NAME': 'Wabaunsee County',
#   'P0010001': '7053',
#   'county': '197',
#   'state': '20'},
#  {'NAME': 'Wallace County',
#   'P0010001': '1485',
#   'county': '199',
#   'state': '20'},
#  {'NAME': 'Washington County',
#   'P0010001': '5799',
#   'county': '201',
#   'state': '20'},
#  {'NAME': 'Wichita County',
#   'P0010001': '2234',
#   'county': '203',
#   'state': '20'},
#  {'NAME': 'Wilson County', 'P0010001': '9409', 'county': '205', 'state': '20'},
#  {'NAME': 'Woodson County',
#   'P0010001': '3309',
#   'county': '207',
#   'state': '20'},
#  {'NAME': 'Wyandotte County',
#   'P0010001': '157505',
#   'county': '209',
#   'state': '20'},
#  {'NAME': 'Adair County', 'P0010001': '18656', 'county': '001', 'state': '21'},
#  {'NAME': 'Allen County', 'P0010001': '19956', 'county': '003', 'state': '21'},
#  {'NAME': 'Anderson County',
#   'P0010001': '21421',
#   'county': '005',
#   'state': '21'},
#  {'NAME': 'Ballard County',
#   'P0010001': '8249',
#   'county': '007',
#   'state': '21'},
#  {'NAME': 'Barren County',
#   'P0010001': '42173',
#   'county': '009',
#   'state': '21'},
#  {'NAME': 'Bath County', 'P0010001': '11591', 'county': '011', 'state': '21'},
#  {'NAME': 'Bell County', 'P0010001': '28691', 'county': '013', 'state': '21'},
#  ...]

# %%
# convert the json from the API into a DataFrame
# coerce to integer the P0010001 column

df = DataFrame(r)
df['P0010001'] = df['P0010001'].astype('int')

# display the first records
df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
# calculate the total population 
# what happens when you google the number you get?

np.sum(df['P0010001'])
# Out:
# 312471327

# %%
# often you can use dot notation to access a DataFrame column
df.P0010001.head()
# Out:
# 0     54571
# 1    182265
# 2     27457
# 3     22915
# 4     57322
# Name: P0010001, dtype: int64

# %%
# let's filter out PR -- what's the total population now
sum(df[np.in1d(df.state, states_fips)].P0010001)
# Out:
# 308745538

# %%
# fall back to non-Pandas solution if you need to
np.sum([int(county['P0010001']) for county in r if county['state'] in states_fips])
# Out:
# 308745538

# %%
# construct counties_df with only 50 states + DC

#counties_df = df[np.in1d(df.state, states_fips)]
counties_df = df.loc[np.in1d(df.state, states_fips)].copy()
len(counties_df)
# Out:
# 3143

# %%
set(counties_df.columns) == set(df.columns)
# Out:
# True

# %% [markdown]
# Check properties of `counties_df`

# %%
# number of counties
assert len(counties_df) == 3143 #3143 county/county-equivs in US

# %%
# check that the total population by adding all counties == population by adding all states

assert np.sum(counties_df['P0010001']) == np.sum(states_df.P0010001)

# %%
# check we have same columns between counties_df and df
set(counties_df.columns) == set(df.columns)
# Out:
# True

# %% [markdown]
# # Using FIPS code as the Index

# %% [markdown]
# From [Mapping Census Data](http://www.udel.edu/johnmack/frec682/census/):
#
# * Each state (SUMLEV = 040) has a 2-digit FIPS ID; Delaware's is 10.
# * Each county (SUMLEV = 050) within a state has a 3-digit FIPS ID, appended to the 2-digit state ID. New Castle County, Delaware, has FIPS ID 10003.
# * Each Census Tract (SUMLEV = 140) within a county has a 6-digit ID, appended to the county code. The Tract in New Castle County DE that contains most of the the UD campus has FIPS ID 10003014502.
# * Each Block Group (SUMLEV = 150) within a Tract has a single digit ID appended to the Tract ID. The center of campus in the northwest corner of the tract is Block Group100030145022.
# * Each Block (SUMLEV = 750) within a Block Group is identified by three more digits appended to the Block Group ID. Pearson Hall is located in Block 100030145022009.

# %%
# take a look at the current structure of counties_df

counties_df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
states_df.head()
# Out:
#          NAME  P0010001 state
# 0     Alabama   4779736    01
# 1      Alaska    710231    02
# 2     Arizona   6392017    04
# 3    Arkansas   2915918    05
# 4  California  37253956    06

# %%
# reindex states_df by state FIPS
# http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.set_index.html

states_df.set_index(keys='state', inplace=True)
states_df.head()
# Out:
#              NAME  P0010001
# state
# 01        Alabama   4779736
# 02         Alaska    710231
# 04        Arizona   6392017
# 05       Arkansas   2915918
# 06     California  37253956

# %%
states_df.columns
# Out:
# Index(['NAME', 'P0010001'], dtype='object')

# %%
# display the result of using set_index
counties_df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
# df.loc[np.in1d(df.state, states_fips), 'FIPS'] = counties_df.apply(lambda s:s['state']+s['county'], axis=1)

# %%
counties_df['FIPS'] = counties_df.apply(lambda s:s['state']+s['county'], axis=1)

# %%
df[np.in1d(df.state, states_fips)].head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
counties_df.head()
# Out:
#              NAME  P0010001 county state   FIPS
# 0  Autauga County     54571    001    01  01001
# 1  Baldwin County    182265    003    01  01003
# 2  Barbour County     27457    005    01  01005
# 3     Bibb County     22915    007    01  01007
# 4   Blount County     57322    009    01  01009

# %%
def double(x):
    return 2*x

counties_df.P0010001.apply(double)
# Out:
# 0       109142
# 1       364530
# 2        54914
# 3        45830
# 4       114644
# 5        21828
# 6        41894
# 7       237144
# 8        68430
# 9        51978
# 10       87286
# 11       27718
# 12       51666
# 13       27864
# 14       29944
# 15       99896
# 16      108856
# 17       26456
# 18       23078
# 19       75530
# 20       27812
# 21      160812
# 22      100502
# 23       87640
# 24      142218
# 25      158606
# 26       76638
# 27      208860
# 28       34482
# 29       63408
#          ...
# 3113     31822
# 3114    263774
# 3115    779782
# 3116    104820
# 3117     48992
# 3118    333988
# 3119    149498
# 3120     72598
# 3121     23336
# 3122     92266
# 3123     31770
# 3124     27666
# 3125     14166
# 3126     80246
# 3127     26498
# 3128      9624
# 3129     17138
# 3130    183476
# 3131     36212
# 3132    150900
# 3133      4968
# 3134     56410
# 3135     17334
# 3136     58232
# 3137     20494
# 3138     87612
# 3139     42588
# 3140     42236
# 3141     17066
# 3142     14416
# Name: P0010001, dtype: int64

# %%
# http://manishamde.github.io/blog/2013/03/07/pandas-and-python-top-10/#create

counties_df['FIPS'] = counties_df.apply(lambda s:s['state'] + s['county'], axis=1)
counties_df.set_index('FIPS', inplace=True)

# %%
counties_df.head()
# Out:
#                  NAME  P0010001 county state
# FIPS
# 01001  Autauga County     54571    001    01
# 01003  Baldwin County    182265    003    01
# 01005  Barbour County     27457    005    01
# 01007     Bibb County     22915    007    01
# 01009   Blount County     57322    009    01

# %%
counties_df.groupby('state').sum().head()
# Out:
#        P0010001
# state
# 01      4779736
# 02       710231
# 04      6392017
# 05      2915918
# 06     37253956

# %%
states_df.P0010001.head()
# Out:
# state
# 01     4779736
# 02      710231
# 04     6392017
# 05     2915918
# 06    37253956
# Name: P0010001, dtype: int64

# %%
# now we're ready to compare for each state, if you add all the counties, do you get the same
# population?
# not that you can do .agg('sum') instead of .sum()
# look at http://pandas.pydata.org/pandas-docs/dev/groupby.html to learn more about agg

np.all(states_df.P0010001 == counties_df.groupby('state').agg('sum').P0010001)
# Out:
# True

# %% [markdown]
# # Counties in California

# %% [markdown]
# Let's look at home: California state and Alameda County

# %%
# boolean indexing to pull up California
states_df[states_df.NAME == 'California']
# Out:
#              NAME  P0010001
# state
# 06     California  37253956

# %%
# use .ix -- most general indexing 
# http://pandas.pydata.org/pandas-docs/dev/indexing.html#different-choices-for-indexing-loc-iloc-and-ix
states_df.ix['06']
# Out:
# NAME        California
# P0010001      37253956
# Name: 06, dtype: object

# %%
# California counties

counties_df[counties_df.state=='06']
# Out:
#                          NAME  P0010001 county state
# FIPS
# 06001          Alameda County   1510271    001    06
# 06003           Alpine County      1175    003    06
# 06005           Amador County     38091    005    06
# 06007            Butte County    220000    007    06
# 06009        Calaveras County     45578    009    06
# 06011           Colusa County     21419    011    06
# 06013     Contra Costa County   1049025    013    06
# 06015        Del Norte County     28610    015    06
# 06017        El Dorado County    181058    017    06
# 06019           Fresno County    930450    019    06
# 06021            Glenn County     28122    021    06
# 06023         Humboldt County    134623    023    06
# 06025         Imperial County    174528    025    06
# 06027             Inyo County     18546    027    06
# 06029             Kern County    839631    029    06
# 06031            Kings County    152982    031    06
# 06033             Lake County     64665    033    06
# 06035           Lassen County     34895    035    06
# 06037      Los Angeles County   9818605    037    06
# 06039           Madera County    150865    039    06
# 06041            Marin County    252409    041    06
# 06043         Mariposa County     18251    043    06
# 06045        Mendocino County     87841    045    06
# 06047           Merced County    255793    047    06
# 06049            Modoc County      9686    049    06
# 06051             Mono County     14202    051    06
# 06053         Monterey County    415057    053    06
# 06055             Napa County    136484    055    06
# 06057           Nevada County     98764    057    06
# 06059           Orange County   3010232    059    06
# 06061           Placer County    348432    061    06
# 06063           Plumas County     20007    063    06
# 06065        Riverside County   2189641    065    06
# 06067       Sacramento County   1418788    067    06
# 06069       San Benito County     55269    069    06
# 06071   San Bernardino County   2035210    071    06
# 06073        San Diego County   3095313    073    06
# 06075    San Francisco County    805235    075    06
# 06077      San Joaquin County    685306    077    06
# 06079  San Luis Obispo County    269637    079    06
# 06081        San Mateo County    718451    081    06
# 06083    Santa Barbara County    423895    083    06
# 06085      Santa Clara County   1781642    085    06
# 06087       Santa Cruz County    262382    087    06
# 06089           Shasta County    177223    089    06
# 06091           Sierra County      3240    091    06
# 06093         Siskiyou County     44900    093    06
# 06095           Solano County    413344    095    06
# 06097           Sonoma County    483878    097    06
# 06099       Stanislaus County    514453    099    06
# 06101           Sutter County     94737    101    06
# 06103           Tehama County     63463    103    06
# 06105          Trinity County     13786    105    06
# 06107           Tulare County    442179    107    06
# 06109         Tuolumne County     55365    109    06
# 06111          Ventura County    823318    111    06
# 06113             Yolo County    200849    113    06
# 06115             Yuba County     72155    115    06

# %%
counties_df[counties_df.NAME == 'Alameda County']
# Out:
#                  NAME  P0010001 county state
# FIPS
# 06001  Alameda County   1510271    001    06

# %%
counties_df[counties_df.NAME == 'Alameda County']['P0010001']
# Out:
# FIPS
# 06001    1510271
# Name: P0010001, dtype: int64

# %% [markdown]
# Different ways to read off the population of Alameda County -- still looking for the best way

# %%
list(counties_df[counties_df.NAME == 'Alameda County']['P0010001'].to_dict().values())[0]
# Out:
# 1510271

# %%
list(counties_df[counties_df.NAME == 'Alameda County']['P0010001'].iteritems())[0][1]
# Out:
# 1510271

# %%
int(counties_df[counties_df.NAME == 'Alameda County']['P0010001'].values)
# Out:
# 1510271

# %% [markdown]
# If you know the FIPS code for Alameda County, just read off the population using `.ix`

# %%
# this is like accessing a cell in a spreadsheet -- row, col

ALAMEDA_COUNTY_FIPS = '06001'

counties_df.ix[ALAMEDA_COUNTY_FIPS,'P0010001']
# Out:
# 1510271

# %% [markdown]
# # Reading off all the tracts in Alameda County

# %%
counties_df.ix[ALAMEDA_COUNTY_FIPS,'county']
# Out:
# '001'

# %%
# http://api.census.gov/data/2010/sf1/geo.html
# state-county-tract

geo = {'for': 'tract:*', 
       'in': 'state:%s county:%s' % (us.states.CA.fips, 
                                     counties_df.ix[ALAMEDA_COUNTY_FIPS,'county'])}
        
r = c.sf1.get('NAME,P0010001', geo=geo)

# %%
#use state_county_tract to make a DataFrame

alameda_county_tracts_df = DataFrame(r)
alameda_county_tracts_df['P0010001'] = alameda_county_tracts_df['P0010001'].astype('int')
alameda_county_tracts_df['FIPS'] = alameda_county_tracts_df.apply(lambda s: s['state']+s['county']+s['tract'], axis=1)
alameda_county_tracts_df.head()
# Out:
#                 NAME  P0010001 county state   tract         FIPS
# 0  Census Tract 4001      2937    001    06  400100  06001400100
# 1  Census Tract 4002      1974    001    06  400200  06001400200
# 2  Census Tract 4003      4865    001    06  400300  06001400300
# 3  Census Tract 4004      3703    001    06  400400  06001400400
# 4  Census Tract 4005      3517    001    06  400500  06001400500

# %%
alameda_county_tracts_df.apply(lambda s: s['state']+s['county']+s['tract'], axis=1)
# Out:
# 0      06001400100
# 1      06001400200
# 2      06001400300
# 3      06001400400
# 4      06001400500
# 5      06001400600
# 6      06001400700
# 7      06001400800
# 8      06001400900
# 9      06001401000
# 10     06001401100
# 11     06001401200
# 12     06001401300
# 13     06001401400
# 14     06001401500
# 15     06001401600
# 16     06001401700
# 17     06001401800
# 18     06001402200
# 19     06001402400
# 20     06001402500
# 21     06001402600
# 22     06001402700
# 23     06001402800
# 24     06001402900
# 25     06001403000
# 26     06001403100
# 27     06001403300
# 28     06001403400
# 29     06001403501
#           ...
# 331    06001450742
# 332    06001450743
# 333    06001450744
# 334    06001450745
# 335    06001450746
# 336    06001450750
# 337    06001450751
# 338    06001450752
# 339    06001451101
# 340    06001451102
# 341    06001451201
# 342    06001451202
# 343    06001451300
# 344    06001451401
# 345    06001451403
# 346    06001451404
# 347    06001451501
# 348    06001451503
# 349    06001451504
# 350    06001451505
# 351    06001451506
# 352    06001451601
# 353    06001451602
# 354    06001451701
# 355    06001451703
# 356    06001451704
# 357    06001981900
# 358    06001982000
# 359    06001983200
# 360    06001990000
# dtype: object

# %%
alameda_county_tracts_df.P0010001.sum()
# Out:
# 1510271

# %%
# Cafe Milano is in tract 4228
MILANO_TRACT_ID = '422800'
alameda_county_tracts_df[alameda_county_tracts_df.tract==MILANO_TRACT_ID]
# Out:
#                   NAME  P0010001 county state   tract         FIPS
# 133  Census Tract 4228      8368    001    06  422800  06001422800

# %% [markdown]
# # Using Generators to yield all the tracts in the country

# %% [markdown]
# http://www.jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/

# %%
import time
import us

from itertools import islice

def census_tracts(variable=('NAME','P0010001'), sleep_time=1.0):
    
    for state in us.states.STATES:
        print (state)
        for tract in c.sf1.get(variable, 
                    geo={'for':"tract:*", 
                        'in':'state:{state_fips}'.format(state_fips=state.fips)
                        }):
            yield tract
        # don't hit the API more than once a second    
        time.sleep(sleep_time)
 
# limit the number of tracts we crawl for until we're reading to get all of them        
tracts_df = DataFrame(list(islice(census_tracts(), 100)))
tracts_df['P0010001'] = tracts_df['P0010001'].astype('int')
# Out:
# Alabama

# %%
tracts_df.head()
# Out:
#                NAME  P0010001 county state   tract
# 0  Census Tract 201      1912    001    01  020100
# 1  Census Tract 202      2170    001    01  020200
# 2  Census Tract 203      3373    001    01  020300
# 3  Census Tract 204      4386    001    01  020400
# 4  Census Tract 205     10766    001    01  020500

# %% [markdown]
# # Compare with Tabulations

# %% [markdown]
# We can compare the total number of tracts we calculate to:
#
# https://www.census.gov/geo/maps-data/data/tallies/tractblock.html
#
# and
#
# https://www.census.gov/geo/maps-data/data/docs/geo_tallies/Tract_Block2010.txt
