# %%
import matplotlib

# %%
# %matplotlib inline

# %%
#  import useful classes of pandas
import pandas as pd
from pandas import Series, DataFrame, Index

# %%
import settings
import census
import requests

c = census.Census(key=settings.CENSUS_KEY)

# %%
census.__version__
# Out:
# '0.7.1'

# %%
c.sf1.fields
# Out:
# <bound method SF1Client.fields of <census.core.SF1Client object at 0x10c1544a8>>

# %% [markdown]
# # Fields in SF1

# %%
sf1_fields = c.sf1.fields(year=2010)

# %%
sorted(sf1_fields.keys())
# Out:
# []

# %% [markdown]
# Let's parse more of pieces that are in the fields

# %%
# let's just parse sf1.xml ourselves to get the concepts
# http://lxml.de/parsing.html

from lxml import etree
from itertools import islice
import re

def parse_concept_name(concept_name):
    if concept_name != 'Geographic Characteristics':
        m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
        if m: 
           return {'label':m.group(1),
                  'clean_name':m.group(2),
                  'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                  }
       # print m.groups()
        else:
           m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
           return {'label':m1.group(1),
                  'clean_name':m1.group(2),
                  'num_vars':0
                 }
    else:
        return None
    
def concepts_2010_sf1():
    # http://www.census.gov/developers/data/sf1.xml
    SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

    doc = etree.parse(SF1_XML_PATH)
    for concept in doc.findall("//concept"):
        concept_name = concept.attrib['name']
        
        if concept_name != 'Geographic Characteristics':
            m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
            if m: 
               yield {'label':m.group(1),
                      'clean_name':m.group(2),
                      'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                      }
           # print m.groups()
            else:
               m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
               yield {'label':m1.group(1),
                      'clean_name':m1.group(2),
                      'num_vars':0
                     }
            
k = list(concepts_2010_sf1())    
k
# Out:
# [{'clean_name': 'Housing Units', 'label': 'H1.', 'num_vars': '1'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS',
#   'label': 'H10.',
#   'num_vars': '1'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE',
#   'label': 'H11.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'H11A.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'H11B.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'H11C.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'H11D.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'H11E.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'H11F.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'H11G.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H11H.',
#   'num_vars': '4'},
#  {'clean_name': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H11I.',
#   'num_vars': '4'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE',
#   'label': 'H12.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'H12A.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'H12B.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'H12C.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'H12D.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'H12E.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'H12F.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'H12G.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H12H.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H12I.',
#   'num_vars': '3'},
#  {'clean_name': 'Household Size', 'label': 'H13.', 'num_vars': '8'},
#  {'clean_name': 'Tenure By Race Of Householder',
#   'label': 'H14.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER',
#   'label': 'H15.',
#   'num_vars': '7'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE', 'label': 'H16.', 'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'H16A.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'H16B.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'H16C.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'H16D.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'H16E.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'H16F.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'H16G.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H16H.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY HOUSEHOLD SIZE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H16I.',
#   'num_vars': '17'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER',
#   'label': 'H17.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (WHITE ALONE HOUSEHOLDER)',
#   'label': 'H17A.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'H17B.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'H17C.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'H17D.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'H17E.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'H17F.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'H17G.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'H17H.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY AGE OF HOUSEHOLDER (WHITE ALONE HOUSEHOLDER, NOT HISPANIC OR LATINO)',
#   'label': 'H17I.',
#   'num_vars': '21'},
#  {'clean_name': 'TENURE BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER',
#   'label': 'H18.',
#   'num_vars': '69'},
#  {'clean_name': 'TENURE BY PRESENCE OF PEOPLE UNDER 18 YEARS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'label': 'H19.',
#   'num_vars': '7'},
#  {'clean_name': 'URBAN AND RURAL', 'label': 'H2.', 'num_vars': '6'},
#  {'clean_name': 'OCCUPIED HOUSING UNITS SUBSTITUTED',
#   'label': 'H20.',
#   'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF VACANCY STATUS',
#   'label': 'H21.',
#   'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF TENURE', 'label': 'H22.', 'num_vars': '3'},
#  {'clean_name': 'Occupancy Status', 'label': 'H3.', 'num_vars': '3'},
#  {'clean_name': 'TENURE', 'label': 'H4.', 'num_vars': '4'},
#  {'clean_name': 'VACANCY STATUS', 'label': 'H5.', 'num_vars': '8'},
#  {'clean_name': 'Race Of Householder', 'label': 'H6.', 'num_vars': '8'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER',
#   'label': 'H7.',
#   'num_vars': '17'},
#  {'clean_name': 'Total Races Tallied For Householders',
#   'label': 'H8.',
#   'num_vars': '7'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN OF HOUSEHOLDERS BY TOTAL RACES TALLIED',
#   'label': 'H9.',
#   'num_vars': '15'},
#  {'clean_name': 'TENURE BY HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER',
#   'label': 'HCT1.',
#   'num_vars': '35'},
#  {'clean_name': 'TENURE BY PRESENCE AND AGE OF OWN CHILDREN',
#   'label': 'HCT2.',
#   'num_vars': '13'},
#  {'clean_name': 'TENURE BY PRESENCE AND AGE OF RELATED CHILDREN',
#   'label': 'HCT3.',
#   'num_vars': '13'},
#  {'clean_name': 'TENURE BY PRESENCE AND AGE OF PEOPLE UNDER 18 YEARS BY HOUSEHOLD TYPE (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'label': 'HCT4.',
#   'num_vars': '13'},
#  {'clean_name': 'Total Population', 'label': 'P1.', 'num_vars': '1'},
#  {'clean_name': 'RACE FOR THE POPULATION 18 YEARS AND OVER',
#   'label': 'P10.',
#   'num_vars': '71'},
#  {'clean_name': 'HISPANIC OR LATINO, AND NOT HISPANIC OR LATINO BY RACE FOR THE POPULATION 18 YEARS AND OVER',
#   'label': 'P11.',
#   'num_vars': '73'},
#  {'clean_name': 'Sex By Age', 'label': 'P12.', 'num_vars': '49'},
#  {'clean_name': 'Sex By Age (White Alone)',
#   'label': 'P12A.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Black Or African American Alone)',
#   'label': 'P12B.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (American Indian And Alaska Native Alone)',
#   'label': 'P12C.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Asian Alone)',
#   'label': 'P12D.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Native Hawaiian And Other Pacific Islander Alone)',
#   'label': 'P12E.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Some Other Race Alone)',
#   'label': 'P12F.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Two Or More Races)',
#   'label': 'P12G.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (Hispanic Or Latino)',
#   'label': 'P12H.',
#   'num_vars': '49'},
#  {'clean_name': 'Sex By Age (White Alone, Not Hispanic Or Latino)',
#   'label': 'P12I.',
#   'num_vars': '49'},
#  {'clean_name': 'MEDIAN AGE BY SEX', 'label': 'P13.', 'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (WHITE ALONE)',
#   'label': 'P13A.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'P13B.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'P13C.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (ASIAN ALONE)',
#   'label': 'P13D.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'P13E.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'label': 'P13F.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'label': 'P13G.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (HISPANIC OR LATINO)',
#   'label': 'P13H.',
#   'num_vars': '3'},
#  {'clean_name': 'MEDIAN AGE BY SEX (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'P13I.',
#   'num_vars': '3'},
#  {'clean_name': 'Sex By Age For The Population Under 20 Years',
#   'label': 'P14.',
#   'num_vars': '43'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER',
#   'label': 'P15.',
#   'num_vars': '17'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE',
#   'label': 'P16.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P16A.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P16B.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P16C.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P16D.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P16E.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P16F.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P16G.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P16H.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN HOUSEHOLDS BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P16I.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE',
#   'label': 'P17.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P17A.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P17B.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P17C.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P17D.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P17E.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P17F.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (TWO OR MORERACES HOUSEHOLDER)',
#   'label': 'P17G.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P17H.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE HOUSEHOLD SIZE BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P17I.',
#   'num_vars': '3'},
#  {'clean_name': 'HOUSEHOLD TYPE', 'label': 'P18.', 'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P18A.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P18B.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P18C.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P18D.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P18E.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P18F.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P18G.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P18H.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD TYPE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P18I.',
#   'num_vars': '9'},
#  {'clean_name': 'HOUSEHOLD SIZE BY HOUSEHOLD TYPE BY PRESENCE OF OWN CHILDREN',
#   'label': 'P19.',
#   'num_vars': '19'},
#  {'clean_name': 'Urban And Rural', 'label': 'P2.', 'num_vars': '6'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF PEOPLE UNDER 18 YEARS BY HOUSEHOLD TYPE BY AGE OF PEOPLE UNDER 18 YEARS',
#   'label': 'P20.',
#   'num_vars': '34'},
#  {'clean_name': 'HOUSEHOLDS BY AGE OF HOUSEHOLDER BY HOUSEHOLD TYPE BY PRESENCE OF RELATED CHILDREN',
#   'label': 'P21.',
#   'num_vars': '31'},
#  {'clean_name': 'HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER',
#   'label': 'P22.',
#   'num_vars': '21'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER BY HOUSEHOLD TYPE',
#   'label': 'P23.',
#   'num_vars': '15'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE',
#   'label': 'P24.',
#   'num_vars': '11'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 65 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE',
#   'label': 'P25.',
#   'num_vars': '11'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 75 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE',
#   'label': 'P26.',
#   'num_vars': '11'},
#  {'clean_name': 'HOUSEHOLDS BY PRESENCE OF NONRELATIVES',
#   'label': 'P27.',
#   'num_vars': '3'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE',
#   'label': 'P28.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P28A.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P28B.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P28C.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P28D.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P28E.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P28F.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P28G.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P28H.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY HOUSEHOLD SIZE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P28I.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP',
#   'label': 'P29.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (WHITE ALONE)',
#   'label': 'P29A.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'P29B.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'P29C.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (ASIAN ALONE)',
#   'label': 'P29D.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'P29E.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (SOME OTHER RACE ALONE)',
#   'label': 'P29F.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (TWO OR MORE RACES)',
#   'label': 'P29G.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (HISPANIC OR LATINO)',
#   'label': 'P29H.',
#   'num_vars': '28'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'P29I.',
#   'num_vars': '28'},
#  {'clean_name': 'RACE', 'label': 'P3.', 'num_vars': '8'},
#  {'clean_name': 'HOUSEHOLD TYPE FOR THE POPULATION IN HOUSEHOLDS',
#   'label': 'P30.',
#   'num_vars': '13'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS',
#   'label': 'P31.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (WHITE ALONE)',
#   'label': 'P31A.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'P31B.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'P31C.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (ASIAN ALONE)',
#   'label': 'P31D.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'P31E.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (SOME OTHER RACE ALONE)',
#   'label': 'P31F.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (TWO OR MORE RACES)',
#   'label': 'P31G.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (HISPANIC OR LATINO)',
#   'label': 'P31H.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'P31I.',
#   'num_vars': '16'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP BY AGE FOR THE POPULATION UNDER 18 YEARS',
#   'label': 'P32.',
#   'num_vars': '45'},
#  {'clean_name': 'HOUSEHOLD TYPE FOR THE POPULATION UNDER 18 YEARS IN HOUSEHOLDS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'label': 'P33.',
#   'num_vars': '7'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER',
#   'label': 'P34.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (WHITE ALONE)',
#   'label': 'P34A.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'P34B.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'P34C.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (ASIAN ALONE)',
#   'label': 'P34D.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'P34E.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'label': 'P34F.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (TWO OR MORE RACES)',
#   'label': 'P34G.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (HISPANIC OR LATINO)',
#   'label': 'P34H.',
#   'num_vars': '22'},
#  {'clean_name': 'HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'P34I.',
#   'num_vars': '22'},
#  {'clean_name': 'FAMILIES', 'label': 'P35.', 'num_vars': '1'},
#  {'clean_name': 'FAMILIES (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P35A.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P35B.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P35C.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P35D.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P35E.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P35F.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P35G.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P35H.',
#   'num_vars': '1'},
#  {'clean_name': 'FAMILIES (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P35I.',
#   'num_vars': '1'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE',
#   'label': 'P36.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P36A.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P36B.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P36C.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P36D.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P36E.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P36F.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P36G.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P36H.',
#   'num_vars': '3'},
#  {'clean_name': 'POPULATION IN FAMILIES BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P36I.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE',
#   'label': 'P37.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P37A.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P37B.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P37C.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P37D.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P37E.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P37F.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P37G.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P37H.',
#   'num_vars': '3'},
#  {'clean_name': 'AVERAGE FAMILY SIZE BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P37I.',
#   'num_vars': '3'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN',
#   'label': 'P38.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P38A.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P38B.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P38C.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P38D.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P38E.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P38F.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P38G.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P38H.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P38I.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN',
#   'label': 'P39.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (WHITE ALONE HOUSEHOLDER)',
#   'label': 'P39A.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'P39B.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'P39C.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'P39D.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'P39E.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'P39F.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'P39G.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P39H.',
#   'num_vars': '20'},
#  {'clean_name': 'FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'P39I.',
#   'num_vars': '20'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN', 'label': 'P4.', 'num_vars': '3'},
#  {'clean_name': 'FAMILY TYPE AND AGE FOR OWN CHILDREN UNDER 18 YEARS',
#   'label': 'P40.',
#   'num_vars': '20'},
#  {'clean_name': 'AGE OF GRANDCHILDREN UNDER 18 YEARS LIVING WITH A GRANDPARENT HOUSEHOLDER',
#   'label': 'P41.',
#   'num_vars': '6'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE',
#   'label': 'P42.',
#   'num_vars': '10'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY AGE BY GROUP QUARTERS TYPE',
#   'label': 'P43.',
#   'num_vars': '63'},
#  {'clean_name': 'POPULATION SUBSTITUTED', 'label': 'P44.', 'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF POPULATION ITEMS',
#   'label': 'P45.',
#   'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF RACE', 'label': 'P46.', 'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF HISPANIC OR LATINO ORIGIN',
#   'label': 'P47.',
#   'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF SEX', 'label': 'P48.', 'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF AGE', 'label': 'P49.', 'num_vars': '3'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN BY RACE',
#   'label': 'P5.',
#   'num_vars': '17'},
#  {'clean_name': 'ALLOCATION OF RELATIONSHIP',
#   'label': 'P50.',
#   'num_vars': '3'},
#  {'clean_name': 'ALLOCATION OF POPULATION ITEMS FOR THE POPULATION IN GROUP QUARTERS',
#   'label': 'P51.',
#   'num_vars': '3'},
#  {'clean_name': 'RACE (TOTAL RACES TALLIED)', 'label': 'P6.', 'num_vars': '7'},
#  {'clean_name': 'HISPANIC OR LATINO ORIGIN BY RACE (TOTAL RACES TALLIED)',
#   'label': 'P7.',
#   'num_vars': '15'},
#  {'clean_name': 'RACE', 'label': 'P8.', 'num_vars': '71'},
#  {'clean_name': 'HISPANIC OR LATINO, AND NOT HISPANIC OR LATINO BY RACE',
#   'label': 'P9.',
#   'num_vars': '73'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY AGE',
#   'label': 'PCO1.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN OTHER NONINSTITUTIONAL FACILITIES BY SEX BY AGE',
#   'label': 'PCO10.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN INSTITUTIONAL FACILITIES BY SEX BY AGE',
#   'label': 'PCO2.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN CORRECTIONAL FACILITIES FOR ADULTS BY SEX BY AGE',
#   'label': 'PCO3.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN JUVENILE FACILITIES BY SEX BY AGE',
#   'label': 'PCO4.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN NURSING FACILITIES/SKILLED-NURSING FACILITIES BY SEX BY AGE',
#   'label': 'PCO5.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN OTHER INSTITUTIONAL FACILITIES BY SEX BY AGE',
#   'label': 'PCO6.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN NONINSTITUTIONAL FACILITIES BY SEX BY AGE',
#   'label': 'PCO7.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN COLLEGE/UNIVERSITY STUDENT HOUSING BY SEX BY AGE',
#   'label': 'PCO8.',
#   'num_vars': '39'},
#  {'clean_name': 'GROUP QUARTERS POPULATION IN MILITARY QUARTERS BY SEX BY AGE',
#   'label': 'PCO9.',
#   'num_vars': '39'},
#  {'clean_name': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE WITH ONE TRIBE REPORTED FOR SELECTED TRIBES',
#   'label': 'PCT1.',
#   'num_vars': '54'},
#  {'clean_name': 'NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE OR IN COMBINATION WITH ONE OR MORE RACES, AND WITH ONE OR MORE NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER CATEGORIES FOR SELECTED GROUPS',
#   'label': 'PCT10.',
#   'num_vars': '14'},
#  {'clean_name': 'Hispanic Or Latino By Specific Origin',
#   'label': 'PCT11.',
#   'num_vars': '31'},
#  {'clean_name': 'Sex By Age', 'label': 'PCT12.', 'num_vars': '209'},
#  {'clean_name': 'Sex By Age (White Alone)',
#   'label': 'PCT12A.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Black Or African American Alone)',
#   'label': 'PCT12B.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (American Indian And Alaska Native Alone)',
#   'label': 'PCT12C.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Asian Alone)',
#   'label': 'PCT12D.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Native Hawaiian And Other Pacific Islander Alone)',
#   'label': 'PCT12E.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Some Other Race Alone)',
#   'label': 'PCT12F.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Two Or More Races)',
#   'label': 'PCT12G.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Hispanic Or Latino)',
#   'label': 'PCT12H.',
#   'num_vars': '209'},
#  {'clean_name': 'SEX BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT12I.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Black Or African American Alone, Not Hispanic Or Latino)',
#   'label': 'PCT12J.',
#   'num_vars': '209'},
#  {'clean_name': 'SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT12K.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Asian Alone, Not Hispanic Or Latino)',
#   'label': 'PCT12L.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Native Hawaiian And Other Pacific Islander Alone, Not Hispanic Or Latino)',
#   'label': 'PCT12M.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Some Other Race Alone, Not Hispanic Or Latino)',
#   'label': 'PCT12N.',
#   'num_vars': '209'},
#  {'clean_name': 'Sex By Age (Two Or More Races, Not Hispanic Or Latino)',
#   'label': 'PCT12O.',
#   'num_vars': '209'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS',
#   'label': 'PCT13.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'label': 'PCT13A.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'PCT13B.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'PCT13C.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (ASIAN ALONE)',
#   'label': 'PCT13D.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'PCT13E.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (SOME OTHER RACE ALONE)',
#   'label': 'PCT13F.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (TWO OR MORE RACES)',
#   'label': 'PCT13G.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (HISPANIC OR LATINO)',
#   'label': 'PCT13H.',
#   'num_vars': '49'},
#  {'clean_name': 'SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT13I.',
#   'num_vars': '49'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS',
#   'label': 'PCT14.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (WHITE ALONE HOUSEHOLDER)',
#   'label': 'PCT14A.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'label': 'PCT14B.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'label': 'PCT14C.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (ASIAN ALONE HOUSEHOLDER)',
#   'label': 'PCT14D.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'label': 'PCT14E.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'label': 'PCT14F.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (TWO OR MORE RACES HOUSEHOLDER)',
#   'label': 'PCT14G.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'PCT14H.',
#   'num_vars': '3'},
#  {'clean_name': 'PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'label': 'PCT14I.',
#   'num_vars': '3'},
#  {'clean_name': 'HUSBAND-WIFE AND UNMARRIED-PARTNER HOUSEHOLDS BY SEX OF PARTNER BY PRESENCE OF RELATED AND OWN CHILDREN UNDER 18 YEARS',
#   'label': 'PCT15.',
#   'num_vars': '34'},
#  {'clean_name': 'HOUSEHOLD TYPE BY NUMBER OF PEOPLE UNDER 18 YEARS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'label': 'PCT16.',
#   'num_vars': '26'},
#  {'clean_name': 'PRESENCE OF UNMARRIED PARTNER OF HOUSEHOLDER BY HOUSEHOLD TYPE FOR THE POPULATION UNDER 18 YEARS IN HOUSEHOLDS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'label': 'PCT17.',
#   'num_vars': '18'},
#  {'clean_name': 'NONFAMILY HOUSEHOLDS BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'label': 'PCT18.',
#   'num_vars': '15'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE',
#   'label': 'PCT19.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (WHITE ALONE)',
#   'label': 'PCT19A.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'PCT19B.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'PCT19C.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (ASIAN ALONE)',
#   'label': 'PCT19D.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'PCT19E.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (SOME OTHER RACE ALONE)',
#   'label': 'PCT19F.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (TWO OR MORE RACES)',
#   'label': 'PCT19G.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (HISPANIC OR LATINO)',
#   'label': 'PCT19H.',
#   'num_vars': '11'},
#  {'clean_name': 'NONRELATIVES BY HOUSEHOLD TYPE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT19I.',
#   'num_vars': '11'},
#  {'clean_name': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE WITH ONE OR MORE TRIBES REPORTED FOR SELECTED TRIBES',
#   'label': 'PCT2.',
#   'num_vars': '54'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE',
#   'label': 'PCT20.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (WHITE ALONE)',
#   'label': 'PCT20A.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'PCT20B.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'PCT20C.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (ASIAN ALONE)',
#   'label': 'PCT20D.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'PCT20E.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (SOME OTHER RACE ALONE)',
#   'label': 'PCT20F.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (TWO OR MORE RACES)',
#   'label': 'PCT20G.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (HISPANIC OR LATINO)',
#   'label': 'PCT20H.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT20I.',
#   'num_vars': '32'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY AGE BY GROUP QUARTERS TYPE',
#   'label': 'PCT21.',
#   'num_vars': '195'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER',
#   'label': 'PCT22.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (WHITE',
#   'label': 'PCT22A.',
#   'num_vars': 0},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'label': 'PCT22B.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'label': 'PCT22C.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (ASIAN',
#   'label': 'PCT22D.',
#   'num_vars': 0},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (NATIVEHAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'label': 'PCT22E.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'label': 'PCT22F.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (TWO OR MORE RACES)',
#   'label': 'PCT22G.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (HISPANIC OR LATINO)',
#   'label': 'PCT22H.',
#   'num_vars': '21'},
#  {'clean_name': 'GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'label': 'PCT22I.',
#   'num_vars': '21'},
#  {'clean_name': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE OR IN COMBINATION WITH ONE OR MORE OTHER RACES AND WITH ONE OR MORE TRIBES REPORTED FOR SELECTED TRIBES',
#   'label': 'PCT3.',
#   'num_vars': '54'},
#  {'clean_name': 'American Indian And Alaska Native Alone Or In Combination With One Or More Other Races',
#   'label': 'PCT4.',
#   'num_vars': '9'},
#  {'clean_name': 'ASIAN ALONE WITH ONE ASIAN CATEGORY FOR SELECTED GROUPS',
#   'label': 'PCT5.',
#   'num_vars': '22'},
#  {'clean_name': 'ASIAN ALONE WITH ONE OR MORE ASIAN CATEGORIES FOR SELECTED GROUPS',
#   'label': 'PCT6.',
#   'num_vars': '22'},
#  {'clean_name': 'ASIAN ALONE OR IN COMBINATION WITH ONE OR MORE OTHER RACES, AND WITH ONE OR MORE ASIAN CATEGORIES FOR SELECTED GROUPS',
#   'label': 'PCT7.',
#   'num_vars': '22'},
#  {'clean_name': 'Native Hawaiian And Other Pacific Islander Alone With One Native Hawaiian And Other Pacific Islander Category For Selected Groups',
#   'label': 'PCT8.',
#   'num_vars': '14'},
#  {'clean_name': 'Native Hawaiian And Other Pacific Islander Alone With One Or More Native Hawaiian And Other Pacific Islander Categories For Selected Groups',
#   'label': 'PCT9.',
#   'num_vars': '14'}]

# %%
df = DataFrame(k, columns=('label','clean_name','num_vars'))
df.head()
# Out:
#    label                                         clean_name num_vars
# 0    H1.                                      Housing Units        1
# 1   H10.         TOTAL POPULATION IN OCCUPIED HOUSING UNITS        1
# 2   H11.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4
# 3  H11A.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4
# 4  H11B.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4

# %%
import re

def sort_label(label):
    (l1, l2, l3) = re.search("([A-Z,a-z]+)(\d+)([A-Z,a-z]*)\.",label).groups()
    return l1 + " " + "{l2:03d}".format(l2=int(l2)) + l3

df['sort_label'] = df.label.apply(sort_label)

# %%
df[df.label.str.startswith("P5")]
# Out:
#     label                                         clean_name num_vars  \
# 232   P5.                  HISPANIC OR LATINO ORIGIN BY RACE       17
# 233  P50.                         ALLOCATION OF RELATIONSHIP        3
# 234  P51.  ALLOCATION OF POPULATION ITEMS FOR THE POPULAT...        3
#
#     sort_label
# 232      P 005
# 233      P 050
# 234      P 051

# %%
# let's go right for the variables and generate a dict, DF

from lxml import etree
from itertools import islice
from collections import OrderedDict

SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

doc = etree.parse(SF1_XML_PATH)
variables = doc.findall("//variable")

variables_dict = OrderedDict([(v.attrib['name'], 
                               {'concept':v.attrib['concept'],
                                'text': v.text
                                }) for v in variables])

# %%
variables_dict['P0050001']
# Out:
# {'concept': 'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  'text': ' Total population '}

# %%
def P005_range(n0,n1): 
    return tuple(('P005'+ "{i:04d}".format(i=i) for i in range(n0,n1)))

P005_vars = P005_range(1,18)
P005_vars_str = ",".join(P005_vars)

[(v,variables_dict[v]['text']) for v in P005_vars]
# Out:
# [('P0050001', ' Total population '),
#  ('P0050002', ' Not Hispanic or Latino: '),
#  ('P0050003', ' Not Hispanic or Latino: !! White alone '),
#  ('P0050004', ' Not Hispanic or Latino: !! Black or African American alone '),
#  ('P0050005',
#   ' Not Hispanic or Latino: !! American Indian and Alaska Native alone '),
#  ('P0050006', ' Not Hispanic or Latino: !! Asian alone '),
#  ('P0050007',
#   ' Not Hispanic or Latino: !! Native Hawaiian and Other Pacific Islander alone '),
#  ('P0050008', ' Not Hispanic or Latino: !! Some Other Race alone '),
#  ('P0050009', ' Not Hispanic or Latino: !! Two or More Races '),
#  ('P0050010', ' Hispanic or Latino: '),
#  ('P0050011', ' Hispanic or Latino: !! White alone '),
#  ('P0050012', ' Hispanic or Latino: !! Black or African American alone '),
#  ('P0050013',
#   ' Hispanic or Latino: !! American Indian and Alaska Native alone '),
#  ('P0050014', ' Hispanic or Latino: !! Asian alone '),
#  ('P0050015',
#   ' Hispanic or Latino: !! Native Hawaiian and Other Pacific Islander alone '),
#  ('P0050016', ' Hispanic or Latino: !! Some Other Race alone '),
#  ('P0050017', ' Hispanic or Latino: !! Two or More Races ')]

# %%
variables_df = DataFrame(variables_dict)
variables_df.head()
# Out:
#                                                   AIANHHCC  \
# concept                         Geographic Characteristics
# text      FIPS American Indian Area/Alaska Native Area/...
#
#                                                   AIANHHFP  \
# concept                         Geographic Characteristics
# text      American Indian Area/Alaska Native Area/Hawai...
#
#                                                    AIHHTLI  \
# concept                         Geographic Characteristics
# text      American Indian Trust Land/Hawaiian Home Land...
#
#                                                 AITS  \
# concept                   Geographic Characteristics
# text      American Indian Tribal Subdivision (FIPS)
#
#                                                     AITSCC  \
# concept                         Geographic Characteristics
# text      FIPS American Indian Tribal Subdivision Class...
#
#                                                 AITSCE  \
# concept                     Geographic Characteristics
# text      American Indian Tribal Subdivision (Census)
#
#                                                 ANRC  \
# concept                   Geographic Characteristics
# text      Alaska Native Regional Corporation (FIPS)
#
#                                                    CBSAPCI  \
# concept                         Geographic Characteristics
# text      Metropolitan Statistical Area/Micropolitan St...
#
#                                              CD113  \
# concept                 Geographic Characteristics
# text      Congressional District - 113th Congress
#
#                                    CNECTA  \
# concept        Geographic Characteristics
# text      New England City and Town Area
#
#                                ...                          \
# concept                        ...
# text                           ...
#
#                                                 PCT0090005  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Polynesian (500-519) & (500-599): !! Tongan (...
#
#                                                 PCT0090006  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Polynesian (500-519) & (500-599): !! Other Po...
#
#                                                 PCT0090007  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text          Micronesian (520-529, 531-541) & (500-599):
#
#                                                 PCT0090008  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Micronesian (520-529, 531-541) & (500-599): !...
#
#                                                 PCT0090009  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Micronesian (520-529, 531-541) & (500-599): !...
#
#                                                 PCT0090010  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Micronesian (520-529, 531-541) & (500-599): !...
#
#                                                 PCT0090011  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text                    Melanesian (542-546) & (500-599):
#
#                                                 PCT0090012  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Melanesian (542-546) & (500-599): !! Fijian (...
#
#                                                 PCT0090013  \
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Melanesian (542-546) & (500-599): !! Other Me...
#
#                                                 PCT0090014
# concept  PCT9. Native Hawaiian And Other Pacific Island...
# text      Other Pacific Islander, not specified (530, 5...
#
# [2 rows x 8945 columns]

# %%
variables_df.T.concept.apply(parse_concept_name)
# Out:
# AIANHHCC                                                   None
# AIANHHFP                                                   None
# AIHHTLI                                                    None
# AITS                                                       None
# AITSCC                                                     None
# AITSCE                                                     None
# ANRC                                                       None
# CBSAPCI                                                    None
# CD113                                                      None
# CNECTA                                                     None
# CONCITSC                                                   None
# GEOCOMP                                                    None
# LOGRECNO                                                   None
# MEMI                                                       None
# METDIV                                                     None
# NAME                                                       None
# NECTADIV                                                   None
# NECTAPCI                                                   None
# PLACECC                                                    None
# SLDL2                                                      None
# SLDL3                                                      None
# SLDL4                                                      None
# SLDU2                                                      None
# SLDU3                                                      None
# SLDU4                                                      None
# SUBMDCC                                                    None
# SUMLEV                                                     None
# UASC                                                       None
# UATYPE                                                     None
# UGA                                                        None
#                                     ...
# PCT0070021    {'label': 'PCT7.', 'clean_name': 'ASIAN ALONE ...
# PCT0070022    {'label': 'PCT7.', 'clean_name': 'ASIAN ALONE ...
# PCT0080001    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080002    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080003    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080004    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080005    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080006    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080007    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080008    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080009    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080010    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080011    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080012    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080013    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0080014    {'label': 'PCT8.', 'clean_name': 'Native Hawai...
# PCT0090001    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090002    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090003    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090004    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090005    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090006    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090007    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090008    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090009    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090010    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090011    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090012    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090013    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# PCT0090014    {'label': 'PCT9.', 'clean_name': 'Native Hawai...
# Name: concept, dtype: object

# %%
parse_concept_name(variables_dict['P0050001']['concept'])
# Out:
# {'clean_name': 'HISPANIC OR LATINO ORIGIN BY RACE',
#  'label': 'P5.',
#  'num_vars': '17'}

# %% [markdown]
# # api.json

# %%
# http://www.census.gov/developers/

import requests
url = "http://api.census.gov/data.json"
api_json = requests.get(url).json()
api_json
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@id': 'http://api.census.gov/data/2010/acs5.json',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'dataset': [{'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['acs5'],
#    'c_documentationLink': 'http://www.census.gov/developers/',
#    'c_geographyLink': 'http://api.census.gov/data/2010/acs5/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_tagsLink': 'http://api.census.gov/data/2010/acs5/tags.json',
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2010/acs5/variables.json',
#    'c_vintage': 2010,
#    'contactPoint': {'fn': 'Census Bureau Call Center',
#     'hasEmail': 'pio@census.gov'},
#    'description': "The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2010/acs5',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/2010acs5',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'US Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'US',
#    'temporal': '2010',
#    'title': '2010 American Community Survey: 5-Year Estimates'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'cochar6'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/pep/cochar6/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/pep/cochar6/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/pep/cochar6/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Population Estimates Branch',
#     'hasEmail': 'pop.population.estimates@census.gov'},
#    'description': "Annual County Resident Population Estimates for 6 Race Groups (5 Race Alone Groups and Two or More Races) by Five-Year Age Groups, Sex, and Hispanic Origin // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see http://www.census.gov/popest/data/historical/files/MRSF-01-US1.pdf. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/pep/cochar6',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/POPESTcochar62014',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-06-09',
#    'programCode': ['006:008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'April 1, 2010 - Current',
#    'title': 'Vintage 2014 Population Estimates: County Population Estimates by 5 Year Age Groups, Sex, 6 Races, and Hispanic Origin'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:007'],
#    'c_dataset': ['ewks'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2007/ewks/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2007/ewks/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2007/ewks/variables.json',
#    'c_vintage': 2007,
#    'contactPoint': {'fn': 'Economic Census Info',
#     'hasEmail': 'econ.2012@census.gov'},
#    'description': "The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2007/ewks',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/2007ewks',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2010-10-31',
#    'programCode': ['006-007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States of America',
#    'temporal': 'January 1992 - Current',
#    'title': '2007 Economic Census - All Sectors: Economy-Wide Key Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['acs5'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2013/acs5/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2013/acs5/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_tagsLink': 'http://api.census.gov/data/2013/acs5/tags.json',
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2013/acs5/variables.json',
#    'c_vintage': 2013,
#    'contactPoint': {'fn': 'American Community Survey Office',
#     'hasEmail': 'acso.users.support@census.gov'},
#    'description': "The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups. Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2013/acs5',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/ACSSF5Y2013',
#    'keyword': ['Income', 'Marital', 'Poverty'],
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-11-17',
#    'programCode': ['006:004'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2009/2013',
#    'title': '2009-2013 American Community Survey 5-Year Estimates'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['acs3'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2013/acs3/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2013/acs3/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_tagsLink': 'http://api.census.gov/data/2013/acs3/tags.json',
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2013/acs3/variables.json',
#    'c_vintage': 2013,
#    'contactPoint': {'fn': 'American Community Survey Office',
#     'hasEmail': 'acso.users.support@census.gov'},
#    'description': "The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics.  The 3-year data provide key estimates for each of the topic areas covered by the ACS for the nation, all 50 states, the District of Columbia, Puerto Rico, every congressional district, every metropolitan area, and all counties and places with populations of 20,000 or more.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties. For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2013/acs3',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/ACSSF3Y2013',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-08-14',
#    'programCode': ['006:004'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2011/2013',
#    'title': '2011-2013 American Community Survey - Summarized Data: 3-Year Summary File'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['timeseries', 'idb', '5year'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/timeseries/idb/5year/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/timeseries/idb/5year/geography.json',
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_isTimeseries': True,
#    'c_tagsLink': 'http://api.census.gov/data/timeseries/idb/5year/tags.json',
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/timeseries/idb/5year/variables.json',
#    'contactPoint': {'fn': 'Loraine West',
#     'hasEmail': 'loraine.a.west@census.gov'},
#    'description': 'Midyear population estimates and projections for all countries and areas of the world with a population of 5,000 or more // Source:  U.S. Census Bureau, Population Division // Release Date:  December 2013 // Note:  Total population available from 1950 to 2050 for all countries and areas.  Other demographic variables available from base year to 2050.  Base year varies by country and therefore, data are not available for all years for all countries.  See Methodology at http://www.census.gov/population/international/data/idb/informationGateway.php',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/timeseries/idb/5year',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/IDB5YR',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-02-06',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'Time Series',
#    'title': 'Time Series International Database: International Populations by 5 Year Age Groups and Sex'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'stchar6'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/pep/stchar6/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/pep/stchar6/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/pep/stchar6/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Population Estimates Branch',
#     'hasEmail': 'pop.population.estimates@census.gov'},
#    'description': "Annual State Resident Population Estimates for 6 Race Groups (5 Race Alone Groups and Two or More Races) by Age, Sex, and Hispanic Origin // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see http://www.census.gov/popest/data/historical/files/MRSF-01-US1.pdf. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/pep/stchar6',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/POPESTstchar62014',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-06-09',
#    'programCode': ['006:008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'April 1, 2010 - Current',
#    'title': 'Vintage 2014 Population Estimates: State Population Estimates by Single Year of Age, Sex, 6 Races, and Hispanic Origin'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['nonemp_old'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2012/nonemp_old/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2012/nonemp_old/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2012/nonemp_old/variables.json',
#    'c_vintage': 2012,
#    'contactPoint': {'fn': 'Nonemployer Statistics staff',
#     'hasEmail': 'epcd.nonemployer.statistics@census.gov'},
#    'description': "Nonemployer Statistics is an annual series that provides subnational economic data for businesses that have no paid employees and are subject to federal income tax. The data consist of the number of businesses and total receipts by industry. Most nonemployers are self-employed individuals operating unincorporated businesses (known as sole proprietorships), which may or may not be the owner's principal source of income. The majority of all business establishments in the United States are nonemployers, yet these firms average less than 4 percent of all sales and receipts nationally. Due to their small economic impact, these firms are excluded from most other Census Bureau business statistics (the primary exception being the Survey of Business Owners). The Nonemployers Statistics series is the primary resource available to study the scope and activities of nonemployers at a detailed geographic level. For complementary statistics on the firms that do have paid employees, refer to the County Business Patterns. Additional sources of data on small businesses include the Economic Census, and the Statistics of U.S. Businesses.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2012/nonemp_old',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/NONEMP2012_old',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2014-05-15',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2012/2012',
#    'title': '2012 Nonemployer Statistics: Nonemployer Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['eits', 'm3'],
#    'c_documentationLink': 'http://www.census.gov/developers/',
#    'c_geographyLink': 'http://api.census.gov/data/eits/m3/geography.json',
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_isTimeseries': True,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/eits/m3/variables.json',
#    'contactPoint': {'fn': 'Economic Indicators Mail List',
#     'hasEmail': 'econ.indicators@census.gov'},
#    'description': "The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/eits/m3',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/eitsm3',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'US Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'spatial': 'US',
#    'temporal': '2013',
#    'title': "Economic Indicators Time Series - Manufacturers' Shipments, Inventories, and Orders"},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['nonemp'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2011/nonemp/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2011/nonemp/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2011/nonemp/variables.json',
#    'c_vintage': 2011,
#    'contactPoint': {'fn': 'Nonemployer Statistics staff',
#     'hasEmail': 'epcd.nonemployer.statistics@census.gov'},
#    'description': "Nonemployer Statistics is an annual series that provides subnational economic data for businesses that have no paid employees and are subject to federal income tax. The data consist of the number of businesses and total receipts by industry. Most nonemployers are self-employed individuals operating unincorporated businesses (known as sole proprietorships), which may or may not be the owner's principal source of income. The majority of all business establishments in the United States are nonemployers, yet these firms average less than 4 percent of all sales and receipts nationally. Due to their small economic impact, these firms are excluded from most other Census Bureau business statistics (the primary exception being the Survey of Business Owners). The Nonemployers Statistics series is the primary resource available to study the scope and activities of nonemployers at a detailed geographic level. For complementary statistics on the firms that do have paid employees, refer to the County Business Patterns. Additional sources of data on small businesses include the Economic Census, and the Statistics of U.S. Businesses.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2011/nonemp',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/NONEMP2011',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-01-29',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2011/2011',
#    'title': '2011 Nonemployer Statistics: Non Employer Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'prcagesex'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/pep/prcagesex/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/pep/prcagesex/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/pep/prcagesex/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Population Estimates Branch',
#     'hasEmail': 'pop.population.estimates@census.gov'},
#    'description': "Annual Estimates of the Resident Population by Single Year of Age and Sex for Puerto Rico // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/pep/prcagesex',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/POPESTprcagesex2014',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-06-09',
#    'programCode': ['006:008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'April 1, 2010 - Current',
#    'title': 'Vintage 2014 Population Estimates: Puerto Rico Commonwealth Estimates by Single Year of Age and Sex'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['sf1'],
#    'c_documentationLink': 'http://www.census.gov/developers/',
#    'c_geographyLink': 'http://api.census.gov/data/1990/sf1/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_tagsLink': 'http://api.census.gov/data/1990/sf1/tags.json',
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/1990/sf1/variables.json',
#    'c_vintage': 1990,
#    'contactPoint': {'fn': 'Census Bureau Call Center',
#     'hasEmail': 'pio@census.gov'},
#    'description': 'Data files available from Census 2000 and the 2010 Census. This file presents 100-percent population and housing figures for the total population, for 63 race categories, and for many other race and Hispanic or Latino categories. This includes age, sex, households, household relationship, housing units, occupancy status, and tenure (whether the residence is owned or rented). Also included are selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, blocks, metropolitan areas (2000), core based statistical areas (2010), American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and ZIP Code Tabulation Areas. Data are available down to the block level for many tabulations, but only to the census-tract level for others. The 2010 Census SF 1 has some tables on the population in group quarters that are available only to the county level. Available on DVD and American FactFinder.  The Census 2000 Summary File 1 data were released in three stages. Individual state files and two national files were released. The state-level data were released first, followed by the Advance National File, which covered the same data subjects, but includes national level summary data for areas that cross state boundaries such as whole metropolitan areas, whole American Indian areas, etc. The Final National File contains the same data subjects and geographic areas as the Advance National File, but adds the first available urban/rural and urbanized area data. For the most current release dates for these files, see the "Census 2000 Release Schedule" link on the AFFAmerican FactFinder Main Page.  The 2010 Census Summaray File 1 data were released in stages. Individual state files and a national update were released in 2011. The SF 1 urban/rural update is planned for release in Fall 2012. This file contains the same data subjects as the previously released files, but for additional geography, including the urban and rural parts of the United States, regions, divisions, states, counties, and places; and urbanized areas and urban clusters. See the 2010 Census Data Products At A Glance',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/1990/sf1',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/1990sf1',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'US',
#    'temporal': '1990',
#    'title': '1990 Decennial: Summary File 1'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['cbp'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2008/cbp/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2008/cbp/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2008/cbp/variables.json',
#    'c_vintage': 2008,
#    'contactPoint': {'fn': 'CBP Staff',
#     'hasEmail': 'epcd.county.business.patterns@census.gov'},
#    'description': 'County Business Patterns (CBP) is an annual series that provides economic data by industry at the U.S., State, County and Metropolitan Area levels. This series includes the number of establishments, employment during the week of March 12, first quarter payroll, and annual payroll. CBP provides statistics for businesses with paid employees for the U.S., Puerto Rico, and the Island Areas.',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2008/cbp',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/CBP_2008',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-01-13',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2008/2008',
#    'title': '2008 County Business Patterns: Business Patterns'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'stchar6'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2013/pep/stchar6/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2013/pep/stchar6/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2013/pep/stchar6/variables.json',
#    'c_vintage': 2013,
#    'contactPoint': {'fn': 'Population Estimates Branch',
#     'hasEmail': 'pop.population.estimates@census.gov'},
#    'description': "Annual State Resident Population Estimates for 6 Race Groups (5 Race Alone Groups and Two or More Races) by Age, Sex, and Hispanic Origin: April 1, 2010 to July 1, 2013 // File: 7/1/2013 State Characteristics Population Estimates // Source: U.S. Census Bureau, Population Division // Release Date: June 2014 // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see http://www.census.gov/popest/data/historical/files/MRSF-01-US1.pdf. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2013/pep/stchar6',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/POPESTstchar62013',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-10-22',
#    'programCode': ['006:008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'April 1, 2010 - Current',
#    'title': 'Vintage 2013 Population Estimates: State Population Estimates by Single Year of Age, Sex, 6 Races, and Hispanic Origin'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['ewks'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2012/ewks/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2012/ewks/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2012/ewks/variables.json',
#    'c_vintage': 2012,
#    'contactPoint': {'fn': 'Economic Census Info',
#     'hasEmail': 'econ.2012@census.gov'},
#    'description': "The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2012/ewks',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/EconCensusEWKS2012',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2014-04-06',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'January 1992 - Current',
#    'title': '2012 Economic Census - All Sectors: Economy-Wide Key Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['bds', 'firms'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/bds/firms/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/bds/firms/geography.json',
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_isTimeseries': True,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/bds/firms/variables.json',
#    'contactPoint': {'fn': 'Javier Miranda', 'hasEmail': 'ces.bds@census.gov'},
#    'description': 'The Business Dynamics Statistics (BDS) is a public use data set of annual aggregate statistics describing establishment openings and closings, firm startups, job creation and destruction by firm size, age, industrial sector, and state. For more information about the dataset set http://www.census.gov/ces/dataproducts/bds/index.html',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/bds/firms',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/BDSFirms',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-09-09',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '1977 - Current',
#    'title': 'Time Series Business Dynamics Statistics: Firm Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['intltrade', 'istnaics'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/intltrade/istnaics/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/intltrade/istnaics/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/intltrade/istnaics/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Foreign Trade Staff',
#     'hasEmail': 'EID.International.Trade.Data@census.gov'},
#    'description': 'This international trade file provides the annual dollar value of imports of goods for all U.S. trade partners by state of destination for imports.   It also provides these state totals by 4-digit NAICS based industry group.  Data in this file spans from 2010 to 2014.  Users can find this data and more by going to usatrade.census.gov.  If you have any questions regarding U.S. international trade data, please call us at 1(800)549-0595 option #4 or email us at eid.international.trade.data@census.gov.',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/intltrade/istnaics',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/ftd14istnaics',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-07-20',
#    'programCode': ['000:000'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2014/2014',
#    'title': '2014 International Trade: State Imports for NAICS4 Database'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'housing'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2013/pep/housing/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2013/pep/housing/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
# ...
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2012/popproj/pop',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/2012popproj/pop',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-05-15',
#    'programCode': ['006-008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States of America',
#    'temporal': 'July 1, 2012 - July 1, 2060',
#    'title': 'Vintage 2012 Population Projections - : Projected Population by Single Year of Age'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['eits', 'ressales'],
#    'c_documentationLink': 'http://www.census.gov/developers/',
#    'c_geographyLink': 'http://api.census.gov/data/eits/ressales/geography.json',
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_isTimeseries': True,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/eits/ressales/variables.json',
#    'contactPoint': {'fn': 'Economic Indicators Mail List',
#     'hasEmail': 'econ.indicators@census.gov'},
#    'description': "The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/eits/ressales',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/eitsresales',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'US Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'spatial': 'US',
#    'temporal': '2013',
#    'title': 'Economic Indicators Time Series - New Home Sales'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['intltrade', 'imp_exp'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/intltrade/imp_exp/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/intltrade/imp_exp/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/intltrade/imp_exp/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Foreign Trade Staff',
#     'hasEmail': 'EID.International.Trade.Data@census.gov'},
#    'description': 'This international trade file provides the annual dollar value of U.S. exports and imports of goods for all U.S. trade partners.  It also provides the annual dollar value of U.S. exports and imports of manufactured goods for all U.S. trade partners.  You can find this data and more by going to usatrade.census.gov.  If you have any questions regarding U.S. international trade data, please call us at 1(800)549-0595 option #4 or email us at eid.international.trade.data@census.gov.',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/intltrade/imp_exp',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/ftdImpExpHist',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2015-07-20',
#    'programCode': ['000:000'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2014/2014',
#    'title': '2014 International Trade: Historical Imports and Exports'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['ewks'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2002/ewks/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2002/ewks/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2002/ewks/variables.json',
#    'c_vintage': 2002,
#    'contactPoint': {'fn': 'Economic Census Info',
#     'hasEmail': 'econ.2012@census.gov'},
#    'description': "The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2002/ewks',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/EconCensusEWKS2002',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2014-10-06',
#    'programCode': ['006:007'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'January 1992 - Current',
#    'title': '2002 Economic Census - All Sectors: Economy-Wide Key Statistics'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['pep', 'natstprc'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2014/pep/natstprc/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2014/pep/natstprc/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isCube': True,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2014/pep/natstprc/variables.json',
#    'c_vintage': 2014,
#    'contactPoint': {'fn': 'Population Estimates Branch',
#     'hasEmail': 'pop.population.estimates@census.gov'},
#    'description': 'Annual Population Estimates, Estimated Components of Resident Population Change, and Rates of the Components of Resident Population Change for the United States, States, and Puerto Rico // Source: U.S. Census Bureau, Population Division // Note: Total population change includes a residual. This residual represents the change in population that cannot be attributed to any specific demographic component. See Population Estimates Terms and Definitions at http://www.census.gov/popest/about/terms.html. // Net international migration (except for Puerto Rico) includes the international migration of both native and foreign-born populations. Specifically, it includes: (a) the net international migration of the foreign born, (b) the net migration between the United States and Puerto Rico, (c) the net migration of natives to and from the United States, and (d) the net movement of the Armed Forces population between the United States and overseas. Net international migration for Puerto Rico includes the migration of native and foreign-born populations between the United States and Puerto Rico. // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. See Geographic Terms and Definitions at http://www.census.gov/popest/about/geo/terms.html for a list of the states that are included in each region and division. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureaus Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2014) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.',
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2014/pep/natstprc',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/POPESTnatstprc2014',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public Domain',
#    'modified': '2014-12-15',
#    'programCode': ['006:008'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': 'April 1, 2010 - Current',
#    'title': 'Vintage 2014 Population Estimates: US, State, and PR Total Population and Components of Change'},
#   {'@type': 'dcat:Dataset',
#    'accessLevel': 'public',
#    'bureauCode': ['006:07'],
#    'c_dataset': ['acs5', 'profile'],
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_examplesLink': 'http://api.census.gov/data/2013/acs5/profile/examples.json',
#    'c_geographyLink': 'http://api.census.gov/data/2013/acs5/profile/geography.json',
#    'c_isAggregate': True,
#    'c_isAvailable': False,
#    'c_isReleased': False,
#    'c_unavailableMessage': 'This dataset is currently unavailable.',
#    'c_variablesLink': 'http://api.census.gov/data/2013/acs5/profile/variables.json',
#    'c_vintage': 2013,
#    'contactPoint': {'fn': 'American Community Survey Office',
#     'hasEmail': 'acso.users.support@census.gov'},
#    'description': "The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups. Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties. For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://api.census.gov/data/2013/acs5/profile',
#      'description': 'API endpoint',
#      'format': 'API',
#      'mediaType': 'application/json',
#      'title': 'API endpoint'}],
#    'identifier': 'http://api.census.gov/data/id/ACSProfile5Y2013',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/',
#    'modified': '2014-11-03',
#    'programCode': ['006:004'],
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Census Bureau',
#     'subOrganizationOf': {'@type': 'org:Organization',
#      'name': 'U.S. Department Of Commerce',
#      'subOrganizationOf': {'@type': 'org:Organization',
#       'name': 'U.S. Government'}}},
#    'references': ['http://www.census.gov/developers/'],
#    'spatial': 'United States',
#    'temporal': '2009/2013',
#    'title': '2009-2013 American Community Survey 5-Year Profiles'}],
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'}

# %%
len(api_json)
# Out:
# 6

# %%
api_json.keys()
# Out:
# dict_keys(['@context', '@type', '@id', 'conformsTo', 'dataset', 'describedBy'])

# %%
len(api_json.get('dataset'))
# Out:
# 95

# %%
df = DataFrame(api_json.get('dataset'))
df.columns
# Out:
# Index(['@type', 'accessLevel', 'bureauCode', 'c_dataset',
#        'c_documentationLink', 'c_examplesLink', 'c_geographyLink',
#        'c_isAggregate', 'c_isAvailable', 'c_isCube', 'c_isReleased',
#        'c_isTimeseries', 'c_tagsLink', 'c_unavailableMessage',
#        'c_variablesLink', 'c_vintage', 'contactPoint', 'description',
#        'distribution', 'identifier', 'keyword', 'license', 'modified',
#        'programCode', 'publisher', 'references', 'spatial', 'temporal',
#        'title'],
#       dtype='object')

# %%
# don't know why there's no 2010 census
df[df.title.apply(lambda s:'census' in s.lower())][['title']]
# Out:
#                                                 title
# 2   2007 Economic Census - All Sectors: Economy-Wi...
# 14  2012 Economic Census - All Sectors: Economy-Wi...
# 20  1990 Decennial Census of Population and Housin...
# 25         2015 Census Planning Database: Block Group
# 87         2015 Census Planning Database: Tract Level
# 92  2002 Economic Census - All Sectors: Economy-Wi...

# %%
df[['c_vintage', 'title']]
# Out:
#     c_vintage                                              title
# 0        2010   2010 American Community Survey: 5-Year Estimates
# 1        2014  Vintage 2014 Population Estimates: County Popu...
# 2        2007  2007 Economic Census - All Sectors: Economy-Wi...
# 3        2013  2009-2013 American Community Survey 5-Year Est...
# 4        2013  2011-2013 American Community Survey - Summariz...
# 5         NaN  Time Series International Database: Internatio...
# 6        2014  Vintage 2014 Population Estimates: State Popul...
# 7        2012  2012 Nonemployer Statistics: Nonemployer Stati...
# 8         NaN  Economic Indicators Time Series - Manufacturer...
# 9        2011  2011 Nonemployer Statistics: Non Employer Stat...
# 10       2014  Vintage 2014 Population Estimates: Puerto Rico...
# 11       1990                     1990 Decennial: Summary File 1
# 12       2008   2008 County Business Patterns: Business Patterns
# 13       2013  Vintage 2013 Population Estimates: State Popul...
# 14       2012  2012 Economic Census - All Sectors: Economy-Wi...
# 15        NaN  Time Series Business Dynamics Statistics: Firm...
# 16       2014  2014 International Trade: State Imports for NA...
# 17       2013  Vintage 2013 Population Estimates: Housing Uni...
# 18        NaN  Economic Indicators Time Series - Quarterly Se...
# 19        NaN  Economic Indicators Time Series - Construction...
# 20       1990  1990 Decennial Census of Population and Housin...
# 21       2013  Vintage 2013 Population Estimates: National Mo...
# 22        NaN  Economic Indicators Time Series - Manufacturin...
# 23        NaN  Time Series Annual Survey of Manufactures: Sta...
# 24        NaN  Economic Indicators Time Series - Quarterly Fi...
# 25       2015         2015 Census Planning Database: Block Group
# 26       2014  Vintage 2014 Population Estimates: Puerto Rico...
# 27        NaN  Economic Indicators Time Series - Advance Mont...
# 28        NaN  Economic Indicators Time Series - Housing Vaca...
# 29       2014  Vintage 2014 Population Estimates: Puerto Rico...
# ..        ...                                                ...
# 65        NaN  Time Series International Database: Internatio...
# 66       2012   2012 County Business Patterns: Business Patterns
# 67       2011   2011 American Community Survey: 5-Year Estimates
# 68        NaN  Time Series Current Population Survey: Poverty...
# 69       2011   2011 County Business Patterns: Business Patterns
# 70        NaN  Economic Indicators Time Series - Manufactured...
# 71       2012  2008-2012 American Community Survey - Summariz...
# 72       2013  Vintage 2013 Population Estimates: Puerto Rico...
# 73        NaN  Economic Indicators Time Series - Monthly Whol...
# 74       2013  Vintage 2013 Population Estimates: Puerto Rico...
# 75       2011  2011 American Community Survey 1-Year Profiles...
# 76       2010  2010 Nonemployer Statistics: Non Employer Stat...
# 77       2012  2012 American Community Survey: 1-Year Profile...
# 78        NaN  Economic Indicators Time Series - New Resident...
# 79       2013  Vintage 2013 Population Estimates: US, State, ...
# 80       2014  Vintage 2014 Population Estimates: County Tota...
# 81       2013  Vintage 2013 Population Estimates: Subcounty P...
# 82       2012  2012 American Community Survey: 3-Year Profile...
# 83        NaN  Economic Indicators Time Series - Quarterly Su...
# 84        NaN  Economic Indicators Time Series - U.S. Interna...
# 85       2013  Vintage 2013 Population Estimates: Puerto Rico...
# 86       2000                     2000 Decennial: Summary File 1
# 87       2015         2015 Census Planning Database: Tract Level
# 88       2009  2009 Nonemployer Statistics: Non Employer Stat...
# 89       2012  Vintage 2012 Population Projections - : Projec...
# 90        NaN   Economic Indicators Time Series - New Home Sales
# 91       2014  2014 International Trade: Historical Imports a...
# 92       2002  2002 Economic Census - All Sectors: Economy-Wi...
# 93       2014  Vintage 2014 Population Estimates: US, State, ...
# 94       2013  2009-2013 American Community Survey 5-Year Pro...
#
# [95 rows x 2 columns]

# %%
# good way to see list of datasets
sorted(list(df['title'],))
# Out:
# ['1990 Decennial Census of Population and Housing - Summary File 3: Summary File 3',
#  '1990 Decennial: Summary File 1',
#  '2000 Decennial: Summary File 1',
#  '2000 Decennial: Summary File 3',
#  '2002 Economic Census - All Sectors: Economy-Wide Key Statistics',
#  '2007 Economic Census - All Sectors: Economy-Wide Key Statistics',
#  '2008 County Business Patterns: Business Patterns',
#  '2008 Nonemployer Statistics: Non Employer Statistics',
#  '2008-2012 American Community Survey - Summarized Data: 5-Year Summary File',
#  '2009 County Business Patterns: Business Patterns',
#  '2009 Nonemployer Statistics: Non Employer Statistics',
#  '2009-2013 American Community Survey 5-Year Estimates',
#  '2009-2013 American Community Survey 5-Year Profiles',
#  '2010 American Community Survey: 5-Year Estimates',
#  '2010 County Business Patterns: Business Patterns',
#  '2010 Decennial: Summary File 1',
#  '2010 Nonemployer Statistics: Non Employer Statistics',
#  '2011 American Community Survey 1-Year Profiles for the 113th Congressional Districts',
#  '2011 American Community Survey: 5-Year Estimates',
#  '2011 County Business Patterns: Business Patterns',
#  '2011 Nonemployer Statistics: Non Employer Statistics',
#  '2011-2013 American Community Survey - Data Profiles: 3-Year Data Profile',
#  '2011-2013 American Community Survey - Summarized Data: 3-Year Summary File',
#  '2012 American Community Survey: 1-Year Estimates',
#  '2012 American Community Survey: 1-Year Profile Tables',
#  '2012 American Community Survey: 3-Year Estimates',
#  '2012 American Community Survey: 3-Year Profile Tables',
#  '2012 American Community Survey: 5-Year Profile Tables',
#  '2012 County Business Patterns: Business Patterns',
#  '2012 Economic Census - All Sectors: Economy-Wide Key Statistics',
#  '2012 Nonemployer Statistics: Non Employer Statistics',
#  '2012 Nonemployer Statistics: Nonemployer Statistics',
#  '2012 Public Elementary-Secondary Education Finance: Individual Unit Tables',
#  '2013 American Community Survey - Data Profiles: 1-Year Data Profile',
#  '2013 American Community Survey - Summarized Data: 1-Year Summary File',
#  '2013 County Business Patterns: Business Patterns',
#  '2013 Nonemployer Statistics: Non Employer Statistics',
#  '2014 International Trade: Historical Imports and Exports',
#  '2014 International Trade: State Exports for NAICS4 Database',
#  '2014 International Trade: State Imports for NAICS4 Database',
#  '2015 Census Planning Database: Block Group',
#  '2015 Census Planning Database: Tract Level',
#  'Economic Indicators Time Series - Advance Monthly Sales for Retail and Food Services',
#  'Economic Indicators Time Series - Construction Spending',
#  'Economic Indicators Time Series - Housing Vacancies and Homeownership',
#  'Economic Indicators Time Series - Manufactured Homes Survey',
#  "Economic Indicators Time Series - Manufacturers' Shipments, Inventories, and Orders",
#  'Economic Indicators Time Series - Manufacturing and Trade Inventories and Sales',
#  'Economic Indicators Time Series - Monthly Retail Trade and Food Services',
#  'Economic Indicators Time Series - Monthly Wholesale Trade: Sales and Inventories',
#  'Economic Indicators Time Series - New Home Sales',
#  'Economic Indicators Time Series - New Residential Construction',
#  'Economic Indicators Time Series - Quarterly Financial Report',
#  'Economic Indicators Time Series - Quarterly Services Survey',
#  'Economic Indicators Time Series - Quarterly Summary of State & Local Taxes',
#  'Economic Indicators Time Series - Quarterly Survey of Public Pensions',
#  'Economic Indicators Time Series - U.S. International Trade in Goods and Services',
#  'Time Series Annual Survey of Manufactures: Statistics for All Manufacturing by State',
#  'Time Series Business Dynamics Statistics: Firm Statistics',
#  'Time Series Current Population Survey: Poverty Status',
#  'Time Series International Database: International Populations by 5 Year Age Groups and Sex',
#  'Time Series International Database: International Populations by Single Year of Age and Sex',
#  'Time Series Small Area Income and Poverty Estimates: State and County',
#  'Vintage 2012 Population Projections - : Projected Births',
#  'Vintage 2012 Population Projections - : Projected Deaths',
#  'Vintage 2012 Population Projections - : Projected Net International Migration by Single Year of age',
#  'Vintage 2012 Population Projections - : Projected Population by Single Year of Age',
#  'Vintage 2013 Population Estimates: County Population Estimates by 5 Year Age Groups, Sex, 5 Races, and Hispanic Origin',
#  'Vintage 2013 Population Estimates: County Population Estimates by 5 Year Age Groups, Sex, 6 Races, and Hispanic Origin',
#  'Vintage 2013 Population Estimates: County Total Population and Components of Change',
#  'Vintage 2013 Population Estimates: Housing Unit Estimates for US, States, and Counties',
#  'Vintage 2013 Population Estimates: National Monthly Population Estimates by Single Year of Age , Sex, 5 Races, Hispanic Origin, and Universe',
#  'Vintage 2013 Population Estimates: National Monthly Population Estimates by Single Year of Age, Sex, 6 Races, Hispanic Origin, and Universe',
#  'Vintage 2013 Population Estimates: Puerto Rico Commonwealth Estimates by Single Year of Age and Sex',
#  'Vintage 2013 Population Estimates: Puerto Rico Municipios Estimates by 5-Year Age Groups and Sex',
#  'Vintage 2013 Population Estimates: Puerto Rico Municipios Total Population',
#  'Vintage 2013 Population Estimates: State Population Estimates by Single Year of Age, Sex, 5 Races, and Hispanic Origin',
#  'Vintage 2013 Population Estimates: State Population Estimates by Single Year of Age, Sex, 6 Races, and Hispanic Origin',
#  'Vintage 2013 Population Estimates: Subcounty Population Places and MCDs',
#  'Vintage 2013 Population Estimates: US, State, and PR Population Age 18+',
#  'Vintage 2013 Population Estimates: US, State, and PR Total Population and Components of Change',
#  'Vintage 2014 Population Estimates: County Population Estimates by 5 Year Age Groups, Sex, 5 Races, and Hispanic Origin',
#  'Vintage 2014 Population Estimates: County Population Estimates by 5 Year Age Groups, Sex, 6 Races, and Hispanic Origin',
#  'Vintage 2014 Population Estimates: County Total Population and Components of Change',
#  'Vintage 2014 Population Estimates: Housing Unit Estimates for US, States, and Counties',
#  'Vintage 2014 Population Estimates: National Monthly Population Estimates by Single Year of Age , Sex, 5 Races, Hispanic Origin, and Universe',
#  'Vintage 2014 Population Estimates: National Monthly Population Estimates by Single Year of Age, Sex, 6 Races, Hispanic Origin, and Universe',
#  'Vintage 2014 Population Estimates: Puerto Rico Commonwealth Estimates by Single Year of Age and Sex',
#  'Vintage 2014 Population Estimates: Puerto Rico Municipios Estimates by 5-Year Age Groups and Sex',
#  'Vintage 2014 Population Estimates: Puerto Rico Municipios Total Population',
#  'Vintage 2014 Population Estimates: State Population Estimates by Single Year of Age, Sex, 5 Races, and Hispanic Origin',
#  'Vintage 2014 Population Estimates: State Population Estimates by Single Year of Age, Sex, 6 Races, and Hispanic Origin',
#  'Vintage 2014 Population Estimates: Subcounty Population Places and MCDs',
#  'Vintage 2014 Population Estimates: US, State, and PR Population Age 18+',
#  'Vintage 2014 Population Estimates: US, State, and PR Total Population and Components of Change']

# %% [markdown]
# # variables.json

# %%
import requests
url = "http://api.census.gov/data/2010/sf1/variables.json"
var_json = requests.get(url).json()
sorted(var_json['variables'].keys())
# Out:
# ['AIANHH',
#  'AIANHHCC',
#  'AIANHHFP',
#  'AIHHTLI',
#  'AITS',
#  'AITSCC',
#  'AITSCE',
#  'ANRC',
#  'BLKGRP',
#  'BLOCK',
#  'CBSA',
#  'CBSAPCI',
#  'CD',
#  'CD113',
#  'CNECTA',
#  'CONCIT',
#  'CONCITSC',
#  'COUNTY',
#  'COUSUB',
#  'CSA',
#  'DIVISION',
#  'GEOCOMP',
#  'H00010001',
#  'H0020001',
#  'H0020002',
#  'H0020003',
#  'H0020004',
#  'H0020005',
#  'H0020006',
#  'H0030001',
#  'H0030002',
#  'H0030003',
#  'H0040001',
#  'H0040002',
#  'H0040003',
#  'H0040004',
#  'H0050001',
#  'H0050002',
#  'H0050003',
#  'H0050004',
#  'H0050005',
#  'H0050006',
#  'H0050007',
#  'H0050008',
#  'H0060001',
#  'H0060002',
#  'H0060003',
#  'H0060004',
#  'H0060005',
#  'H0060006',
#  'H0060007',
#  'H0060008',
#  'H0070001',
#  'H0070002',
#  'H0070003',
#  'H0070004',
#  'H0070005',
#  'H0070006',
#  'H0070007',
#  'H0070008',
#  'H0070009',
#  'H0070010',
#  'H0070011',
#  'H0070012',
#  'H0070013',
#  'H0070014',
#  'H0070015',
#  'H0070016',
#  'H0070017',
#  'H0080001',
#  'H0080002',
#  'H0080003',
#  'H0080004',
#  'H0080005',
#  'H0080006',
#  'H0080007',
#  'H0090001',
#  'H0090002',
#  'H0090003',
#  'H0090004',
#  'H0090005',
#  'H0090006',
#  'H0090007',
#  'H0090008',
#  'H0090009',
#  'H0090010',
#  'H0090011',
#  'H0090012',
#  'H0090013',
#  'H0090014',
#  'H0090015',
#  'H0100001',
#  'H0110001',
#  'H0110002',
#  'H0110003',
#  'H0110004',
#  'H011A0001',
#  'H011A0002',
#  'H011A0003',
#  'H011A0004',
#  'H011B0001',
#  'H011B0002',
#  'H011B0003',
#  'H011B0004',
#  'H011C0001',
#  'H011C0002',
#  'H011C0003',
#  'H011C0004',
#  'H011D0001',
#  'H011D0002',
#  'H011D0003',
#  'H011D0004',
#  'H011E0001',
#  'H011E0002',
#  'H011E0003',
#  'H011E0004',
#  'H011F0001',
#  'H011F0002',
#  'H011F0003',
#  'H011F0004',
#  'H011G0001',
#  'H011G0002',
#  'H011G0003',
#  'H011G0004',
#  'H011H0001',
#  'H011H0002',
#  'H011H0003',
#  'H011H0004',
#  'H011I0001',
#  'H011I0002',
#  'H011I0003',
#  'H011I0004',
#  'H0120001',
#  'H0120002',
#  'H0120003',
#  'H012A0001',
#  'H012A0002',
#  'H012A0003',
#  'H012B0001',
#  'H012B0002',
#  'H012B0003',
#  'H012C0001',
#  'H012C0002',
#  'H012C0003',
#  'H012D0001',
#  'H012D0002',
#  'H012D0003',
#  'H012E0001',
#  'H012E0002',
#  'H012E0003',
#  'H012F0001',
#  'H012F0002',
#  'H012F0003',
#  'H012G0001',
#  'H012G0002',
#  'H012G0003',
#  'H012H0001',
#  'H012H0002',
#  'H012H0003',
#  'H012I0001',
#  'H012I0002',
#  'H012I0003',
#  'H0130001',
#  'H0130002',
#  'H0130003',
#  'H0130004',
#  'H0130005',
#  'H0130006',
#  'H0130007',
#  'H0130008',
#  'H0140001',
#  'H0140002',
#  'H0140003',
#  'H0140004',
#  'H0140005',
#  'H0140006',
#  'H0140007',
#  'H0140008',
#  'H0140009',
#  'H0140010',
#  'H0140011',
#  'H0140012',
#  'H0140013',
#  'H0140014',
#  'H0140015',
#  'H0140016',
#  'H0140017',
#  'H0150001',
#  'H0150002',
#  'H0150003',
#  'H0150004',
#  'H0150005',
#  'H0150006',
#  'H0150007',
#  'H0160001',
#  'H0160002',
#  'H0160003',
#  'H0160004',
#  'H0160005',
#  'H0160006',
#  'H0160007',
#  'H0160008',
#  'H0160009',
#  'H0160010',
#  'H0160011',
#  'H0160012',
#  'H0160013',
#  'H0160014',
#  'H0160015',
#  'H0160016',
#  'H0160017',
#  'H016A0001',
#  'H016A0002',
#  'H016A0003',
#  'H016A0004',
#  'H016A0005',
#  'H016A0006',
#  'H016A0007',
#  'H016A0008',
#  'H016A0009',
#  'H016A0010',
#  'H016A0011',
#  'H016A0012',
#  'H016A0013',
#  'H016A0014',
#  'H016A0015',
#  'H016A0016',
#  'H016A0017',
#  'H016B0001',
#  'H016B0002',
#  'H016B0003',
#  'H016B0004',
#  'H016B0005',
#  'H016B0006',
#  'H016B0007',
#  'H016B0008',
#  'H016B0009',
#  'H016B0010',
#  'H016B0011',
#  'H016B0012',
#  'H016B0013',
#  'H016B0014',
#  'H016B0015',
#  'H016B0016',
#  'H016B0017',
#  'H016C0001',
#  'H016C0002',
#  'H016C0003',
#  'H016C0004',
#  'H016C0005',
#  'H016C0006',
#  'H016C0007',
#  'H016C0008',
#  'H016C0009',
#  'H016C0010',
#  'H016C0011',
#  'H016C0012',
#  'H016C0013',
#  'H016C0014',
#  'H016C0015',
#  'H016C0016',
#  'H016C0017',
#  'H016D0001',
#  'H016D0002',
#  'H016D0003',
#  'H016D0004',
#  'H016D0005',
#  'H016D0006',
#  'H016D0007',
#  'H016D0008',
#  'H016D0009',
#  'H016D0010',
#  'H016D0011',
#  'H016D0012',
#  'H016D0013',
#  'H016D0014',
#  'H016D0015',
#  'H016D0016',
#  'H016D0017',
#  'H016E0001',
#  'H016E0002',
#  'H016E0003',
#  'H016E0004',
#  'H016E0005',
#  'H016E0006',
#  'H016E0007',
#  'H016E0008',
#  'H016E0009',
#  'H016E0010',
#  'H016E0011',
#  'H016E0012',
#  'H016E0013',
#  'H016E0014',
#  'H016E0015',
#  'H016E0016',
#  'H016E0017',
#  'H016F0001',
#  'H016F0002',
#  'H016F0003',
#  'H016F0004',
#  'H016F0005',
#  'H016F0006',
#  'H016F0007',
#  'H016F0008',
#  'H016F0009',
#  'H016F0010',
#  'H016F0011',
#  'H016F0012',
#  'H016F0013',
#  'H016F0014',
#  'H016F0015',
#  'H016F0016',
#  'H016F0017',
#  'H016G0001',
#  'H016G0002',
#  'H016G0003',
#  'H016G0004',
#  'H016G0005',
#  'H016G0006',
#  'H016G0007',
#  'H016G0008',
#  'H016G0009',
#  'H016G0010',
#  'H016G0011',
#  'H016G0012',
#  'H016G0013',
#  'H016G0014',
#  'H016G0015',
#  'H016G0016',
#  'H016G0017',
#  'H016H0001',
#  'H016H0002',
#  'H016H0003',
#  'H016H0004',
#  'H016H0005',
#  'H016H0006',
#  'H016H0007',
#  'H016H0008',
#  'H016H0009',
#  'H016H0010',
#  'H016H0011',
#  'H016H0012',
#  'H016H0013',
#  'H016H0014',
#  'H016H0015',
#  'H016H0016',
#  'H016H0017',
#  'H016I0001',
#  'H016I0002',
#  'H016I0003',
#  'H016I0004',
#  'H016I0005',
#  'H016I0006',
#  'H016I0007',
#  'H016I0008',
#  'H016I0009',
#  'H016I0010',
#  'H016I0011',
#  'H016I0012',
#  'H016I0013',
#  'H016I0014',
#  'H016I0015',
#  'H016I0016',
#  'H016I0017',
#  'H0170001',
#  'H0170002',
#  'H0170003',
#  'H0170004',
#  'H0170005',
#  'H0170006',
#  'H0170007',
#  'H0170008',
#  'H0170009',
#  'H0170010',
#  'H0170011',
#  'H0170012',
#  'H0170013',
#  'H0170014',
#  'H0170015',
#  'H0170016',
#  'H0170017',
#  'H0170018',
#  'H0170019',
#  'H0170020',
#  'H0170021',
#  'H017A0001',
#  'H017A0002',
#  'H017A0003',
#  'H017A0004',
#  'H017A0005',
#  'H017A0006',
#  'H017A0007',
#  'H017A0008',
#  'H017A0009',
#  'H017A0010',
#  'H017A0011',
#  'H017A0012',
#  'H017A0013',
#  'H017A0014',
#  'H017A0015',
#  'H017A0016',
#  'H017A0017',
#  'H017A0018',
#  'H017A0019',
#  'H017A0020',
#  'H017A0021',
#  'H017B0001',
#  'H017B0002',
#  'H017B0003',
#  'H017B0004',
#  'H017B0005',
#  'H017B0006',
#  'H017B0007',
#  'H017B0008',
#  'H017B0009',
#  'H017B0010',
#  'H017B0011',
#  'H017B0012',
#  'H017B0013',
#  'H017B0014',
#  'H017B0015',
#  'H017B0016',
#  'H017B0017',
#  'H017B0018',
#  'H017B0019',
#  'H017B0020',
#  'H017B0021',
#  'H017C0001',
#  'H017C0002',
#  'H017C0003',
#  'H017C0004',
#  'H017C0005',
#  'H017C0006',
#  'H017C0007',
#  'H017C0008',
#  'H017C0009',
#  'H017C0010',
#  'H017C0011',
#  'H017C0012',
#  'H017C0013',
#  'H017C0014',
#  'H017C0015',
#  'H017C0016',
#  'H017C0017',
#  'H017C0018',
#  'H017C0019',
#  'H017C0020',
#  'H017C0021',
#  'H017D0001',
#  'H017D0002',
#  'H017D0003',
#  'H017D0004',
#  'H017D0005',
#  'H017D0006',
#  'H017D0007',
#  'H017D0008',
#  'H017D0009',
#  'H017D0010',
#  'H017D0011',
#  'H017D0012',
#  'H017D0013',
#  'H017D0014',
#  'H017D0015',
#  'H017D0016',
#  'H017D0017',
#  'H017D0018',
#  'H017D0019',
#  'H017D0020',
#  'H017D0021',
#  'H017E0001',
#  'H017E0002',
#  'H017E0003',
#  'H017E0004',
#  'H017E0005',
#  'H017E0006',
#  'H017E0007',
#  'H017E0008',
#  'H017E0009',
#  'H017E0010',
#  'H017E0011',
#  'H017E0012',
#  'H017E0013',
#  'H017E0014',
#  'H017E0015',
#  'H017E0016',
#  'H017E0017',
#  'H017E0018',
#  'H017E0019',
#  'H017E0020',
#  'H017E0021',
#  'H017F0001',
#  'H017F0002',
#  'H017F0003',
#  'H017F0004',
#  'H017F0005',
#  'H017F0006',
#  'H017F0007',
#  'H017F0008',
#  'H017F0009',
#  'H017F0010',
#  'H017F0011',
#  'H017F0012',
#  'H017F0013',
#  'H017F0014',
#  'H017F0015',
#  'H017F0016',
#  'H017F0017',
#  'H017F0018',
#  'H017F0019',
#  'H017F0020',
#  'H017F0021',
#  'H017G0001',
#  'H017G0002',
#  'H017G0003',
#  'H017G0004',
#  'H017G0005',
#  'H017G0006',
#  'H017G0007',
#  'H017G0008',
#  'H017G0009',
#  'H017G0010',
#  'H017G0011',
#  'H017G0012',
#  'H017G0013',
#  'H017G0014',
#  'H017G0015',
#  'H017G0016',
#  'H017G0017',
#  'H017G0018',
#  'H017G0019',
#  'H017G0020',
#  'H017G0021',
#  'H017H0001',
#  'H017H0002',
#  'H017H0003',
#  'H017H0004',
#  'H017H0005',
#  'H017H0006',
#  'H017H0007',
#  'H017H0008',
#  'H017H0009',
#  'H017H0010',
#  'H017H0011',
#  'H017H0012',
#  'H017H0013',
#  'H017H0014',
#  'H017H0015',
#  'H017H0016',
#  'H017H0017',
#  'H017H0018',
#  'H017H0019',
#  'H017H0020',
#  'H017H0021',
#  'H017I0001',
#  'H017I0002',
#  'H017I0003',
#  'H017I0004',
#  'H017I0005',
#  'H017I0006',
#  'H017I0007',
#  'H017I0008',
#  'H017I0009',
#  'H017I0010',
#  'H017I0011',
#  'H017I0012',
#  'H017I0013',
#  'H017I0014',
#  'H017I0015',
#  'H017I0016',
#  'H017I0017',
#  'H017I0018',
#  'H017I0019',
#  'H017I0020',
#  'H017I0021',
#  'H0180001',
#  'H0180002',
#  'H0180003',
#  'H0180004',
#  'H0180005',
#  'H0180006',
#  'H0180007',
#  'H0180008',
#  'H0180009',
#  'H0180010',
#  'H0180011',
#  'H0180012',
#  'H0180013',
#  'H0180014',
#  'H0180015',
#  'H0180016',
#  'H0180017',
#  'H0180018',
#  'H0180019',
#  'H0180020',
#  'H0180021',
#  'H0180022',
#  'H0180023',
#  'H0180024',
#  'H0180025',
#  'H0180026',
#  'H0180027',
#  'H0180028',
#  'H0180029',
#  'H0180030',
#  'H0180031',
#  'H0180032',
#  'H0180033',
#  'H0180034',
#  'H0180035',
#  'H0180036',
#  'H0180037',
#  'H0180038',
#  'H0180039',
#  'H0180040',
#  'H0180041',
#  'H0180042',
#  'H0180043',
#  'H0180044',
#  'H0180045',
#  'H0180046',
#  'H0180047',
#  'H0180048',
#  'H0180049',
#  'H0180050',
#  'H0180051',
#  'H0180052',
#  'H0180053',
#  'H0180054',
#  'H0180055',
#  'H0180056',
#  'H0180057',
#  'H0180058',
#  'H0180059',
#  'H0180060',
#  'H0180061',
#  'H0180062',
#  'H0180063',
#  'H0180064',
#  'H0180065',
#  'H0180066',
#  'H0180067',
#  'H0180068',
#  'H0180069',
#  'H0190001',
#  'H0190002',
#  'H0190003',
#  'H0190004',
#  'H0190005',
#  'H0190006',
#  'H0190007',
#  'H0200001',
#  'H0200002',
#  'H0200003',
#  'H0210001',
#  'H0210002',
#  'H0210003',
#  'H0220001',
#  'H0220002',
#  'H0220003',
#  'HCT0010001',
#  'HCT0010002',
#  'HCT0010003',
#  'HCT0010004',
#  'HCT0010005',
#  'HCT0010006',
#  'HCT0010007',
#  'HCT0010008',
#  'HCT0010009',
#  'HCT0010010',
#  'HCT0010011',
#  'HCT0010012',
#  'HCT0010013',
#  'HCT0010014',
#  'HCT0010015',
#  'HCT0010016',
#  'HCT0010017',
#  'HCT0010018',
#  'HCT0010019',
#  'HCT0010020',
#  'HCT0010021',
#  'HCT0010022',
#  'HCT0010023',
#  'HCT0010024',
#  'HCT0010025',
#  'HCT0010026',
#  'HCT0010027',
#  'HCT0010028',
#  'HCT0010029',
#  'HCT0010030',
#  'HCT0010031',
#  'HCT0010032',
#  'HCT0010033',
#  'HCT0010034',
#  'HCT0010035',
#  'HCT0020001',
#  'HCT0020002',
#  'HCT0020003',
#  'HCT0020004',
#  'HCT0020005',
#  'HCT0020006',
#  'HCT0020007',
#  'HCT0020008',
#  'HCT0020009',
#  'HCT0020010',
#  'HCT0020011',
#  'HCT0020012',
#  'HCT0020013',
#  'HCT0030001',
#  'HCT0030002',
#  'HCT0030003',
#  'HCT0030004',
#  'HCT0030005',
#  'HCT0030006',
#  'HCT0030007',
#  'HCT0030008',
#  'HCT0030009',
#  'HCT0030010',
#  'HCT0030011',
#  'HCT0030012',
#  'HCT0030013',
#  'HCT0040001',
#  'HCT0040002',
#  'HCT0040003',
#  'HCT0040004',
#  'HCT0040005',
#  'HCT0040006',
#  'HCT0040007',
#  'HCT0040008',
#  'HCT0040009',
#  'HCT0040010',
#  'HCT0040011',
#  'HCT0040012',
#  'HCT0040013',
#  'LOGRECNO',
#  'MEMI',
#  'METDIV',
#  'NAME',
#  'NECTA',
#  'NECTADIV',
#  'NECTAPCI',
#  'P0010001',
#  'P0020001',
#  'P0020002',
#  'P0020003',
#  'P0020004',
#  'P0020005',
#  'P0020006',
#  'P0030001',
#  'P0030002',
#  'P0030003',
#  'P0030004',
#  'P0030005',
#  'P0030006',
#  'P0030007',
#  'P0030008',
#  'P0040001',
#  'P0040002',
#  'P0040003',
#  'P0050001',
#  'P0050002',
#  'P0050003',
#  'P0050004',
#  'P0050005',
#  'P0050006',
#  'P0050007',
#  'P0050008',
#  'P0050009',
#  'P0050010',
#  'P0050011',
#  'P0050012',
#  'P0050013',
#  'P0050014',
#  'P0050015',
#  'P0050016',
#  'P0050017',
#  'P0060001',
#  'P0060002',
#  'P0060003',
#  'P0060004',
#  'P0060005',
#  'P0060006',
#  'P0060007',
#  'P0070001',
#  'P0070002',
#  'P0070003',
#  'P0070004',
#  'P0070005',
#  'P0070006',
#  'P0070007',
#  'P0070008',
#  'P0070009',
#  'P0070010',
#  'P0070011',
#  'P0070012',
#  'P0070013',
#  'P0070014',
#  'P0070015',
#  'P0080001',
#  'P0080002',
#  'P0080003',
#  'P0080004',
#  'P0080005',
#  'P0080006',
#  'P0080007',
#  'P0080008',
#  'P0080009',
#  'P0080010',
#  'P0080011',
#  'P0080012',
#  'P0080013',
#  'P0080014',
#  'P0080015',
#  'P0080016',
#  'P0080017',
#  'P0080018',
#  'P0080019',
#  'P0080020',
#  'P0080021',
#  'P0080022',
#  'P0080023',
#  'P0080024',
#  'P0080025',
#  'P0080026',
#  'P0080027',
#  'P0080028',
#  'P0080029',
#  'P0080030',
#  'P0080031',
#  'P0080032',
#  'P0080033',
#  'P0080034',
#  'P0080035',
#  'P0080036',
#  'P0080037',
#  'P0080038',
#  'P0080039',
#  'P0080040',
#  'P0080041',
#  'P0080042',
#  'P0080043',
#  'P0080044',
#  'P0080045',
#  'P0080046',
#  'P0080047',
#  'P0080048',
#  'P0080049',
#  'P0080050',
#  'P0080051',
#  'P0080052',
#  'P0080053',
#  'P0080054',
#  'P0080055',
#  'P0080056',
#  'P0080057',
#  'P0080058',
#  'P0080059',
#  'P0080060',
#  'P0080061',
#  'P0080062',
#  'P0080063',
#  'P0080064',
#  'P0080065',
#  'P0080066',
#  'P0080067',
#  'P0080068',
#  'P0080069',
#  'P0080070',
#  'P0080071',
#  'P0090001',
#  'P0090002',
#  'P0090003',
#  'P0090004',
#  'P0090005',
#  'P0090006',
#  'P0090007',
#  'P0090008',
#  'P0090009',
#  'P0090010',
#  'P0090011',
#  'P0090012',
#  'P0090013',
#  'P0090014',
#  'P0090015',
#  'P0090016',
#  'P0090017',
#  'P0090018',
#  'P0090019',
#  'P0090020',
#  'P0090021',
#  'P0090022',
#  'P0090023',
#  'P0090024',
#  'P0090025',
#  'P0090026',
#  'P0090027',
#  'P0090028',
#  'P0090029',
#  'P0090030',
#  'P0090031',
#  'P0090032',
#  'P0090033',
#  'P0090034',
#  'P0090035',
#  'P0090036',
#  'P0090037',
#  'P0090038',
#  'P0090039',
#  'P0090040',
#  'P0090041',
#  'P0090042',
#  'P0090043',
#  'P0090044',
#  'P0090045',
#  'P0090046',
#  'P0090047',
#  'P0090048',
#  'P0090049',
#  'P0090050',
#  'P0090051',
#  'P0090052',
#  'P0090053',
#  'P0090054',
#  'P0090055',
#  'P0090056',
#  'P0090057',
#  'P0090058',
#  'P0090059',
#  'P0090060',
#  'P0090061',
#  'P0090062',
#  'P0090063',
#  'P0090064',
#  'P0090065',
#  'P0090066',
#  'P0090067',
#  'P0090068',
#  'P0090069',
#  'P0090070',
#  'P0090071',
#  'P0090072',
#  'P0090073',
#  'P0100001',
#  'P0100002',
#  'P0100003',
#  'P0100004',
#  'P0100005',
#  'P0100006',
#  'P0100007',
#  'P0100008',
#  'P0100009',
#  'P0100010',
#  'P0100011',
#  'P0100012',
#  'P0100013',
#  'P0100014',
#  'P0100015',
#  'P0100016',
#  'P0100017',
#  'P0100018',
#  'P0100019',
#  'P0100020',
#  'P0100021',
#  'P0100022',
#  'P0100023',
#  'P0100024',
#  'P0100025',
#  'P0100026',
#  'P0100027',
#  'P0100028',
#  'P0100029',
#  'P0100030',
#  'P0100031',
#  'P0100032',
#  'P0100033',
#  'P0100034',
#  'P0100035',
#  'P0100036',
#  'P0100037',
#  'P0100038',
#  'P0100039',
#  'P0100040',
#  'P0100041',
#  'P0100042',
#  'P0100043',
#  'P0100044',
#  'P0100045',
#  'P0100046',
#  'P0100047',
#  'P0100048',
#  'P0100049',
#  'P0100050',
#  'P0100051',
#  'P0100052',
#  'P0100053',
#  'P0100054',
#  'P0100055',
#  'P0100056',
#  'P0100057',
#  'P0100058',
#  'P0100059',
#  ...]

# %%
var_json['variables']['P0050002']
# Out:
# {'concept': 'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  'label': 'Not Hispanic or Latino:'}

# %%
from pandas import DataFrame
DataFrame(var_json['variables']).T
# Out:
#                                                       concept  \
# AIANHH                               Geographic Summary Level
# AIANHHCC                           Geographic Characteristics
# AIANHHFP                           Geographic Characteristics
# AIHHTLI                            Geographic Characteristics
# AITS                               Geographic Characteristics
# AITSCC                             Geographic Characteristics
# AITSCE                             Geographic Characteristics
# ANRC                               Geographic Characteristics
# BLKGRP                               Geographic Summary Level
# BLOCK                                                     NaN
# CBSA                                 Geographic Summary Level
# CBSAPCI                            Geographic Characteristics
# CD                                   Geographic Summary Level
# CD113                              Geographic Characteristics
# CNECTA                             Geographic Characteristics
# CONCIT                               Geographic Summary Level
# CONCITSC                           Geographic Characteristics
# COUNTY                               Geographic Summary Level
# COUSUB                               Geographic Summary Level
# CSA                                  Geographic Summary Level
# DIVISION                             Geographic Summary Level
# GEOCOMP                            Geographic Characteristics
# H00010001                               H1. Housing Units [1]
# H0020001    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020002    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020003    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020004    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020005    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020006    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0030001                             H3. Occupancy Status [3]
# ...                                                       ...
# PCT022I020  PCT22I. GROUP QUARTERS POPULATION BY SEX BY GR...
# PCT022I021  PCT22I. GROUP QUARTERS POPULATION BY SEX BY GR...
# PLACE                                Geographic Summary Level
# PLACECC                            Geographic Characteristics
# REGION                               Geographic Summary Level
# SDELEM                               Geographic Summary Level
# SDSEC                                Geographic Summary Level
# SDUNI                                Geographic Summary Level
# SLDL                                 Geographic Summary Level
# SLDL2                              Geographic Characteristics
# SLDL3                              Geographic Characteristics
# SLDL4                              Geographic Characteristics
# SLDU                                 Geographic Summary Level
# SLDU2                              Geographic Characteristics
# SLDU3                              Geographic Characteristics
# SLDU4                              Geographic Characteristics
# STATE                                Geographic Summary Level
# SUBMCD                               Geographic Summary Level
# SUBMCDCC                                                  NaN
# SUMLEV                             Geographic Characteristics
# TRACT                                Geographic Summary Level
# UASC                               Geographic Characteristics
# UATYPE                             Geographic Characteristics
# UGA                                Geographic Characteristics
# UR                                 Geographic Characteristics
# VTD                                Geographic Characteristics
# ZCTA5                              Geographic Characteristics
# for                        Census API Geography Specification
# gnis                       Census API Geography Specification
# in                         Census API Geography Specification
#
#                                                         label predicateOnly  \
# AIANHH                                       GEO PLACE HOLDER           NaN
# AIANHHCC                                     GEO PLACE HOLDER           NaN
# AIANHHFP                                     GEO PLACE HOLDER           NaN
# AIHHTLI                                      GEO PLACE HOLDER           NaN
# AITS                                         GEO PLACE HOLDER           NaN
# AITSCC                                       GEO PLACE HOLDER           NaN
# AITSCE                                       GEO PLACE HOLDER           NaN
# ANRC                                         GEO PLACE HOLDER           NaN
# BLKGRP                                       GEO PLACE HOLDER           NaN
# BLOCK                                        GEO PLACE HOLDER           NaN
# CBSA                                         GEO PLACE HOLDER           NaN
# CBSAPCI                                      GEO PLACE HOLDER           NaN
# CD                                           GEO PLACE HOLDER           NaN
# CD113                                        GEO PLACE HOLDER           NaN
# CNECTA                                       GEO PLACE HOLDER           NaN
# CONCIT                                       GEO PLACE HOLDER           NaN
# CONCITSC                                     GEO PLACE HOLDER           NaN
# COUNTY                                         County (FIPS))           NaN
# COUSUB                                       GEO PLACE HOLDER           NaN
# CSA                                          GEO PLACE HOLDER           NaN
# DIVISION                                     GEO PLACE HOLDER           NaN
# GEOCOMP                                      GEO PLACE HOLDER           NaN
# H00010001                                       Housing units           NaN
# H0020001                                        Housing units           NaN
# H0020002                                               Urban:           NaN
# H0020003                     Urban: !! Inside urbanized areas           NaN
# H0020004                      Urban: !! Inside urban clusters           NaN
# H0020005                       Rural !! Inside urban clusters           NaN
# H0020006    Not defined for this file !! Inside urban clus...           NaN
# H0030001                                        Housing units           NaN
# ...                                                       ...           ...
# PCT022I020  Female: !! Noninstitutionalized population (50...           NaN
# PCT022I021  Female: !! Noninstitutionalized population (50...           NaN
# PLACE                                           Place (FIPS))           NaN
# PLACECC                                      GEO PLACE HOLDER           NaN
# REGION                                       GEO PLACE HOLDER           NaN
# SDELEM                                       GEO PLACE HOLDER           NaN
# SDSEC                                        GEO PLACE HOLDER           NaN
# SDUNI                                        GEO PLACE HOLDER           NaN
# SLDL                                         GEO PLACE HOLDER           NaN
# SLDL2                                        GEO PLACE HOLDER           NaN
# SLDL3                                        GEO PLACE HOLDER           NaN
# SLDL4                                        GEO PLACE HOLDER           NaN
# SLDU                                         GEO PLACE HOLDER           NaN
# SLDU2                                        GEO PLACE HOLDER           NaN
# SLDU3                                        GEO PLACE HOLDER           NaN
# SLDU4                                        GEO PLACE HOLDER           NaN
# STATE                                            State (FIPS)           NaN
# SUBMCD                                       GEO PLACE HOLDER           NaN
# SUBMCDCC                                     GEO PLACE HOLDER           NaN
# SUMLEV                                          Summary Level           NaN
# TRACT                                           Tract (FIPS))           NaN
# UASC                                         GEO PLACE HOLDER           NaN
# UATYPE                                       GEO PLACE HOLDER           NaN
# UGA                                          GEO PLACE HOLDER           NaN
# UR                                           GEO PLACE HOLDER           NaN
# VTD                                          GEO PLACE HOLDER           NaN
# ZCTA5                                        GEO PLACE HOLDER           NaN
# for                              Census API FIPS 'for' clause          True
# gnis                                   Census API GNIS clause          True
# in                                Census API FIPS 'in' clause          True
#
#            predicateType
# AIANHH               NaN
# AIANHHCC             NaN
# AIANHHFP             NaN
# AIHHTLI              NaN
# AITS                 NaN
# AITSCC               NaN
# AITSCE               NaN
# ANRC                 NaN
# BLKGRP               NaN
# BLOCK                NaN
# CBSA                 NaN
# CBSAPCI              NaN
# CD                   NaN
# CD113                NaN
# CNECTA               NaN
# CONCIT               NaN
# CONCITSC             NaN
# COUNTY               NaN
# COUSUB               NaN
# CSA                  NaN
# DIVISION             NaN
# GEOCOMP              int
# H00010001            NaN
# H0020001             NaN
# H0020002             NaN
# H0020003             NaN
# H0020004             NaN
# H0020005             NaN
# H0020006             NaN
# H0030001             NaN
# ...                  ...
# PCT022I020           NaN
# PCT022I021           NaN
# PLACE                NaN
# PLACECC              NaN
# REGION               NaN
# SDELEM               NaN
# SDSEC                NaN
# SDUNI                NaN
# SLDL                 NaN
# SLDL2                NaN
# SLDL3                NaN
# SLDL4                NaN
# SLDU                 NaN
# SLDU2                NaN
# SLDU3                NaN
# SLDU4                NaN
# STATE                NaN
# SUBMCD               NaN
# SUBMCDCC             NaN
# SUMLEV               NaN
# TRACT                NaN
# UASC                 NaN
# UATYPE               NaN
# UGA                  NaN
# UR                   NaN
# VTD                  NaN
# ZCTA5                NaN
# for             fips-for
# gnis                gnis
# in               fips-in
#
# [8969 rows x 4 columns]

# %% [markdown]
# # Plotting Age Distribution By Gender (Population Pyramid)

# %% [markdown]
# This example written by AJ Renold.  (and rewritten by R. Yee to adapt to changes in the census API.)

# %%
sf1_fields
# Out:
# {}

# %%
sf1_fields = c.sf1.fields(year=2010)

# Get the sf1 fields that are only P12 Sex By Age
gender_population_fields = sf1_fields.get('P12. Sex By Age [49]')

# Separate the by male and female
male_fields = { key: val for key, val in gender_population_fields.items() 
                                 if 'Male' in val and val != ' Male: ' }
female_fields = { key: val for key, val in gender_population_fields.items() 
                                   if 'Female' in val and val != ' Female: '}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-dc3b3cc82a46> in <module>()
#       5
#       6 # Separate the by male and female
# ----> 7 male_fields = { key: val for key, val in gender_population_fields.items()
#       8                                  if 'Male' in val and val != ' Male: ' }
#       9 female_fields = { key: val for key, val in gender_population_fields.items()
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
# Query the census API with the gender_population_fields
query_results = c.sf1.get(('NAME', ','.join(gender_population_fields.keys())), geo={'for': 'state:*'})

# Create a DataFrame
gender_df = pd.DataFrame(query_results)

# %%
# Set the Index to the NAME column
gender_df = gender_df.set_index(gender_df['NAME'])

# %%
# Recast all numeric columns to be type int
for col in gender_df.columns:
    if col != "state" and col != "NAME":
        gender_df[col] = gender_df[col].astype(int)

# %%
from numpy import arange

def showPopulationPyramidPlot(df, state, male_fields, female_fields):
    
    # create a series with the row of the state
    s = Series(df.ix[state])
    #del s['NAME']
    #del s['state']
    
    # get the plot values and labels from the series
    male_list = sorted([ [key, s[key]] for key in s.keys() if key in male_fields ])
    female_list = sorted([ [key, s[key]] for key in s.keys() if key in female_fields ]) 
    
    # calculate the bar locations and the maximum value
    bar_ypos = arange(len(male_list))+.5
    max_val = max([ val for label, val in male_list + female_list ])
    
    # create the figures for the plots
    fig, (ax2, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
    fig.suptitle('Population Age Pyramid for {state}'.format(state=state), fontsize=14)
    
    # plot the male populations
    bar1 = ax1.barh(bar_ypos, [ val for label, val in male_list ], align='center')
    ax1.set_xlim((0,max_val))
    ax1.set_yticks(bar_ypos)
    ax1.set_yticklabels([ male_fields[label][male_fields[label].find('!!')+3:] for label, val in male_list ])
    ax1.set_xlabel('People')
    ax1.set_title('Male Population by Age')
    ax1.grid(True)
    
    # plot the the female populations
    bar2 = ax2.barh(bar_ypos,[ val for label, val in female_list ], align='center', color='red')
    ax2.set_yticks([])
    #ax2.yaxis.tick_right()
    ax2.set_xlim(ax1.get_xlim()[::-1]) # reverses the x axis direction
    ax2.set_xlabel('People')
    ax2.set_title('Female Population by Age')
    ax2.grid(True)
    
    plt.subplots_adjust(wspace=0.22, hspace=0.0)
    plt.show()

# %%
showPopulationPyramidPlot(gender_df, 'Illinois', male_fields, female_fields)
